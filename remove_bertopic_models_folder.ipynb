# %%
import shutil
import os

path = "./final/bertopic_models"

# Controlla se la cartella esiste prima di eliminarla
if os.path.exists(path):
    shutil.rmtree(path)
    print(f"Cartella '{path}' eliminata con successo.")
else:
    print(f"La cartella '{path}' non esiste.")
