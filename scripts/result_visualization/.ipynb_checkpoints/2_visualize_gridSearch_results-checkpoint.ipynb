# %%
level_depth = 0

# %%
import os
import argparse
from pathlib import Path
import pandas as pd
from bertopic import BERTopic
import plotly.io as pio

# Headless-safe Plotly renderer
pio.renderers.default = "notebook_connected" if (os.environ.get("DISPLAY") or os.environ.get("MPLBACKEND")) else "png"


print(f"[INFO] level_depth={level_depth}")

# --- Per-level layout only ---
BASE_LEVEL_DIR = Path(f"/home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_{level_depth}")
GRID_DIR       = BASE_LEVEL_DIR / "grid_search"

DF_SAMPLED_CSV = GRID_DIR / f"df_sampled_level_{level_depth}.csv"
GRID_RESULTS   = GRID_DIR / f"grid_search_results_level_{level_depth}.csv"
MODELS_DIR     = GRID_DIR / f"bertopic_models_level_{level_depth}"

# --- Validate required inputs ---
missing = [p for p in (DF_SAMPLED_CSV, GRID_RESULTS, MODELS_DIR) if not p.exists()]
if missing:
    miss_str = "\n  - ".join(str(m) for m in missing)
    raise FileNotFoundError(f"Required paths/files not found for level {level_depth}:\n  - {miss_str}")

print(f"[INFO] DF_SAMPLED_CSV = {DF_SAMPLED_CSV}")
print(f"[INFO] GRID_RESULTS   = {GRID_RESULTS}")
print(f"[INFO] MODELS_DIR     = {MODELS_DIR}")

# --- Load dataframes ---
df_sampled = pd.read_csv(DF_SAMPLED_CSV)
df_grid = pd.read_csv(GRID_RESULTS)

# --- Compute avg_score and filter (aligned with your grid search) ---
required_cols = ("silhouette", "coherence", "diversity", "hdbscan_min_cluster_size")
missing_cols = [c for c in required_cols if c not in df_grid.columns]
if missing_cols:
    raise ValueError(f"Missing columns in grid_search_results: {missing_cols}")

df_grid["avg_score"] = (df_grid["silhouette"] + df_grid["coherence"] + df_grid["diversity"]) / 3
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------------------------------------------------------------

# --- Select best rows for each metric ---
best_models = {
    "silhouette": df_grid[
        (df_grid["hdbscan_min_cluster_size"] != 10) &
        (df_grid["umap_n_neighbors"] != 25) &
        (df_grid["umap_n_neighbors"] != 3)
    ].sort_values(by="silhouette", ascending=False).iloc[0],

    # Più topic: preferisci cluster più piccoli (10 o 15), UMAP più locale (5) e embedding più compatti (min_dist=0.0)
    "coherence": df_grid[
        (df_grid["hdbscan_min_cluster_size"].isin([10, 30])) &
        (df_grid["umap_n_neighbors"]  != 25) &
        (df_grid["umap_min_dist"] == 0.0)
    ].sort_values(by="coherence", ascending=False).iloc[0],

    "diversity": df_grid[
        (df_grid["hdbscan_min_cluster_size"].isin([10, 30])) &
        (df_grid["umap_n_neighbors"] != 25) &
        (df_grid["umap_min_dist"] == 0.0)
    ].sort_values(by="diversity", ascending=False).iloc[0],

    "avg_score": df_grid[
        (df_grid["hdbscan_min_cluster_size"].isin([10, 30])) &
        (df_grid["umap_n_neighbors"]  != 25) &
        (df_grid["umap_min_dist"] == 0.0)
    ].sort_values(by="avg_score", ascending=False).iloc[0],
}




# Expose for later cells
print("[INFO] Data and grid loaded. Variables available:")
print(f"  MODELS_DIR = {MODELS_DIR}")
print(f"  DF_SAMPLED_CSV = {DF_SAMPLED_CSV}")
print(f"  GRID_RESULTS = {GRID_RESULTS}")
print("  best_models keys =", list(best_models.keys()))

print("df_sampled sampled")
print(df_sampled.head())
# Out:
# [INFO] level_depth=0
# [INFO] DF_SAMPLED_CSV = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/df_sampled_level_0.csv
# [INFO] GRID_RESULTS   = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/grid_search_results_level_0.csv
# [INFO] MODELS_DIR     = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0
# [INFO] Data and grid loaded. Variables available:
#   MODELS_DIR = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0
#   DF_SAMPLED_CSV = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/df_sampled_level_0.csv
#   GRID_RESULTS = /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/grid_search_results_level_0.csv
#   best_models keys = ['silhouette', 'coherence', 'diversity', 'avg_score']
# df_sampled sampled
#                                                 text   timestamp  \
# 0  💊 DEBATE [36.3K/1.9%] $DEBATE 🔼\n🌐 Solana @ Ra...  1725920360
# 1  We will make America greater than ever before ...  1702146126
# 2  JD Vance: Whatever the number is, it's way too...  1724594968
# 3  Japanese Scientists Find Indisputable Evidence...  1702808169
# 4  Pamela's friend told me that she is on holiday...  1706170568
#
#                                    text_preprocessed language  \
# 0  debate debate solana raydium xvol mint tgxweb ...       en
# 1      america greater support join share join storm       en
# 2  vance number high millions illegals come kamal...       en
# 3  japanese scientists find indisputable evidence...       en
# 4  pamelafriend told holiday queenstown wait post...       en
#
#            channel_id
# 0  channel_2065916066
# 1  channel_1906835275
# 2  channel_2097121852
# 3  channel_1410320603
# 4  channel_1840578235

# %%
#SILHOUETTE

from pathlib import Path
from bertopic import BERTopic

print("[INFO] Visualizzo il best model per SILHOUETTE")

key = "silhouette"
row = best_models[key]

suffix = (
    f"{row['model']}_"
    f"umap{row['umap_n_components']}_"
    f"umap{row['umap_n_neighbors']}_"
    f"umap{row['umap_min_dist']}_"
    f"hdbscan{row['hdbscan_min_cluster_size']}"
)
model_path = Path(MODELS_DIR) / suffix
print(model_path)

if not model_path.exists():
    print(f"[WARN] Path not found: {model_path}")
else:
    print(f"[INFO] Loading model for best {key} from: {model_path}")
    topic_model = BERTopic.load(str(model_path))
    num_topics = len(set(topic_model.topics_))
    print(f"[INFO] {key}: {num_topics} topics found, at most 180 topics are shown")

    fig = topic_model.visualize_barchart(
        top_n_topics=min(180, num_topics),
        n_words=20,
        width=350,
        height=450
    )
    try:
        fig.show()
    except Exception:
        print("[WARN] Impossibile mostrare il grafico in questa sessione.")
# Out:
# [INFO] Visualizzo il best model per SILHOUETTE
# /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/all-MiniLM-L6-v2_umap3_umap5_umap0.0_hdbscan50
# [INFO] Loading model for best silhouette from: /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/all-MiniLM-L6-v2_umap3_umap5_umap0.0_hdbscan50
# [INFO] silhouette: 95 topics found, at most 80 topics are shown
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0832c046-ee35-48a3-b46c-ff75f4d3ca11" class="plotly-graph-div" style="height:9000px; width:1400px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0832c046-ee35-48a3-b46c-ff75f4d3ca11")) {                    Plotly.newPlot(                        "0832c046-ee35-48a3-b46c-ff75f4d3ca11",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008260845595982069,0.008297272519387333,0.008377761854667327,0.008383058500904103,0.009119067009700967,0.009517965356370858,0.00969629908400719,0.0099307306111369,0.010175716242617542,0.011580756900085677,0.012179183270201807,0.012279589081009595,0.01306696956805108,0.015695570750644483,0.016677241730833813,0.017603985181223428,0.018860029038426995,0.021242252642248265,0.054673018801643554,0.0753842863568361],"y":["conference  ","question  ","days  ","single  ","press  ","democrat  ","hasn  ","vice  ","liberal  ","radical  ","nominee  ","questions  ","campaign  ","interview  ","trump  ","biden  ","president  ","debate  ","harris  ","kamala  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.011934075479384377,0.012133337165766067,0.013024551091739492,0.013373931195373936,0.01347462694120717,0.014028816776102656,0.015175885377394241,0.015551282459892114,0.016141485155334475,0.016979215998019662,0.017399079233943224,0.019998479943785234,0.021303381740653483,0.021609168339292596,0.02183495978576194,0.02261914537852886,0.024308986628210443,0.03445671207021693,0.03712267599007598,0.04302893701531427],"y":["ruling  ","prosecution  ","donald  ","president  ","merchan  ","breaking  ","york  ","read  ","willis  ","fani  ","attorney  ","immunity  ","jack  ","supreme  ","trump  ","smith  ","trial  ","court  ","case  ","judge  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.00963978788450659,0.010272034462113507,0.010377860586923143,0.010439190485337035,0.011312186825566947,0.011818995890104574,0.012086868276957267,0.012585235459126348,0.013916217468719703,0.014577214790536731,0.014741651757727455,0.017034118237567758,0.017716871735742237,0.018530929150732078,0.02155795124374025,0.0247220349794083,0.03573882100150732,0.04816719763780423,0.05664646067853377,0.06656351537824744],"y":["held  ","october  ","forces  ","palestine  ","minister  ","terrorist  ","killed  ","release  ","hostage  ","netanyahu  ","humanitarian  ","palestinians  ","strip  ","ceasefire  ","palestinian  ","hostages  ","israeli  ","israel  ","hamas  ","gaza  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008550867113130715,0.008614877260366263,0.008647142628568126,0.00892427008560861,0.009454878673628838,0.009674788891820753,0.009679347677738575,0.010072857340641865,0.01017073574542187,0.010356218405150549,0.010408182497941556,0.010601721614794512,0.01292967669056443,0.019355738925253458,0.02256261894307283,0.027211002823552623,0.030461798969379873,0.04356144675281213,0.05211756374261872,0.08410680506050222],"y":["nuclear  ","ukrainians  ","potus  ","support  ","kyiv  ","missiles  ","forces  ","missile  ","dear  ","military  ","package  ","moscow  ","russians  ","weapons  ","nato  ","ukrainian  ","putin  ","russian  ","russia  ","ukraine  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010579020494875947,0.010586542886575373,0.010680024226415083,0.01107978049111572,0.011502420247208364,0.01252903724640511,0.012782721906653673,0.012843688306534162,0.012843688306534162,0.014820069235897742,0.017079524187018514,0.01778285455264437,0.020675902158614652,0.021706707561378324,0.02228220014760148,0.02541123358827047,0.025824217996080274,0.029367551323512254,0.0423918783282513,0.05645625047360284],"y": ...

# %%
#COHERENCE from pathlib import Path

from bertopic import BERTopic

print("[INFO] Visualizzo il best model per COHERENCE")

key = "coherence"
row = best_models[key]

suffix = (
    f"{row['model']}_"
    f"umap{row['umap_n_components']}_"
    f"umap{row['umap_n_neighbors']}_"
    f"umap{row['umap_min_dist']}_"
    f"hdbscan{row['hdbscan_min_cluster_size']}"
)
model_path = Path(MODELS_DIR) / suffix
print(model_path)

if not model_path.exists():
    print(f"[WARN] Path not found: {model_path}")
else:
    print(f"[INFO] Loading model for best {key} from: {model_path}")
    topic_model = BERTopic.load(str(model_path))
    num_topics = len(set(topic_model.topics_))
    print(f"[INFO] {key}: {num_topics} topics found, at most 180 topics are shown")

    fig = topic_model.visualize_barchart(
        top_n_topics=min(180, num_topics),
        n_words=20,
        width=350,
        height=450
    )
    try:
        fig.show()
    except Exception:
        print("[WARN] Impossibile mostrare il grafico in questa sessione.")
# Out:
# [INFO] Visualizzo il best model per COHERENCE
# /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] Loading model for best coherence from: /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] coherence: 134 topics found, at most 80 topics are shown
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="5614f746-154c-43cc-88ae-d6c5fa807afc" class="plotly-graph-div" style="height:9000px; width:1400px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5614f746-154c-43cc-88ae-d6c5fa807afc")) {                    Plotly.newPlot(                        "5614f746-154c-43cc-88ae-d6c5fa807afc",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007156617090336774,0.007379497215658136,0.007560197461188997,0.007635834824508521,0.00810616778058843,0.00858823346449794,0.009081912745616772,0.009094620100080561,0.009590833933385699,0.009915045162705392,0.010340485757759216,0.01279302126127538,0.01342122767154084,0.015027330945804197,0.017472214744206998,0.022176722720511056,0.02698480533575054,0.028402259124835492,0.04106119182246612,0.04864169895652069],"y":["vladimir  ","forces  ","like  ","europe  ","defense  ","drones  ","missile  ","countries  ","zelensky  ","nuclear  ","russians  ","military  ","missiles  ","weapons  ","ukrainian  ","nato  ","putin  ","russian  ","russia  ","ukraine  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.025575764984875606,0.02562632281904101,0.026058116759577466,0.02931849557669994,0.02970365147770314,0.03087984365162667,0.031146168278595773,0.034101678758046726,0.03774987590802663,0.03787156418513646,0.038476757475936915,0.04430065253040999,0.054750722007341025,0.056735164582853576,0.06374452993056988,0.07097054353809323,0.07333555863846802,0.08342396490525365,0.09017825015862672,0.1029433133996352],"y":["claiming  ","thanks  ","following  ","successfully  ","steps  ","migrated  ","airdrop  ","contract  ","mate  ","instructions  ","rewards  ","tokens  ","reward  ","claim  ","message  ","token  ","migrate  ","wallet  ","pinned  ","migration  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012747296753064163,0.013102984666037994,0.013167936561147914,0.0137672305749727,0.013893338021229678,0.013976868088551758,0.014421169345659434,0.014617264540596328,0.014658679715103455,0.01508890313847935,0.016890947361240357,0.01737060240115272,0.017428178992810357,0.01820079781626868,0.0190120457328857,0.020282920834940172,0.02088432471865436,0.0299985490757894,0.03334936285343818,0.03338696042889866],"y":["costs  ","rate  ","business  ","tariffs  ","economy  ","groceries  ","manufacturing  ","americans  ","average  ","jobs  ","harris  ","trump  ","american  ","energy  ","taxes  ","president  ","cost  ","kamala  ","prices  ","inflation  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008408428929883808,0.008452183090676354,0.008563203012532501,0.008595644529611824,0.008925540037712154,0.009110517680697282,0.009817557448707215,0.010651897812154766,0.01158796603335993,0.011736941817359426,0.011785814531428464,0.0119325325468605,0.01204338720728878,0.013009134248612799,0.01421758432023863,0.014627239995240784,0.015418669469619423,0.019401024306218328,0.038122332196443245,0.06081737804661008],"y":["installed  ","running  ","interviews  ","record  ","vote  ","policy  ","vice  ","democrat  ","conference  ","president  ","campaign  ","single  ","hasn  ","questions  ","press  ","nominee  ","walz  ","interview  ","harris  ","kamala  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.005907017439096928,0.006466653175628542,0.006661300065951612,0.007173654266337871,0.00749645239335095,0.007643936622183069,0.007665570860005846,0.007966106700536942,0.008362981766593516,0.009193216732651041,0.009620763323932493,0.009840484747722105,0.010233343998880009,0.010782160642189544,0.011607717381269969,0.011689526385301857,0.012844094538352255,0.013060263284078813,0.021334923436822407,0.032497402195 ...

# %%
#DIVERSITY

from pathlib import Path
from bertopic import BERTopic

print("[INFO] Visualizzo il best model per DIVERSITY")

key = "diversity"
row = best_models[key]

suffix = (
    f"{row['model']}_"
    f"umap{row['umap_n_components']}_"
    f"umap{row['umap_n_neighbors']}_"
    f"umap{row['umap_min_dist']}_"
    f"hdbscan{row['hdbscan_min_cluster_size']}"
)
model_path = Path(MODELS_DIR) / suffix
print(model_path)

if not model_path.exists():
    print(f"[WARN] Path not found: {model_path}")
else:
    print(f"[INFO] Loading model for best {key} from: {model_path}")
    topic_model = BERTopic.load(str(model_path))
    num_topics = len(set(topic_model.topics_))
    print(f"[INFO] {key}: {num_topics} topics found, at most 180 topics are shown")

    fig = topic_model.visualize_barchart(
        top_n_topics=min(180, num_topics),
        n_words=20,
        width=350,
        height=450
    )
    try:
        fig.show()
    except Exception:
        print("[WARN] Impossibile mostrare il grafico in questa sessione.")
# Out:
# [INFO] Visualizzo il best model per DIVERSITY
# /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] Loading model for best diversity from: /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] diversity: 134 topics found, at most 80 topics are shown
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="304347e4-65e4-46d3-93e4-5935b56514d0" class="plotly-graph-div" style="height:9000px; width:1400px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("304347e4-65e4-46d3-93e4-5935b56514d0")) {                    Plotly.newPlot(                        "304347e4-65e4-46d3-93e4-5935b56514d0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007156617090336774,0.007379497215658136,0.007560197461188997,0.007635834824508521,0.00810616778058843,0.00858823346449794,0.009081912745616772,0.009094620100080561,0.009590833933385699,0.009915045162705392,0.010340485757759216,0.01279302126127538,0.01342122767154084,0.015027330945804197,0.017472214744206998,0.022176722720511056,0.02698480533575054,0.028402259124835492,0.04106119182246612,0.04864169895652069],"y":["vladimir  ","forces  ","like  ","europe  ","defense  ","drones  ","missile  ","countries  ","zelensky  ","nuclear  ","russians  ","military  ","missiles  ","weapons  ","ukrainian  ","nato  ","putin  ","russian  ","russia  ","ukraine  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.025575764984875606,0.02562632281904101,0.026058116759577466,0.02931849557669994,0.02970365147770314,0.03087984365162667,0.031146168278595773,0.034101678758046726,0.03774987590802663,0.03787156418513646,0.038476757475936915,0.04430065253040999,0.054750722007341025,0.056735164582853576,0.06374452993056988,0.07097054353809323,0.07333555863846802,0.08342396490525365,0.09017825015862672,0.1029433133996352],"y":["claiming  ","thanks  ","following  ","successfully  ","steps  ","migrated  ","airdrop  ","contract  ","mate  ","instructions  ","rewards  ","tokens  ","reward  ","claim  ","message  ","token  ","migrate  ","wallet  ","pinned  ","migration  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012747296753064163,0.013102984666037994,0.013167936561147914,0.0137672305749727,0.013893338021229678,0.013976868088551758,0.014421169345659434,0.014617264540596328,0.014658679715103455,0.01508890313847935,0.016890947361240357,0.01737060240115272,0.017428178992810357,0.01820079781626868,0.0190120457328857,0.020282920834940172,0.02088432471865436,0.0299985490757894,0.03334936285343818,0.03338696042889866],"y":["costs  ","rate  ","business  ","tariffs  ","economy  ","groceries  ","manufacturing  ","americans  ","average  ","jobs  ","harris  ","trump  ","american  ","energy  ","taxes  ","president  ","cost  ","kamala  ","prices  ","inflation  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008408428929883808,0.008452183090676354,0.008563203012532501,0.008595644529611824,0.008925540037712154,0.009110517680697282,0.009817557448707215,0.010651897812154766,0.01158796603335993,0.011736941817359426,0.011785814531428464,0.0119325325468605,0.01204338720728878,0.013009134248612799,0.01421758432023863,0.014627239995240784,0.015418669469619423,0.019401024306218328,0.038122332196443245,0.06081737804661008],"y":["installed  ","running  ","interviews  ","record  ","vote  ","policy  ","vice  ","democrat  ","conference  ","president  ","campaign  ","single  ","hasn  ","questions  ","press  ","nominee  ","walz  ","interview  ","harris  ","kamala  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.005907017439096928,0.006466653175628542,0.006661300065951612,0.007173654266337871,0.00749645239335095,0.007643936622183069,0.007665570860005846,0.007966106700536942,0.008362981766593516,0.009193216732651041,0.009620763323932493,0.009840484747722105,0.010233343998880009,0.010782160642189544,0.011607717381269969,0.011689526385301857,0.012844094538352255,0.013060263284078813,0.021334923436822407,0.032497402195 ...

# %%
#AVG_SCORE

from pathlib import Path
from bertopic import BERTopic

print("[INFO] Visualizzo il best model per AVG_SCORE")

key = "avg_score"
row = best_models[key]

suffix = (
    f"{row['model']}_"
    f"umap{row['umap_n_components']}_"
    f"umap{row['umap_n_neighbors']}_"
    f"umap{row['umap_min_dist']}_"
    f"hdbscan{row['hdbscan_min_cluster_size']}"
)
model_path = Path(MODELS_DIR) / suffix
print(model_path)

if not model_path.exists():
    print(f"[WARN] Path not found: {model_path}")
else:
    print(f"[INFO] Loading model for best {key} from: {model_path}")
    topic_model = BERTopic.load(str(model_path))
    num_topics = len(set(topic_model.topics_))
    print(f"[INFO] {key}: {num_topics} topics found, at most 180 topics are shown")

    fig = topic_model.visualize_barchart(
        top_n_topics=min(180, num_topics),
        n_words=20,
        width=350,
        height=450
    )
    try:
        fig.show()
    except Exception:
        print("[WARN] Impossibile mostrare il grafico in questa sessione.")
# Out:
# [INFO] Visualizzo il best model per AVG_SCORE
# /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] Loading model for best avg_score from: /home/students/s328743/Thesis/Smart_crawler_telegram/results/levels/level_0/grid_search/bertopic_models_level_0/paraphrase-MiniLM-L6-v2_umap5_umap5_umap0.0_hdbscan30
# [INFO] avg_score: 134 topics found, at most 80 topics are shown
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="412a2d01-9b26-484a-853b-72ca6a314028" class="plotly-graph-div" style="height:9000px; width:1400px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("412a2d01-9b26-484a-853b-72ca6a314028")) {                    Plotly.newPlot(                        "412a2d01-9b26-484a-853b-72ca6a314028",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007156617090336774,0.007379497215658136,0.007560197461188997,0.007635834824508521,0.00810616778058843,0.00858823346449794,0.009081912745616772,0.009094620100080561,0.009590833933385699,0.009915045162705392,0.010340485757759216,0.01279302126127538,0.01342122767154084,0.015027330945804197,0.017472214744206998,0.022176722720511056,0.02698480533575054,0.028402259124835492,0.04106119182246612,0.04864169895652069],"y":["vladimir  ","forces  ","like  ","europe  ","defense  ","drones  ","missile  ","countries  ","zelensky  ","nuclear  ","russians  ","military  ","missiles  ","weapons  ","ukrainian  ","nato  ","putin  ","russian  ","russia  ","ukraine  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.025575764984875606,0.02562632281904101,0.026058116759577466,0.02931849557669994,0.02970365147770314,0.03087984365162667,0.031146168278595773,0.034101678758046726,0.03774987590802663,0.03787156418513646,0.038476757475936915,0.04430065253040999,0.054750722007341025,0.056735164582853576,0.06374452993056988,0.07097054353809323,0.07333555863846802,0.08342396490525365,0.09017825015862672,0.1029433133996352],"y":["claiming  ","thanks  ","following  ","successfully  ","steps  ","migrated  ","airdrop  ","contract  ","mate  ","instructions  ","rewards  ","tokens  ","reward  ","claim  ","message  ","token  ","migrate  ","wallet  ","pinned  ","migration  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012747296753064163,0.013102984666037994,0.013167936561147914,0.0137672305749727,0.013893338021229678,0.013976868088551758,0.014421169345659434,0.014617264540596328,0.014658679715103455,0.01508890313847935,0.016890947361240357,0.01737060240115272,0.017428178992810357,0.01820079781626868,0.0190120457328857,0.020282920834940172,0.02088432471865436,0.0299985490757894,0.03334936285343818,0.03338696042889866],"y":["costs  ","rate  ","business  ","tariffs  ","economy  ","groceries  ","manufacturing  ","americans  ","average  ","jobs  ","harris  ","trump  ","american  ","energy  ","taxes  ","president  ","cost  ","kamala  ","prices  ","inflation  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008408428929883808,0.008452183090676354,0.008563203012532501,0.008595644529611824,0.008925540037712154,0.009110517680697282,0.009817557448707215,0.010651897812154766,0.01158796603335993,0.011736941817359426,0.011785814531428464,0.0119325325468605,0.01204338720728878,0.013009134248612799,0.01421758432023863,0.014627239995240784,0.015418669469619423,0.019401024306218328,0.038122332196443245,0.06081737804661008],"y":["installed  ","running  ","interviews  ","record  ","vote  ","policy  ","vice  ","democrat  ","conference  ","president  ","campaign  ","single  ","hasn  ","questions  ","press  ","nominee  ","walz  ","interview  ","harris  ","kamala  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.005907017439096928,0.006466653175628542,0.006661300065951612,0.007173654266337871,0.00749645239335095,0.007643936622183069,0.007665570860005846,0.007966106700536942,0.008362981766593516,0.009193216732651041,0.009620763323932493,0.009840484747722105,0.010233343998880009,0.010782160642189544,0.011607717381269969,0.011689526385301857,0.012844094538352255,0.013060263284078813,0.021334923436822407,0.032497402195 ...

# %%
#SILHOUETTE

texts = df_sampled['text_preprocessed']
timestamps = pd.to_datetime(df_sampled['timestamp'], unit='s').dt.date
timestamps = pd.to_datetime(timestamps)

topics_over_time = topic_models['silhouette'].topics_over_time(
    docs=list(texts),
    timestamps=list(timestamps),
    nr_bins = 52,
    global_tuning = False,
    evolution_tuning = True)

topic_model.visualize_topics_over_time(
    topics_over_time,
    top_n_topics=-1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1cdd0132-2c11-493e-9d66-8deeec74ae9a" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1cdd0132-2c11-493e-9d66-8deeec74ae9a")) {                    Plotly.newPlot(                        "1cdd0132-2c11-493e-9d66-8deeec74ae9a",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tapes, keeping, promise, january, available","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rodney, hydegreenwashed, favourite, hyde, solomon","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: chased, columbia, hillary, university, students","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: photographer, wreaks, photographers, approve, liberals","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rawhiti, zealandyoungest, maipi, maiden, clarke","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: handouts, running, nomination, boeing, tough","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: charging, dubby, stooges, presser, journalism","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: guns, comments, stances, moms, addressed","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: minenkov, surmised, plow, formula, woman","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cancel, crapped, tits, perigo, crab","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hilary, dead, clinton, half, bill","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mitch, mcconnell, endorse, refuses, announcement","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: sitting, concerts, shaming, incorrect, madonna","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: drag, invited, queen, shangela, accused","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: clapping, claps, unknowingly, sang, lizzo","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: alesandro, nancy, pelosi, irony, baltimore","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: agla, bewada, bolne, certifies, kejri","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: bidenpress, hatch, kangaroo, hysterical, charlie","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: affirmative, decison, pander, adoration, segregationists","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: venomous, paagal, puechased, medias, broadcasting","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: reactors, nuclear, needs, ninety, vogtle","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: outlet, chism, veritable, watchers, madonna","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rules, invites, staged, queer, debates","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: alexis, shocked, trmp, nungaray, jocelyn","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: cuomo, appointed, andrew, kathy, hochul","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: weaponize, locker, kamala, usual, falsely","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rudy, fiserv, ridicolous, ponzu, translator","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: kamala, harris, czar, biden, nominee","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: kamala, harris, liberal, official, dems","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: kamala, harris, nominee, ticket, questions","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: kamala, harris, debates, sept, interview","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: kamala, harris, howell, convention, spox","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003c ...

# %%
topic_models['silhouette'].get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1  13301                 -1_like_join_trump_people
# 1       0    887          0_kamala_harris_debate_president
# 2       1    632                  1_judge_case_court_trial
# 3       2    568               2_gaza_hamas_israel_israeli
# 4       3    555            3_ukraine_russia_russian_putin
# ..    ...    ...                                       ...
# 90     89     54               89_share_join_dots_showtime
# 91     90     53              90_israel_peace_jewish_trump
# 92     91     53  91_visibility_jesus_christian_christians
# 93     92     51           92_hunter_biden_committee_comer
# 94     93     50              93_nesara_gesara_join_coming
#
#                                        Representation  \
# 0   [like, join, trump, people, president, know, w...
# 1   [kamala, harris, debate, president, biden, tru...
# 2   [judge, case, court, trial, smith, trump, supr...
# 3   [gaza, hamas, israel, israeli, hostages, pales...
# 4   [ukraine, russia, russian, putin, ukrainian, n...
# ..                                                ...
# 90  [share, join, dots, showtime, able, decoding, ...
# 91  [israel, peace, jewish, trump, president, reco...
# 92  [visibility, jesus, christian, christians, eas...
# 93  [hunter, biden, committee, comer, james, garla...
# 94  [nesara, gesara, join, coming, govtreduced, sh...
#
#                                   Representative_Docs
# 0   [couldn risk worked hard deleted posted eviden...
# 1   [hands president trump debate policy able answ...
# 2   [judge overseeing donald trumpclassified docum...
# 3   [israel gaza latest updated defense forces say...
# 4   [kamala harris explains ukraine russia conflic...
# ..                                                ...
# 90  [attention security reasons evidence safe time...
# 91  [president trump leadership america stand shou...
# 92  [boom trump declares november called christian...
# 93  [according house oversight chair james comer s...
# 94  [truth real return ready join nesara gesara, t...
#
# [95 rows x 5 columns]

# %%
topic_models['silhouette'].get_topic_info().set_index('Topic').loc[1,'Representative_Docs']
# Out:
# ['judge overseeing donald trumpclassified documents case unusual step hearing arguments special counsel jack smith removed prosecution connected proceedings legal expert said federal prosecutor joyce vance remark judge aileen cannon writing blog upcoming legal proceedings involving president allies friday june cannon hear arguments people involved federal case claim smith unlawfully appointed attorney general merrick garland approved senate rare hear outside parties previously criticized legal experts cannon federal classified documents trial indefinite hold rules number hearings motions dismiss connected case read',
#  'president trump said case today judge allowing supreme court presidential immunity',
#  'breaking judge merchan delays trumpsentencing september following scotus presidential immunity ruling left judge juan merchan delayed president trump hush money sentencing september earlier tuesday alvin braggoffice agreed delay trumpsentencing july supreme court decided presidential immunity president trump monday sought overturn hush money conviction supreme court ruled presidential immunity official acts trump accused paying porn star stormy daniels stephanie clifford hush payments attorney michael cohen scheme silence stop story alleged affair published national enquirer payments internal business records deduction taken obligation file according trump attorney tacopina bragg alleged trump committed fraud payment labeled legal fees president trump found guilty felony counts manhattan alvin bragg hush money lawfare trial president trumplawyers argued alvin braggcase built trumptime white house supreme courtruling immunity means prosecutors cite evidence judge merchan said issue ruling related presidential immunity argument september news reported judge donald trumpnew york criminal trial tuesday approved delay presidentsentencing lawyers asked time review potential impact supreme courtimmunity decision trumplawyers indicated want judge juan merchan toss trumpfelony conviction counts falsified business records related hush money payments adult film star stormy daniels hearing previously scheduled july delayed september trumpteam monday sent letter merchan asking brief supreme courtmonday ruling said president immunity prosecution related official acts president ruling blow prosecutors trumpfederal election interference case exactly clear affect criminal cases follow share']

# %%
df_sampled['topic']=topic_models['silhouette'].topics_

# %%
#COHERERENCE

texts = df_sampled['text_preprocessed']
timestamps = pd.to_datetime(df_sampled['timestamp'], unit='s').dt.date
timestamps = pd.to_datetime(timestamps)

topics_over_time = topic_models['coherence'].topics_over_time(
    docs=list(texts),
    timestamps=list(timestamps),
    nr_bins = 52,
    global_tuning = False,
    evolution_tuning = True)

topic_model.visualize_topics_over_time(
    topics_over_time,
    top_n_topics=-1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="dd4fe31c-6379-4112-a287-cafdcbf5dc16" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dd4fe31c-6379-4112-a287-cafdcbf5dc16")) {                    Plotly.newPlot(                        "dd4fe31c-6379-4112-a287-cafdcbf5dc16",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ants, missiles, base, aids, accurate","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ronna, realize, mediaite, corporatists, chiefresignation","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: rapaport, picture, smokin, thigh, desanctus","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: psyop, desantis, ethereal, blooming, trumpgoals","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: gadgets, trumptwitter, retweeted, dinesh, souza","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mackey, watching, regimetargeting, keks, douglass","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: dictator, drill, wanna, bidenplastic, hegel","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: obamaright, insidious, bush, argentina, shadow","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: dems, weaponization, pimped, trumpfuture, oblige","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: sight, convulsions, connotation, jrresponse, assasinated","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: plain, obama, atac, pied, workings","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: vivek, swampy, ramaswamy, hampshire, accomplishes","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: king, finances, rhino, nothingness, strickland","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: snoop, dogg, carroll, punisher, maher","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: brics, yearsummit, mustache, apex, nato","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ludwig, connecticut, waynedaughter, aissa, dunham","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: bust, pohlhaus, bidenbetter, baited, trumpexoneration","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: fractional, display, scaling, ubuntu, revenge","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: fining, wanking, mastodon, forgot, grateful","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: incomming, fema, yelling, tribute, hammer","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: shadow, sedewc, tinyurl, letimagine, swamp","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: gambling, mars, bruno, entity, media","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: treatment, special, senile, speeches, bond","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: trumpdeclaration, doomers, narendra, sabha, solving","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: aftershock, quake, rocked, magnitude, rogan","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: mayhem, abomination, taiwan, salesman, stoke","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: woodward, nixon, richard, waving, naval","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: eminem, anons, storm, floodgates, tougher","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: roast, netflix, dana, machine, weeks","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: packages, fedex, travesty, maher, york","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: staging, barron, lunges, rockerfeller, thletter","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: deceiving, peterson, fuckin, peace, backhanded ...

# %%
topic_models['coherence'].get_topic_info()
# Out:
#      Topic  Count                                        Name  \
# 0       -1  10769               -1_people_like_president_join
# 1        0    698              0_trump_donald_president_going
# 2        1    652             1_prices_inflation_kamala_taxes
# 3        2    577              2_kamala_harris_walz_interview
# 4        3    574              3_ukraine_russia_putin_russian
# ..     ...    ...                                         ...
# 273    272     15       272_spending_cuts_increases_increased
# 274    273     15  273_businesses_small_applications_business
# 275    274     15       274_swatting_azzarello_bullet_fascist
# 276    275     15              275_allahu_akbar_auckland_illa
# 277    276     15     276_documentary_bixler_masterson_linkin
#
#                                         Representation  \
# 0    [people, like, president, join, world, trump, ...
# 1    [trump, donald, president, going, country, med...
# 2    [prices, inflation, kamala, taxes, cost, energ...
# 3    [kamala, harris, walz, interview, nominee, pre...
# 4    [ukraine, russia, putin, russian, nato, ukrain...
# ..                                                 ...
# 273  [spending, cuts, increases, increased, debt, t...
# 274  [businesses, small, applications, business, st...
# 275  [swatting, azzarello, bullet, fascist, bloodst...
# 276  [allahu, akbar, auckland, illa, ashhadu, ilaha...
# 277  [documentary, bixler, masterson, linkin, mins,...
#
#                                    Representative_Docs
# 0    [nearly decade government hapu length aotearoa...
# 1    [trump media hoaxes media claimed trump called...
# 2    [inflation insists fake news inflation straigh...
# 3    [kamala hasn single interview press conference...
# 4    [kamala harris explains ukraine russia conflic...
# ..                                                 ...
# 273  [reference money government wastes excess insu...
# 274  [president biden americans filed record millio...
# 275  [incidents bigger trend swatting cases general...
# 276  [like auckland lads personally remember time w...
# 277  [guido reports speculation rife long starmer l...
#
# [278 rows x 5 columns]

# %%
topic_models['coherence'].get_topic_info().set_index('Topic').loc[1,'Representative_Docs']
# Out:
# ['inflation insists fake news inflation straight months overall prices kamala prices higher kamala took office',
#  'pennsylvania electricity prices kamala took office president trump energy prices half months',
#  'today kamala harris join mentor crooked biden deliver labor message americans things mess responsible means costs overall prices harris biden prices overall transportation costs overall grocery prices inflation harris biden americans subjected longest period high inflation decades costing average family extra paying increased cost living aided kamalasupport breaking votes inflation accelerating trillion spending incomes savings americans earning power hasn kept real average weekly earnings kamala americans personal savings nearly trillion wiped middle class lost trillion march average middle class household losing view original post']

# %%
df_sampled['topic']=topic_models['coherence'].topics_

# %%
#DIVERSITY

texts = df_sampled['text_preprocessed']
timestamps = pd.to_datetime(df_sampled['timestamp'], unit='s').dt.date
timestamps = pd.to_datetime(timestamps)

topics_over_time = topic_models['diversity'].topics_over_time(
    docs=list(texts),
    timestamps=list(timestamps),
    nr_bins = 52,
    global_tuning = False,
    evolution_tuning = True)

topic_model.visualize_topics_over_time(
    topics_over_time,
    top_n_topics=-1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="07bdaede-279c-4bf9-b46e-df8efde148b3" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("07bdaede-279c-4bf9-b46e-df8efde148b3")) {                    Plotly.newPlot(                        "07bdaede-279c-4bf9-b46e-df8efde148b3",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: gifted, allah, patience, gift, faster","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: hopefully, managed, nice, guess, sent","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: diversity, concerned, gender, wing, migrant","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tribunes, partaking, advert, levy, voluntarily","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: iupiter, meme, page, successful, admin","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: alcp, offset, incorrect, transfer, learned","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ages, blocked, posts, guess, account","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: giveaway, participate, reward, contracts, amaizing","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: pione, bonuses, bribes, collect, guess","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: giveaway, platfrom, staking, revenue, tokens","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: defi, staking, wallet, developers, reward","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: felicitations, prez, relief, congratulations, students","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: airdrop, tensor, functionality, marketplace, solana","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: reward, claiming, claim, wallet, pinned","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: developer, apply, blockchain, frontend, contact","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: gettinjg, thanking, promotion, collect, giveaway","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: collect, cheating, memes, saved, phone","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ledger, manually, claimed, claim, holders","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, migrate, pinned, token, message","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migrate, pinned, mate, token, migration","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, pinned, migrate, wallet, tokens","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migrate, wallet, migration, metamask, token","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: reward, claim, pinned, token, wallet","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, pinned, migrate, message, token","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, pinned, wallet, token, message","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: reward, rewards, claim, claiming, wallet","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, contract, pinned, migrate, smart","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: migration, rewards, reward, wallet, pinned","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wallet, claim, pinned, reward, migration","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: wallet, airdrop, rewards, reward, claim","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: paywall, allows, breaks, cunts, email","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: empirebot, heroplay, letposted, startapp, startup","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: disb ...

# %%
topic_models['diversity'].get_topic_info()
# Out:
#      Topic  Count                                           Name  \
# 0       -1  11612                 -1_trump_people_president_like
# 1        0    663              0_migration_pinned_wallet_migrate
# 2        1    585                   1_crypto_bitcoin_faster_elon
# 3        2    549                 2_prices_inflation_kamala_cost
# 4        3    534              3_kamala_harris_interview_nominee
# ..     ...    ...                                            ...
# 289    288     16  288_assassination_attempt_surviving_guardsman
# 290    289     15                    289_fani_willis_wade_fulton
# 291    290     15              290_sinkhole_moreno_wife_dressage
# 292    291     15             291_veterans_hotels_illegal_luxury
# 293    292     15         292_arps_rights_expression_intolerance
#
#                                         Representation  \
# 0    [trump, people, president, like, join, world, ...
# 1    [migration, pinned, wallet, migrate, token, me...
# 2    [crypto, bitcoin, faster, elon, musk, playing,...
# 3    [prices, inflation, kamala, cost, taxes, energ...
# 4    [kamala, harris, interview, nominee, press, qu...
# ..                                                 ...
# 289  [assassination, attempt, surviving, guardsman,...
# 290  [fani, willis, wade, fulton, nathan, county, a...
# 291  [sinkhole, moreno, wife, dressage, hobbyhorsin...
# 292  [veterans, hotels, illegal, luxury, aliens, sq...
# 293  [arps, rights, expression, intolerance, senten...
#
#                                    Representative_Docs
# 0    [important update message real patriots love c...
# 1    [mate proceed claim read pinned message follow...
# 2    [bitcoin etfs bleeding outflows faster leaky s...
# 3    [kamala white house years says lower cost livi...
# 4    [kamala time world stage photo democrat suppor...
# ..                                                 ...
# 289  [president trump recounts assassination attemp...
# 290  [breaking georgia house commission powers disc...
# 291  [tiktok horse girl competes hobbyhorsing slamm...
# 292  [kicking veterans hotels house immigrants brok...
# 293  [valid concern critics argue applying laws int...
#
# [294 rows x 5 columns]

# %%
topic_models['diversity'].get_topic_info().set_index('Topic').loc[1,'Representative_Docs']
# Out:
# ['bitcoin etfs bleeding outflows faster leaky spaceship tether usdc slash fees like crypto clearance sale ukraine halts russian offensive binance gives boot vitalikthrowing ltokens like confetti blockchain party',
#  'breaking news white house turns orange code bitcoin bigger ncswic white house turned completely orange shocking transformation ignited speculation globe color change hidden message connected bitcoin convinced signals trumptriumphant return white house turning orange mean news broke instantly world started buzzing iconic white house symbol american leadership glows orange sign bigger analysts scrambling answers trump supporters message clear trump dubbed orange sending signal comeback imminent timing perfect coincidence sudden shift color reignited trust plan mantra patriots phrase long echoed circles reassures faithful unfolding planned stop ncswic bitcoin hidden code orange believe transformation white house coded message bitcoin enthusiasts color orange synonymous bitcoin branding speculating signal massive price surge horizon white house tipping financial elite crypto boom bitcoin prices known wild fluctuations theory gained traction know urging investors attention huge pump corner orange glow aesthetic signal decode stand gain trumporange revolution return orange donald trump influence waned white house bathed orange return certain trump linked color orange distinctive appearance fiery bold personality white house reflects aura social media trumpsupporters rallying orange trump incoming excitement palpable base convinced final piece puzzle trump power orange glow color warning shot deep state days numbered ncswic stop coming ncswic final countdown know phrase stop coming rallying patriot movement white house turning orange seen grand plan visible time action near exactly coming speculate trumpreturn political power global shift leadership finance society white housenew color clearest sign revolution begun orange color revolution energy change coincidence seeing color bathe halls power like orange revolution ukraine brought corrupt regime orange transformation marks beginning revolutionary america trumpcomeback bitcoin boom bigger play patriots prepared signs deep state running scared plan unfolding eyes world soon know preparing white house turning orange start hold tight ride wild join share support channel',
#  'ethereum bitcoin etfs bleeding cash faster leaky faucet muskx faces brazilian court showdown russian strikes ukonline safety german cyberattack making world news circuit look like disaster movie crypto whales hoarding bitcoin like going style binance cozying coinoh forget respect forehead folks']

# %%
df_sampled['topic']=topic_models['diversity'].topics_

# %%
#AVG_SCORE

texts = df_sampled['text_preprocessed']
timestamps = pd.to_datetime(df_sampled['timestamp'], unit='s').dt.date
timestamps = pd.to_datetime(timestamps)

topics_over_time = topic_models['avg_score'].topics_over_time(
    docs=list(texts),
    timestamps=list(timestamps),
    nr_bins = 52,
    global_tuning = False,
    evolution_tuning = True)

topic_model.visualize_topics_over_time(
    topics_over_time,
    top_n_topics=-1)

# %%
topic_models['avg_score'].get_topic_info()

# %%
topic_models['avg_score'].get_topic_info().set_index('Topic').loc[1,'Representative_Docs']

# %%
df_sampled['topic']=topic_models['avg_score'].topics_
