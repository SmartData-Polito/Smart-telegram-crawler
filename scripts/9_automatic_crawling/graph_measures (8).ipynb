# %% [markdown]
# # Misure rilevanti su un grafo diretto con NetworkX
#
# Questo notebook mostra **solo le misure più utili** per analizzare un **grafo diretto** costruito da una *edge list* e indica **quando una misura è dispendiosa** per grafi grandi.
#
# > **Nota:** per grafi molto grandi, alcune misure basate su cammini minimi o enumerazione di cicli possono diventare impraticabili.

# %% [markdown]
# ## 0) Setup e costruzione del grafo
#
# Assumiamo di avere una lista di archi orientati:
#
# - `edges = [(u1, v1), (u2, v2), ...]`
#
# Sostituisci/leggi i dati nel modo che preferisci (CSV, JSON, ecc.).

# %%
# =============================================
# FULL COMPUTATION: FILTER ALL CHANNELS BY ENGLISH MESSAGES
# =============================================
# This cell processes ALL 1.1M channels to find which have >= 10 English messages.
# Takes 2-4+ hours the FIRST time, then saves cache for fast reload.
#
# What it does:
# 1. Load all edges from TGDataset
# 2. For each channel: count English messages (FastText)
# 3. Keep only channels with >= 10 English messages
# 4. Filter edges: keep only where BOTH source AND target are valid
# 5. Save cache files for future fast loading

import pandas as pd
import networkx as nx
import json
import os
import fasttext
from tqdm import tqdm
from collections import defaultdict

# ============================================================
# CONFIGURATION
# ============================================================
EDGES_FILE = '../../material/tgdataset_edges.csv.gz'                    # Input: all edges
FILTERED_EDGES_FILE = '../../material/tgdataset_edges_filtered.csv.gz'  # Output: filtered edges
VALID_CHANNELS_CACHE = '../../material/valid_channels_cache.json'       # Output: cache
EXTRACTED_DIR = '../../material/TGDataset_extracted/public_db'          # TGDataset JSON files
FASTTEXT_MODEL_PATH = '../../material/lid.176.bin'                      # FastText model
CHANNEL_MAPPING_FILE = '../../material/channel_file_mapping.json'       # Channel to file mapping

MIN_MESSAGE_LENGTH = 15      # Minimum characters per message
MIN_CHANNEL_MESSAGES = 10    # Minimum English messages per channel
LANG_CONFIDENCE = 0.5        # Minimum confidence for English detection

# ============================================================
# CHECK IF ALREADY COMPUTED
# ============================================================
if os.path.exists(FILTERED_EDGES_FILE) and os.path.exists(VALID_CHANNELS_CACHE):
    print("="*60)
    print("CACHE FILES ALREADY EXIST - LOADING...")
    print("="*60)
    
    # Load filtered edges
    edges_df = pd.read_csv(FILTERED_EDGES_FILE, compression='gzip')
    G = nx.DiGraph()
    G.add_edges_from(zip(edges_df['source'], edges_df['target']))
    
    # Load cache
    with open(VALID_CHANNELS_CACHE, 'r') as f:
        cache_data = json.load(f)
    
    valid_channels = set(cache_data['valid_channel_ids'])
    channel_english_count = {int(k): v for k, v in cache_data['channel_english_count'].items()}
    
    print(f"  Edges: {len(edges_df):,}")
    print(f"  Nodes: {G.number_of_nodes():,}")
    print(f"  Valid channels: {len(valid_channels):,}")

else:
    print("="*60)
    print("COMPUTING FROM SCRATCH (this takes 2-4+ hours)")
    print("="*60)
    
    # ============================================================
    # STEP 1: Load all edges and get unique channel IDs
    # ============================================================
    print("\n[1/5] Loading all edges...")
    edges_df_original = pd.read_csv(EDGES_FILE, compression='gzip')
    all_channel_ids = set(edges_df_original['source']) | set(edges_df_original['target'])
    print(f"  Total edges: {len(edges_df_original):,}")
    print(f"  Unique channels: {len(all_channel_ids):,}")
    
    # ============================================================
    # STEP 2: Load FastText model
    # ============================================================
    print("\n[2/5] Loading FastText model...")
    if not os.path.exists(FASTTEXT_MODEL_PATH):
        print("  Downloading FastText model...")
        import urllib.request
        url = "https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin"
        urllib.request.urlretrieve(url, FASTTEXT_MODEL_PATH)
    
    fasttext.FastText.eprint = lambda x: None  # Suppress warnings
    ft_model = fasttext.load_model(FASTTEXT_MODEL_PATH)
    print("  FastText model loaded")
    
    # ============================================================
    # STEP 3: Load channel to file mapping
    # ============================================================
    print("\n[3/5] Loading channel mapping...")
    with open(CHANNEL_MAPPING_FILE, 'r') as f:
        channel_mapping = json.load(f)
    print(f"  Channels in mapping: {len(channel_mapping):,}")
    
    # Group channels by file for efficient reading
    # Example: by_file = {'public_db/folder_0/file_1.json': ['123', '456', ...], ...}
    by_file = defaultdict(list)
    channels_not_in_mapping = 0
    
    for ch_id in all_channel_ids:
        ch_str = str(int(ch_id))  # Ensure string format
        if ch_str in channel_mapping:
            file_path = channel_mapping[ch_str]['file']
            by_file[file_path].append(ch_str)
        else:
            channels_not_in_mapping += 1
    
    print(f"  Files to process: {len(by_file):,}")
    print(f"  Channels not in mapping: {channels_not_in_mapping:,}")
    
    # ============================================================
    # STEP 4: Count English messages for each channel
    # ============================================================
    print("\n[4/5] Counting English messages per channel...")
    print("  This is the slow part - processing all JSON files...")
    
    # channel_english_count = {channel_id: count_of_english_messages}
    channel_english_count = {}
    
    for file_path, ch_ids_in_file in tqdm(by_file.items(), desc="  Processing files"):
        full_path = f"{EXTRACTED_DIR.replace('/public_db', '')}/{file_path}"
        
        try:
            with open(full_path, 'r') as f:
                data = json.load(f)
            
            for ch_str in ch_ids_in_file:
                if ch_str in data:
                    channel_data = data[ch_str]
                    text_messages = channel_data.get('text_messages', {})
                    
                    # Count English messages
                    english_count = 0
                    for msg in text_messages.values():
                        msg_text = msg.get('message', '')
                        
                        # Filter: minimum length
                        if not msg_text or len(msg_text) < MIN_MESSAGE_LENGTH:
                            continue
                        
                        # Detect language
                        text_clean = msg_text.replace('\n', ' ').strip()
                        try:
                            predictions = ft_model.predict(text_clean, k=1)
                            lang = predictions[0][0].replace('__label__', '')
                            conf = predictions[1][0]
                            
                            if lang == 'en' and conf > LANG_CONFIDENCE:
                                english_count += 1
                        except:
                            pass
                    
                    channel_english_count[int(ch_str)] = english_count
                else:
                    # Channel not found in file
                    channel_english_count[int(ch_str)] = 0
                    
        except Exception as e:
            # File read error - mark all channels as 0
            for ch_str in ch_ids_in_file:
                channel_english_count[int(ch_str)] = 0
    
    # Channels not in mapping get 0
    for ch_id in all_channel_ids:
        ch_int = int(ch_id)
        if ch_int not in channel_english_count:
            channel_english_count[ch_int] = 0
    
    print(f"  Processed {len(channel_english_count):,} channels")
    
    # ============================================================
    # STEP 5: Filter channels and edges
    # ============================================================
    print("\n[5/5] Filtering channels and edges...")
    
    # Valid channels: those with >= MIN_CHANNEL_MESSAGES English messages
    valid_channels = {ch for ch, count in channel_english_count.items() 
                      if count >= MIN_CHANNEL_MESSAGES}
    print(f"  Valid channels (>= {MIN_CHANNEL_MESSAGES} English msgs): {len(valid_channels):,}")
    print(f"  Excluded channels: {len(channel_english_count) - len(valid_channels):,}")
    
    # Filter edges: keep only where BOTH source AND target are valid
    mask = (edges_df_original['source'].isin(valid_channels) & 
            edges_df_original['target'].isin(valid_channels))
    edges_df = edges_df_original[mask].copy()
    print(f"  Original edges: {len(edges_df_original):,}")
    print(f"  Filtered edges: {len(edges_df):,}")
    
    # Build filtered graph
    G = nx.DiGraph()
    G.add_edges_from(zip(edges_df['source'], edges_df['target']))
    print(f"  Filtered nodes: {G.number_of_nodes():,}")
    
    # ============================================================
    # SAVE CACHE FILES
    # ============================================================
    print("\nSaving cache files...")
    
    # Save filtered edges
    edges_df.to_csv(FILTERED_EDGES_FILE, index=False, compression='gzip')
    print(f"  Saved: {FILTERED_EDGES_FILE}")
    
    # Save valid channels cache
    cache_data = {
        'min_message_length': MIN_MESSAGE_LENGTH,
        'min_channel_messages': MIN_CHANNEL_MESSAGES,
        'lang_confidence': LANG_CONFIDENCE,
        'total_channels_processed': len(channel_english_count),
        'valid_channel_ids': list(valid_channels),
        'channel_english_count': {str(k): v for k, v in channel_english_count.items()}
    }
    
    with open(VALID_CHANNELS_CACHE, 'w') as f:
        json.dump(cache_data, f)
    print(f"  Saved: {VALID_CHANNELS_CACHE}")
    
    print("\n" + "="*60)
    print("COMPUTATION COMPLETE!")
    print("="*60)

# ============================================================
# FINAL SUMMARY
# ============================================================
print(f"\n{'='*60}")
print("FILTERED GRAPH READY")
print(f"{'='*60}")
print(f"  Nodes: {G.number_of_nodes():,}")
print(f"  Edges: {G.number_of_edges():,}")
print(f"  Valid channels: {len(valid_channels):,}")
print(f"  Density: {nx.density(G):.6f}")
# Out:
# ============================================================
# CACHE FILES ALREADY EXIST - LOADING...
# ============================================================
#   Edges: 2,099,813
#   Nodes: 48,630
#   Valid channels: 49,122
#
# ============================================================
# FILTERED GRAPH READY
# ============================================================
#   Nodes: 48,630
#   Edges: 2,099,813
#   Valid channels: 49,122
#   Density: 0.000888

# %% [markdown]
# ## 1) Dimensione e densità (sempre fattibili)
#
# - **Numero di nodi**: `G.number_of_nodes()`
# - **Numero di archi**: `G.number_of_edges()`
# - **Densità**: `nx.density(G)`
#
# **Costo:** ~O(1)

# %%
n = G.number_of_nodes()
m = G.number_of_edges()
dens = nx.density(G)

n, m, dens
# Out:
# (48630, 2099813, 0.0008879346659704809)

# %% [markdown]
# ## 2) In-degree e out-degree (fondamentali)
#
# - **In-degree**: numero di archi entranti
# - **Out-degree**: numero di archi uscenti
#
# **Costo:** ~O(|E|) (scala bene anche su grafi grandi)

# %%
in_deg  = dict(G.in_degree())
out_deg = dict(G.out_degree())

# Top-10 per in-degree / out-degree
top_in  = sorted(in_deg.items(),  key=lambda x: x[1], reverse=True)[:10]
top_out = sorted(out_deg.items(), key=lambda x: x[1], reverse=True)[:10]

top_in, top_out
# Out:
# ([(1335904171, 926),
#   (1160507923, 843),
#   (1368365091, 773),
#   (1379886235, 771),
#   (1365860979, 746),
#   (1367422246, 707),
#   (1475145200, 707),
#   (1442233413, 701),
#   (1279459175, 697),
#   (1474120050, 696)],
#  [(1179270258, 4347),
#   (1479163323, 3723),
#   (1136479756, 2837),
#   (1387645188, 2813),
#   (1459035940, 2635),
#   (1417136285, 2457),
#   (1200497997, 2257),
#   (1390659157, 2183),
#   (1225790696, 2153),
#   (1335927003, 2126)])

# %%
import matplotlib.pyplot as plt
import numpy as np

# =============================================
# PLOT IN-DEGREE DISTRIBUTION (log-log)
# =============================================
in_values = list(in_deg.values())
out_values = list(out_deg.values())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# In-degree histogram con bin logaritmici
in_values_nonzero = [v for v in in_values if v > 0]
bins_in = np.logspace(0, np.log10(max(in_values_nonzero)), 50)
axes[0].hist(in_values_nonzero, bins=bins_in, edgecolor='black', alpha=0.7)
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel('In-degree')
axes[0].set_ylabel('Number of nodes')
axes[0].set_title('In-degree distribution(log-log)')
axes[0].grid(True, alpha=0.3)

# Out-degree histogram con bin logaritmici
out_values_nonzero = [v for v in out_values if v > 0]
bins_out = np.logspace(0, np.log10(max(out_values_nonzero)), 50)
axes[1].hist(out_values_nonzero, bins=bins_out, edgecolor='black', alpha=0.7, color='orange')
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlabel('Out-degree')
axes[1].set_ylabel('Number of nodes')
axes[1].set_title('Out-degree distribution(log-log)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('degree_distribution_loglog.png', dpi=150)
plt.show()

# =============================================
# STATISTICHE: Frazioni di nodi per soglie
# =============================================
n_nodes = len(in_deg)

print("=" * 60)
print("STATISTICHE IN-DEGREE")
print("=" * 60)
print(f"Nodi con in-degree = 0:   {sum(1 for v in in_values if v == 0):,} ({100*sum(1 for v in in_values if v == 0)/n_nodes:.1f}%)")
print(f"Nodi con in-degree < 10:  {sum(1 for v in in_values if v < 10):,} ({100*sum(1 for v in in_values if v < 10)/n_nodes:.1f}%)")
print(f"Nodi con in-degree < 100: {sum(1 for v in in_values if v < 100):,} ({100*sum(1 for v in in_values if v < 100)/n_nodes:.1f}%)")
print(f"Nodi con in-degree >= 100: {sum(1 for v in in_values if v >= 100):,} ({100*sum(1 for v in in_values if v >= 100)/n_nodes:.1f}%)")

print("\n" + "=" * 60)
print("STATISTICHE OUT-DEGREE")
print("=" * 60)
print(f"Nodi con out-degree = 0:   {sum(1 for v in out_values if v == 0):,} ({100*sum(1 for v in out_values if v == 0)/n_nodes:.1f}%)")
print(f"Nodi con out-degree < 10:  {sum(1 for v in out_values if v < 10):,} ({100*sum(1 for v in out_values if v < 10)/n_nodes:.1f}%)")
print(f"Nodi con out-degree < 100: {sum(1 for v in out_values if v < 100):,} ({100*sum(1 for v in out_values if v < 100)/n_nodes:.1f}%)")
print(f"Nodi con out-degree >= 100: {sum(1 for v in out_values if v >= 100):,} ({100*sum(1 for v in out_values if v >= 100)/n_nodes:.1f}%)")
# Out:
# ============================================================
# STATISTICHE IN-DEGREE
# ============================================================
# Nodi con in-degree = 0:   5,161 (10.6%)
# Nodi con in-degree < 10:  24,769 (50.9%)
# Nodi con in-degree < 100: 43,150 (88.7%)
# Nodi con in-degree >= 100: 5,480 (11.3%)
#
# ============================================================
# STATISTICHE OUT-DEGREE
# ============================================================
# Nodi con out-degree = 0:   1,100 (2.3%)
# Nodi con out-degree < 10:  25,956 (53.4%)
# Nodi con out-degree < 100: 44,283 (91.1%)
# Nodi con out-degree >= 100: 4,347 (8.9%)

# %% [markdown]
# ### Centralità di grado (normalizzata)
#
# - `nx.in_degree_centrality(G)`
# - `nx.out_degree_centrality(G)`
#
# **Costo:** ~O(|E|)

# %%
in_deg_cent  = nx.in_degree_centrality(G)
out_deg_cent = nx.out_degree_centrality(G)

# Top-10
sorted(in_deg_cent.items(), key=lambda x: x[1], reverse=True)[:10], sorted(out_deg_cent.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# ([(1335904171, 0.019042135351333565),
#   (1160507923, 0.017335334882477533),
#   (1368365091, 0.01589586460753871),
#   (1379886235, 0.0158547368853976),
#   (1365860979, 0.015340640358633736),
#   (1367422246, 0.014538649776882106),
#   (1475145200, 0.014538649776882106),
#   (1442233413, 0.01441526661045878),
#   (1279459175, 0.014333011166176562),
#   (1474120050, 0.014312447305106007)],
#  [(1179270258, 0.08939110407370088),
#   (1479163323, 0.0765592547656748),
#   (1136479756, 0.05833967385716342),
#   (1387645188, 0.05784614119147011),
#   (1459035940, 0.05418577392091139),
#   (1417136285, 0.05052540665035267),
#   (1200497997, 0.046412634436241745),
#   (1390659157, 0.04489090871702071),
#   (1225790696, 0.04427399288490407),
#   (1335927003, 0.04371876863599909)])

# %% [markdown]
# ## 3) Componenti connesse (molto importanti)
#
# Nei grafi diretti si usa spesso:
#
# - **SCC** (*Strongly Connected Components*): nodi mutuamente raggiungibili seguendo le direzioni.
# - **WCC** (*Weakly Connected Components*): connettività ignorando l'orientamento.
#
# **Costo:** ~O(|V| + |E|) (fattibile anche su grafi grandi)

# %%
scc = list(nx.strongly_connected_components(G))
wcc = list(nx.weakly_connected_components(G))

num_scc = len(scc)
num_wcc = len(wcc)

largest_scc = max(scc, key=len)
largest_wcc = max(wcc, key=len)

num_scc, len(largest_scc), num_wcc, len(largest_wcc)
# Out:
# (11622, 36386, 384, 48222)

# %%
# =============================================
# DETAILED CONNECTED COMPONENTS ANALYSIS
# =============================================
# This block analyzes WCC (Weakly Connected Components) and SCC (Strongly Connected Components)
# to understand the graph structure and implications for the crawler.
# - WCC: groups of nodes reachable ignoring edge direction
# - SCC: groups where EVERY node can reach EVERY other following edge directions
# If seeds are outside the Giant SCC, the crawler may not reach many groups.

print("=" * 60)
print("CONNECTED COMPONENTS ANALYSIS")
print("=" * 60)

# Get number of nodes for percentage calculations
total_nodes = G.number_of_nodes()

# ---- WCC Analysis ----
# wcc_sizes: list of component sizes, sorted descending
# Example: [1116361, 50, 30, 20, 10, ...] → giant component + small ones
wcc_sizes_sorted = sorted([len(component) for component in wcc], reverse=True)

print(f"\nWEAKLY CONNECTED COMPONENTS (WCC):")
print(f"  Total components: {num_wcc}")
print(f"  Giant WCC: {wcc_sizes_sorted[0]:,} nodes ({100*wcc_sizes_sorted[0]/total_nodes:.1f}%)")

if len(wcc_sizes_sorted) > 1:
    print(f"  2nd component: {wcc_sizes_sorted[1]:,} nodes ({100*wcc_sizes_sorted[1]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 2:
    print(f"  3rd component: {wcc_sizes_sorted[2]:,} nodes ({100*wcc_sizes_sorted[2]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 3:
    print(f"  4th component: {wcc_sizes_sorted[3]:,} nodes ({100*wcc_sizes_sorted[3]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 4:
    print(f"  5th component: {wcc_sizes_sorted[4]:,} nodes ({100*wcc_sizes_sorted[4]/total_nodes:.1f}%)")

print(f"  Top 10 component sizes: {wcc_sizes_sorted[:10]}")

# ---- SCC Analysis ----
# scc_sizes: list of component sizes, sorted descending
# Example: [85361, 2, 2, 2, 1, 1, ...] → one medium component + many singletons
scc_sizes_sorted = sorted([len(component) for component in scc], reverse=True)

print(f"\nSTRONGLY CONNECTED COMPONENTS (SCC):")
print(f"  Total components: {num_scc}")
print(f"  Giant SCC: {scc_sizes_sorted[0]:,} nodes ({100*scc_sizes_sorted[0]/total_nodes:.1f}%)")

if len(scc_sizes_sorted) > 1:
    print(f"  2nd component: {scc_sizes_sorted[1]:,} nodes ({100*scc_sizes_sorted[1]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 2:
    print(f"  3rd component: {scc_sizes_sorted[2]:,} nodes ({100*scc_sizes_sorted[2]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 3:
    print(f"  4th component: {scc_sizes_sorted[3]:,} nodes ({100*scc_sizes_sorted[3]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 4:
    print(f"  5th component: {scc_sizes_sorted[4]:,} nodes ({100*scc_sizes_sorted[4]/total_nodes:.1f}%)")

print(f"  Top 10 component sizes: {scc_sizes_sorted[:10]}")

# ---- Implications for the crawler ----
print("\n" + "=" * 60)
print("IMPLICATIONS FOR THE CRAWLER")
print("=" * 60)
print(f"• {100*wcc_sizes_sorted[0]/total_nodes:.1f}% of nodes are in Giant WCC → network is connected (ignoring directions)")
print(f"• Only {100*scc_sizes_sorted[0]/total_nodes:.1f}% are in Giant SCC → few nodes are mutually reachable")
print(f"• If seeds are OUTSIDE the SCC, the crawler may not reach many groups")
print(f"• There are {num_wcc} separate WCC components: if all seeds are in one, others are unreachable")
# Out:
# ============================================================
# CONNECTED COMPONENTS ANALYSIS
# ============================================================
#
# WEAKLY CONNECTED COMPONENTS (WCC):
#   Total components: 384
#   Giant WCC: 48,222 nodes (99.2%)
#   2nd component: 3 nodes (0.0%)
#   3rd component: 3 nodes (0.0%)
#   4th component: 3 nodes (0.0%)
#   5th component: 2 nodes (0.0%)
#   Top 10 component sizes: [48222, 3, 3, 3, 2, 2, 2, 2, 2, 2]
#
# STRONGLY CONNECTED COMPONENTS (SCC):
#   Total components: 11622
#   Giant SCC: 36,386 nodes (74.8%)
#   2nd component: 17 nodes (0.0%)
#   3rd component: 15 nodes (0.0%)
#   4th component: 12 nodes (0.0%)
#   5th component: 12 nodes (0.0%)
#   Top 10 component sizes: [36386, 17, 15, 12, 12, 11, 10, 8, 8, 7]
#
# ============================================================
# IMPLICATIONS FOR THE CRAWLER
# ============================================================
# • 99.2% of nodes are in Giant WCC → network is connected (ignoring directions)
# • Only 74.8% are in Giant SCC → few nodes are mutually reachable
# • If seeds are OUTSIDE the SCC, the crawler may not reach many groups
# • There are 384 separate WCC components: if all seeds are in one, others are unreachable

# %% [markdown]
# ## 4) PageRank (chiave nei grafi diretti)
#
# - `nx.pagerank(G)` calcola un punteggio di importanza dei nodi.
# - È un metodo **iterativo**.
#
# **Costo:** ~O(k·|E|) dove *k* è il numero di iterazioni.
# Su grafi grandi può essere costoso: controlla `max_iter` e `tol`.

# %%
# =============================================
# PAGERANK CON ARCHI INVERTITI
# =============================================
# Normalmente PageRank premia chi ha archi ENTRANTI (aggregatori)
# Con archi invertiti, premia chi ha archi USCENTI (fonti originali)

# Crea una copia del grafo con archi invertiti
# Originale: A → B (B ha forwardato da A)
# Invertito: B → A
G_reversed = G.reverse()

# Calcola PageRank sul grafo invertito
pr = nx.pagerank(G_reversed, max_iter=100, tol=1e-6)

top_pr = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:10]
top_pr
# Out:
# [(1472892297, 0.003477405970602263),
#  (1392160803, 0.0021345230574174867),
#  (1006503122, 0.0018439964034215343),
#  (1003099698, 0.0017312547591434684),
#  (1179270258, 0.0014053712640501106),
#  (1126704851, 0.0013511265041318012),
#  (1009232144, 0.0012554292937492302),
#  (1000170429, 0.0012096496480927075),
#  (1117426017, 0.0011529135427803022),
#  (1387645188, 0.0011014160868745618)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# =============================================
# PLOT PAGERANK DISTRIBUTION (log-log)
# =============================================
pr_values = list(pr.values())

fig, ax = plt.subplots(figsize=(8, 5))

# Bin logaritmici
pr_values_nonzero = [v for v in pr_values if v > 0]
bins_pr = np.logspace(np.log10(min(pr_values_nonzero)), np.log10(max(pr_values_nonzero)), 50)
ax.hist(pr_values_nonzero, bins=bins_pr, edgecolor='black', alpha=0.7, color='green')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('PageRank')
ax.set_ylabel('Number of nodes')
ax.set_title('PageRank distribution(log-log) ')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('pagerank_distribution_loglog.png', dpi=150)
plt.show()

# %% [markdown]
# ## 5) HITS (hub e authority)
#
# - `nx.hits(G)` restituisce due dizionari: **hubs** e **authorities**.
# - Anche questo è **iterativo**.
#
# **Costo:** ~O(k·|E|)
# Su grafi grandi può essere costoso e talvolta più instabile di PageRank.

# %%
hubs, auth = nx.hits(G, max_iter=1000, tol=1e-8)

top_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:10]
top_auth = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:10]

print("top hubs")
print(top_hubs)
print("top auth")
print(top_auth)
# Out:
# top hubs
# [(1353291112, 0.002202872749196711), (1287556984, 0.0022025831140929106), (1460033413, 0.00220245796630524), (1420437562, 0.0022024250537855884), (1269495740, 0.002202411102343578), (1343638843, 0.0022024073972653443), (1424937539, 0.002202396762113201), (1473683433, 0.002202353490917981), (1429622111, 0.002202341930394119), (1484513106, 0.0022022790916465355)]
# top auth
# [(1318275860, 0.002182173060742206), (1254182474, 0.002163054323920109), (1215834055, 0.0021580741537662582), (1444621361, 0.0021579981521336836), (1220662131, 0.0021558978688205528), (1461240728, 0.0021534918286627413), (1282935538, 0.00215140024040589), (1185780966, 0.0021493644234800843), (1435525948, 0.0021489830562961333), (1473948950, 0.002148974967843785)]

# %% [markdown]
# ## 9) Cicli e DAG
#
# - `nx.is_directed_acyclic_graph(G)` verifica se il grafo è un **DAG** (nessun ciclo diretto).
#   **Costo:** ~O(|V|+|E|)
#
# - `nx.simple_cycles(G)` elenca i cicli semplici.
#   **Costo:** potenzialmente **esponenziale** 👉 evitare su grafi grandi.

# %%
is_dag = nx.is_directed_acyclic_graph(G)
is_dag
# Out:
# False

# %% [markdown]
# ## 10) Reciprocità (utile e leggera)
#
# Misura quanto gli archi sono spesso **bidirezionali**.
#
# - `nx.reciprocity(G)` -> valore globale (0..1 circa)
#
# **Costo:** ~O(|E|) (molto fattibile)

# %%
nx.reciprocity(G)
# Out:
# 0.2162849739476801

# %%
# =============================================
# TELEGRAM LINKS FOR MANUAL INVESTIGATION
# =============================================
# This block provides channel IDs for manual investigation.
# 
# Note: Telegram channel_ids cannot be directly converted to links.
# To investigate, you need to either:
# 1. Use Telegram API (telethon/pyrogram) to get username/title from ID
# 2. Search the ID on sites like tgstat.com or similar

# ---- Define top 20 for each metric ----
# top20_pagerank: list of tuples [(node_id, score), ...]
# Example: [(1004035975, 0.00132), (1064404455, 0.00118), ...]
top20_pagerank = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:20]
top20_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:20]
top20_authorities = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:20]

# ---- Extract just the node IDs as sets (for comparison later) ----
# Example: {1004035975, 1064404455, 1433940064, ...}
top20_pagerank_ids = set([node_id for node_id, score in top20_pagerank])
top20_hub_ids = set([node_id for node_id, score in top20_hubs])
top20_authority_ids = set([node_id for node_id, score in top20_authorities])

print("=" * 70)
print("CHANNEL IDs FOR MANUAL INVESTIGATION")
print("=" * 70)

print("\nNote: Telegram channel_ids are numeric and cannot be directly")
print("converted to links without using the Telegram API.")
print("\nTo investigate these channels, you can:")
print("  1. Use Telegram API (telethon) to get username/title from ID")
print("  2. Search the ID on tgstat.com or similar services")
print("  3. Use a bot like @username_to_id_bot (reverse lookup)")

# ---- Top 10 PageRank IDs ----
print("\n--- TOP 10 PAGERANK (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_pagerank[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Top 10 Hub IDs ----
print("\n--- TOP 10 HUBS (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_hubs[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Top 10 Authority IDs ----
print("\n--- TOP 10 AUTHORITIES (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_authorities[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Summary of unique channels to investigate ----
all_top_ids = top20_pagerank_ids | top20_hub_ids | top20_authority_ids
print(f"\n--- SUMMARY ---")
print(f"Total unique channels in top 20 of any metric: {len(all_top_ids)}")
# Out:
# ======================================================================
# CHANNEL IDs FOR MANUAL INVESTIGATION
# ======================================================================
#
# Note: Telegram channel_ids are numeric and cannot be directly
# converted to links without using the Telegram API.
#
# To investigate these channels, you can:
#   1. Use Telegram API (telethon) to get username/title from ID
#   2. Search the ID on tgstat.com or similar services
#   3. Use a bot like @username_to_id_bot (reverse lookup)
#
# --- TOP 10 PAGERANK (to investigate) ---
#   1. Channel ID: 1472892297 (in:1, out:761)
#   2. Channel ID: 1392160803 (in:1, out:1945)
#   3. Channel ID: 1006503122 (in:1, out:1760)
#   4. Channel ID: 1003099698 (in:14, out:68)
#   5. Channel ID: 1179270258 (in:0, out:4347)
#   6. Channel ID: 1126704851 (in:4, out:856)
#   7. Channel ID: 1009232144 (in:11, out:1704)
#   8. Channel ID: 1000170429 (in:4, out:273)
#   9. Channel ID: 1117426017 (in:1, out:462)
#   10. Channel ID: 1387645188 (in:7, out:2813)
#
# --- TOP 10 HUBS (to investigate) ---
#   1. Channel ID: 1353291112 (in:249, out:519)
#   2. Channel ID: 1287556984 (in:261, out:509)
#   3. Channel ID: 1460033413 (in:211, out:512)
#   4. Channel ID: 1420437562 (in:223, out:510)
#   5. Channel ID: 1269495740 (in:143, out:510)
#   6. Channel ID: 1343638843 (in:47, out:512)
#   7. Channel ID: 1424937539 (in:207, out:509)
#   8. Channel ID: 1473683433 (in:211, out:506)
#   9. Channel ID: 1429622111 (in:236, out:506)
#   10. Channel ID: 1484513106 (in:252, out:508)
#
# --- TOP 10 AUTHORITIES (to investigate) ---
#   1. Channel ID: 1318275860 (in:483, out:458)
#   2. Channel ID: 1254182474 (in:476, out:446)
#   3. Channel ID: 1215834055 (in:476, out:447)
#   4. Channel ID: 1444621361 (in:476, out:465)
#   5. Channel ID: 1220662131 (in:474, out:455)
#   6. Channel ID: 1461240728 (in:475, out:468)
#   7. Channel ID: 1282935538 (in:474, out:476)
#   8. Channel ID: 1185780966 (in:475, out:450)
#   9. Channel ID: 1435525948 (in:473, out:389)
#   10. Channel ID: 1473948950 (in:473, out:432)
#
# --- SUMMARY ---
# Total unique channels in top 20 of any metric: 60

# %%
# =============================================
# MANUAL INVESTIGATION: TOP NODES BY PAGERANK, HUB, AUTHORITY
# =============================================
# This block prints detailed tables and compares overlap between metrics.
# Goal: understand if top Hubs are also top Authorities, or if they differ.
# 
# Reminder (in this graph, edge A→B means B forwarded from A):
# - Hub: node whose content is forwarded a lot (high out-degree)
# - Authority: node that forwards from many good sources (high in-degree)

# =============================================
# CONFIGURATION: Set how many top nodes to analyze
# =============================================
TOP_N = 700  # ← CHANGE THIS VALUE TO ANALYZE MORE OR FEWER NODES

# ---- Define top N for each metric ----
# top_n_pagerank: list of tuples [(node_id, score), ...]
# Example: [(1004035975, 0.00132), (1064404455, 0.00118), ...]
top_n_pagerank = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:TOP_N]
top_n_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:TOP_N]
top_n_authorities = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:TOP_N]

# ---- Extract just the node IDs as sets (for comparison) ----
# Example: {1004035975, 1064404455, 1433940064, ...}
top_n_pagerank_ids = set([node_id for node_id, score in top_n_pagerank])
top_n_hub_ids = set([node_id for node_id, score in top_n_hubs])
top_n_authority_ids = set([node_id for node_id, score in top_n_authorities])

print("=" * 70)
print(f"TOP {TOP_N} NODES BY PAGERANK, HUB, AUTHORITY")
print("=" * 70)

# ---- Print top N PageRank with in/out degree ----
print(f"\n--- TOP {TOP_N} PAGERANK ---")
print(f"{'Rank':<5} {'Node ID':<15} {'PageRank':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_pagerank, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# ---- Print top N Hubs with in/out degree ----
print(f"\n--- TOP {TOP_N} HUBS ---")
print(f"{'Rank':<5} {'Node ID':<15} {'Hub Score':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_hubs, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# ---- Print top N Authorities with in/out degree ----
print(f"\n--- TOP {TOP_N} AUTHORITIES ---")
print(f"{'Rank':<5} {'Node ID':<15} {'Auth Score':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_authorities, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# =============================================
# COMPARISON: Are top Hubs also top Authorities?
# =============================================
print("\n" + "=" * 70)
print(f"COMPARISON: TOP {TOP_N} HUBS vs TOP {TOP_N} AUTHORITIES")
print("=" * 70)

# Set operations to find overlap and differences
nodes_in_both_hub_and_auth = top_n_hub_ids & top_n_authority_ids  # intersection
nodes_only_in_hub = top_n_hub_ids - top_n_authority_ids           # hub but not authority
nodes_only_in_auth = top_n_authority_ids - top_n_hub_ids          # authority but not hub

print(f"\nNodes in BOTH top {TOP_N} (Hub AND Authority): {len(nodes_in_both_hub_and_auth)}")
print(f"Nodes ONLY in top {TOP_N} Hubs: {len(nodes_only_in_hub)}")
print(f"Nodes ONLY in top {TOP_N} Authorities: {len(nodes_only_in_auth)}")

if len(nodes_in_both_hub_and_auth) > 0:
    print(f"\nNode IDs in common: {nodes_in_both_hub_and_auth}")
else:
    print(f"\n→ Top {TOP_N} Hubs and top {TOP_N} Authorities are DISTINCT groups!")

# ---- Comparison across all three metrics ----
print("\n" + "=" * 70)
print(f"COMPARISON: PAGERANK vs HUB vs AUTHORITY (TOP {TOP_N})")
print("=" * 70)

overlap_pr_hub = top_n_pagerank_ids & top_n_hub_ids
overlap_pr_auth = top_n_pagerank_ids & top_n_authority_ids
overlap_hub_auth = top_n_hub_ids & top_n_authority_ids
overlap_all_three = top_n_pagerank_ids & top_n_hub_ids & top_n_authority_ids

print(f"PageRank ∩ Hub: {len(overlap_pr_hub)} nodes in common")
print(f"PageRank ∩ Authority: {len(overlap_pr_auth)} nodes in common")
print(f"Hub ∩ Authority: {len(overlap_hub_auth)} nodes in common")
print(f"All three metrics: {len(overlap_all_three)} nodes in common")

if len(overlap_all_three) > 0:
    print(f"\nNodes in ALL three top {TOP_N}: {overlap_all_three}")

# ---- Summary ----
all_top_ids = top_n_pagerank_ids | top_n_hub_ids | top_n_authority_ids
print(f"\n--- SUMMARY ---")
print(f"Total unique channels in top {TOP_N} of any metric: {len(all_top_ids)}")
# Out:
# ======================================================================
# TOP 700 NODES BY PAGERANK, HUB, AUTHORITY
# ======================================================================
#
# --- TOP 700 PAGERANK ---
# Rank  Node ID         PageRank     In-degree    Out-degree
# --------------------------------------------------------
# 1     1472892297      0.003477     1            761
# 2     1392160803      0.002135     1            1945
# 3     1006503122      0.001844     1            1760
# 4     1003099698      0.001731     14           68
# 5     1179270258      0.001405     0            4347
# 6     1126704851      0.001351     4            856
# 7     1009232144      0.001255     11           1704
# 8     1000170429      0.001210     4            273
# 9     1117426017      0.001153     1            462
# 10    1387645188      0.001101     7            2813
# 11    1137657151      0.001002     4            1133
# 12    1244077735      0.001001     1            1883
# 13    1200497997      0.000963     7            2257
# 14    1479163323      0.000930     41           3723
# 15    1265936035      0.000913     9            260
# 16    1463721328      0.000909     0            497
# 17    1124469578      0.000815     125          1215
# 18    1008681933      0.000807     1            276
# 19    1459890679      0.000780     87           531
# 20    1123046963      0.000779     73           667
# 21    1146915409      0.000749     1            92
# 22    1417136285      0.000721     72           2457
# 23    1227152968      0.000654     104          645
# 24    1112562459      0.000633     35           814
# 25    1198299024      0.000622     24           456
# 26    1203808566      0.000616     44           299
# 27    1142271647      0.000612     2            880
# 28    1279430055      0.000575     2            583
# 29    1113052711      0.000575     35           625
# 30    1077923535      0.000572     3            497
# 31    1437733910      0.000569     9            476
# 32    1128083841      0.000568     2            301
# 33    1225790696      0.000562     171          2153
# 34    1099350027      0.000555     98           880
# 35    1136479756      0.000545     69           2837
# 36    1008107955      0.000543     20           243
# 37    1443119244      0.000541     4            366
# 38    1038976893      0.000540     1            42
# 39    1042737298      0.000536     11           572
# 40    1114685706      0.000534     69           354
# 41    1250173526      0.000527     14           188
# 42    1454077785      0.000524     26           635
# 43    1041599776      0.000523     71           511
# 44    1111348665      0.000516     5            785
, 1458674626, 1160147907, 1411515332, 1256096706, 1322468294, 1447590857, 1307816907, 1462131660, 1219806160, 1305236438, 1336527836, 1364620262, 1453773802, 1266930670, 1473686513, 1323871218, 1436767219, 1296614390, 1434407928, 1468480507, 1353100285, 1194380292, 1406061577, 1309854729, 1409885196, 1335743500, 1171694609, 1440646162, 1377596439, 1484117016, 1393597470, 1585929250, 1456710691, 1381262373, 1282872361, 1235139628, 1444621361, 1494801458, 1438807089, 1157215287, 1391029308, 1214784580, 1396200521, 1470485586, 1216672855, 1483545694, 1467538533, 1159335013, 1430336615, 1497568365, 1441582193, 1402379380, 1188240500, 1571501186, 1471935619, 1157022853, 1222065290, 1281475729, 1154913427, 1460266135, 1312873633, 1454529701, 1324459174, 1256035493, 1309549738, 1256066219, 1317563566, 1339907252, 1178076344, 1109515455, 1176583367, 1338762444, 1487873228, 1283235025, 1305060569, 1520592090, 1349944541, 1566293215, 1426216160, 1293063394, 1492348130, 1306295 ...
#
# ======================================================================
# COMPARISON: PAGERANK vs HUB vs AUTHORITY (TOP 700)
# ======================================================================
# PageRank ∩ Hub: 69 nodes in common
# PageRank ∩ Authority: 9 nodes in common
# Hub ∩ Authority: 540 nodes in common
# All three metrics: 7 nodes in common
#
# Nodes in ALL three top 700: {1003740416, 1227152968, 1492765963, 1283359437, 1053161069, 1093357968, 1043238747}
#
# --- SUMMARY ---
# Total unique channels in top 700 of any metric: 1489

# %%
# =============================================
# INVESTIGATE TOP NODES: PAGERANK, HUB, AUTHORITY
# =============================================
# This cell allows manual investigation of top channels.
# Shows preprocessing info (English message count) for each channel.
#
# Data structure example:
# channels_config = {
#     1004035975: {
#         'n_messages': 15,
#         'selection': 'random',
#         'metrics': ['pagerank', 'hub'],
#         'english_msg_count': 156,  # From preprocessing
#     },
# }

import json
import os
import random
from collections import defaultdict
from datetime import datetime

# =============================================
# CONFIGURATION
# =============================================
TGDATASET_DIR = "../../material"
EXTRACTED_DIR = f"{TGDATASET_DIR}/TGDataset_extracted"
MAPPING_FILE = f"{TGDATASET_DIR}/channel_file_mapping.json"
LABELED_FILE = f"{TGDATASET_DIR}/TGDataset/labeled_data/ch_to_topic_mapping.csv"

# How many top nodes to investigate for each metric
TOP_N_TO_INVESTIGATE = 10

# How many messages to extract per channel
N_MESSAGES = 15

# Selection mode: 'first', 'last', 'random'
SELECTION_MODE = 'random'

# =============================================
# BUILD CHANNELS CONFIG DICTIONARY
# =============================================
# Structure: {channel_id: {'n_messages': int, 'selection': str, 'metrics': list, ...}}
channels_config = {}

# Add top PageRank nodes
for rank, (node_id, score) in enumerate(top_n_pagerank[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),  # From preprocessing
        }
    channels_config[node_id]['metrics'].append('pagerank')
    channels_config[node_id]['pagerank_rank'] = rank
    channels_config[node_id]['pagerank_score'] = score

# Add top Hub nodes
for rank, (node_id, score) in enumerate(top_n_hubs[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),
        }
    channels_config[node_id]['metrics'].append('hub')
    channels_config[node_id]['hub_rank'] = rank
    channels_config[node_id]['hub_score'] = score

# Add top Authority nodes
for rank, (node_id, score) in enumerate(top_n_authorities[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),
        }
    channels_config[node_id]['metrics'].append('authority')
    channels_config[node_id]['authority_rank'] = rank
    channels_config[node_id]['authority_score'] = score

print(f"Channels to investigate: {len(channels_config)}")
print(f"  - From PageRank top {TOP_N_TO_INVESTIGATE}")
print(f"  - From Hub top {TOP_N_TO_INVESTIGATE}")
print(f"  - From Authority top {TOP_N_TO_INVESTIGATE}")

# =============================================
# LOAD CHANNEL MAPPING AND LABELS
# =============================================
print("\nLoading channel mapping...")
with open(MAPPING_FILE, 'r') as f:
    channel_mapping = json.load(f)

print("Loading ground truth labels...")
labels_df = pd.read_csv(LABELED_FILE)
channel_labels = dict(zip(labels_df['ch_ID'], labels_df['topic']))

print(f"  Channels in mapping: {len(channel_mapping):,}")
print(f"  Channels with labels: {len(channel_labels):,}")

# =============================================
# FUNCTION: LOAD CHANNEL DATA FROM TGDATASET
# =============================================
def load_channel_data(channel_id, channel_mapping, extracted_dir):
    """
    Load channel data from TGDataset extracted files.
    
    Returns dict with keys: 'title', 'username', 'text_messages', 'total_messages'
    """
    ch_id_str = str(channel_id)
    
    if ch_id_str not in channel_mapping:
        return None
    
    file_path = channel_mapping[ch_id_str]['file']
    full_path = f"{extracted_dir}/{file_path}"
    
    if not os.path.exists(full_path):
        return None
    
    try:
        with open(full_path, 'r') as f:
            data = json.load(f)
        
        if ch_id_str in data:
            channel_data = data[ch_id_str]
            return {
                'title': channel_data.get('title', '[no title]'),
                'username': channel_data.get('username', '[no username]'),
                'text_messages': channel_data.get('text_messages', {}),
                'total_messages': len(channel_data.get('text_messages', {})),
            }
    except Exception as e:
        print(f"  [ERROR] Failed to load channel {channel_id}: {e}")
    
    return None

# =============================================
# FUNCTION: SELECT MESSAGES
# =============================================
def select_messages(text_messages, n_messages, selection_mode):
    """
    Select messages from a channel based on configuration.
    Returns list of (msg_id, msg_data) tuples, sorted by date.
    """
    if not text_messages:
        return []
    
    msg_items = list(text_messages.items())
    msg_items_sorted = sorted(msg_items, key=lambda x: x[1].get('date', 0))
    
    n_available = len(msg_items_sorted)
    n_to_select = min(n_messages, n_available)
    
    if selection_mode == 'first':
        selected = msg_items_sorted[:n_to_select]
    elif selection_mode == 'last':
        selected = msg_items_sorted[-n_to_select:]
    elif selection_mode == 'random':
        selected = random.sample(msg_items_sorted, n_to_select)
        selected = sorted(selected, key=lambda x: x[1].get('date', 0))
    else:
        selected = msg_items_sorted[:n_to_select]
    
    return selected

# =============================================
# INVESTIGATE EACH CHANNEL
# =============================================
print("\n" + "=" * 80)
print("CHANNEL INVESTIGATION")
print("=" * 80)

investigation_results = {}

for channel_id, config in channels_config.items():
    print(f"\n{'─' * 80}")
    
    # Header with metrics
    metrics_str = ', '.join(config['metrics']).upper()
    print(f"CHANNEL {channel_id} [{metrics_str}]")
    print(f"{'─' * 80}")
    
    # Print metric rankings
    for metric in config['metrics']:
        rank = config.get(f'{metric}_rank', '?')
        score = config.get(f'{metric}_score', 0)
        print(f"  {metric.capitalize()}: Rank #{rank}, Score: {score:.6f}")
    
    # Print degree info
    print(f"  In-degree: {config['in_degree']:,}")
    print(f"  Out-degree: {config['out_degree']:,}")
    
    # Print preprocessing info
    english_count = config['english_msg_count']
    preprocess_status = "✓ VALID" if english_count >= MIN_CHANNEL_MESSAGES else f"✗ INVALID (< {MIN_CHANNEL_MESSAGES})"
    print(f"  English messages: {english_count} {preprocess_status}")
    
    # Check if labeled
    gt_label = channel_labels.get(channel_id, '[NOT LABELED]')
    print(f"  Ground Truth Label: {gt_label}")
    
    # Load channel data
    channel_data = load_channel_data(channel_id, channel_mapping, EXTRACTED_DIR)
    
    if channel_data is None:
        print(f"  [WARNING] Channel not found in TGDataset")
        investigation_results[channel_id] = {
            'config': config,
            'label': gt_label,
            'found': False,
        }
        continue
    
    print(f"  Title: {channel_data['title']}")
    print(f"  Username: @{channel_data['username']}")
    print(f"  Total messages in dataset: {channel_data['total_messages']:,}")
    
    # Select messages
    selected_messages = select_messages(
        channel_data['text_messages'],
        config['n_messages'],
        config['selection']
    )
    
    print(f"\n  MESSAGES ({len(selected_messages)} {config['selection']}, max {config['n_messages']}):")
    print(f"  {'─' * 70}")
    
    for msg_id, msg_data in selected_messages:
        msg_text = msg_data.get('message', '[no text]')
        msg_date = msg_data.get('date', 0)
        fwd_from = msg_data.get('forwarded_from_id', None)
        
        # Format date
        if msg_date:
            date_str = datetime.fromtimestamp(msg_date).strftime('%Y-%m-%d %H:%M')
        else:
            date_str = '[no date]'
        
        # Truncate message
        msg_display = msg_text[:300] if msg_text else '[empty]'
        if len(msg_text) > 300:
            msg_display += "..."
        
        # Forward indicator
        fwd_str = f" [FWD from {fwd_from}]" if fwd_from else ""
        
        print(f"    [{date_str}]{fwd_str}")
        print(f"    {msg_display}")
        print()
    
    # Store results
    investigation_results[channel_id] = {
        'config': config,
        'label': gt_label,
        'found': True,
        'title': channel_data['title'],
        'username': channel_data['username'],
        'total_messages': channel_data['total_messages'],
        'english_msg_count': english_count,
    }

# =============================================
# SUMMARY
# =============================================
print("\n" + "=" * 80)
print("INVESTIGATION SUMMARY")
print("=" * 80)

found_count = sum(1 for r in investigation_results.values() if r['found'])
labeled_count = sum(1 for r in investigation_results.values() if r['label'] != '[NOT LABELED]')

print(f"\nChannels investigated: {len(investigation_results)}")
print(f"  Found in TGDataset: {found_count}")
print(f"  Not found: {len(investigation_results) - found_count}")
print(f"  With GT label: {labeled_count}")

# Preprocessing status
valid_count = sum(1 for ch_id, r in investigation_results.items() 
                  if channels_config[ch_id]['english_msg_count'] >= MIN_CHANNEL_MESSAGES)
print(f"  Valid (>= {MIN_CHANNEL_MESSAGES} English msgs): {valid_count}")
print(f"  Invalid (< {MIN_CHANNEL_MESSAGES} English msgs): {len(investigation_results) - valid_count}")

# By metric
print("\nBy metric:")
for metric in ['pagerank', 'hub', 'authority']:
    count = sum(1 for ch_id, r in investigation_results.items() 
                if metric in channels_config[ch_id]['metrics'])
    print(f"  {metric.capitalize()}: {count} channels")
# Out:
# Channels to investigate: 30
#   - From PageRank top 10
#   - From Hub top 10
#   - From Authority top 10
#
# Loading channel mapping...
# Loading ground truth labels...
#   Channels in mapping: 120,979
#   Channels with labels: 19,768
#
# ================================================================================
# CHANNEL INVESTIGATION
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1472892297 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #1, Score: 0.003477
#   In-degree: 1
#   Out-degree: 761
#   English messages: 10 ✓ VALID
#   Ground Truth Label: Religion
#   Title: MTRK ǀ Rasmiy kanal
#   Username: @mtrkuzofficial
#   Total messages in dataset: 34,878
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-12-05 16:54]
#     **Янгиликлар 24 | 5 декабрь - халқаро волонтёрлар куни
# **#5dec #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2021-12-10 05:31]
#     **Imkoniyat daftari
# **#9dec #navoiy
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-01-02 07:14]
#     **Студия 24 | Минҳожиддин Мирзо - Республика Маънавият ва маърифат маркази раҳбари** **билан суҳбат
# **#2jan #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuz...
#
#     [2022-01-18 05:52]
#     **Янгиликлар 24 | Қонун лойиҳалари депутатлар муҳокамасида
# **#18jan #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-02-12 12:31]
#     **Янгиликлар 24 | Тошкент шаҳар фермер, деҳқон хўжаликлари ва томорқа ер эгалари кенгаши ташкил этилмоқда
# **#12feb #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me...
#
#     [2022-02-22 12:07]
#     **Янгиликлар 24 | Чет тилларини ўрганишни такомиллаштириш масалаларига бағишланган матбуот анжумани
# **#22feb #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrku...
#
#     [2022-04-04 17:11]
#     **Янгиликлар 24 | Томорқа - даромад манбаи
# **#4apr #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-04-08 09:50]
#     **Янгиликлар 24 | «Ўзсаноатқурилишматериаллари» уюшмаси брифинги
# **#8apr #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv....
#
#     [2022-04-09 06:25]
#     **Махсус репортаж | Хорижий тилларни ўрганишда янги ёндашувлар
# **#9apr #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv...
#
#     [2022-04-24 18:06]
#     **Янгиликлар 24 | «Яшил макон» умуммиллий лойиҳаси
# **#24apr #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-05-06 05:46]
#     **Янгиликлар 24 | «Tashkent flower fest - 2022» гуллар фестивали
# **#6may #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv...
#
#     [2022-05-23 06:30]
#     **Uchinchi renessans
# **#21may #uzbtarixi
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-06-20 06:27]
#     **Hamma uchun
# **#19june #uzbtarixi
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#     [2022-07-05 19:41]
#     **Ахборот 24 | Ўзбекистон ва Туркия Президентлари телефон орқали мулоқот қилдилар
# **#5july #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [...
#
#     [2022-07-28 06:41]
#     **Новый Узбекистан – Взгляд мирового сообщества
# **#28july #uzbekiston24
#
# [mtrk.uz](https://mtrk.uz/) | [Youtube](https://www.youtube.com/channel/UCWCThSM0ntBV9lQQ4PnIesg) | [Facebook](https://www.facebook.com/mtrkuzb/) | [Telegram](http://t.me/mtrkuzofficial) | [uztv.tv](https://uztv.tv/)
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1392160803 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #2, Score: 0.002135
#   In-degree: 1
#   Out-degree: 1,945
#   English messages: 6975 ✓ VALID
#   Ground Truth Label: US news
#   Title: Breaking911
#   Username: @breaking911
#   Total messages in dataset: 7,305
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-01-13 04:47]
#     **BREAKING:** YouTube is suspending President Donald Trump's channel for at least one week, and potentially longer, after his channel earned a strike under the platform's policies, the company said Tuesday evening.
#
# **Follow** @Breaking911
#
#     [2021-02-02 18:03]
#     **BREAKING**: Russia's Sputnik V COVID-19 vaccine appears safe and effective according to a study published in a British medical journal.
#
# The efficacy is 91% and prevents individuals from becoming severely ill. It is unclear whether the vaccine can stop transmission.
#
# **Follow** @Breaking911 @Bre...
#
#     [2021-03-06 18:15]
#     BREAKING: The Senate has passed the Covid-19 relief bill by a vote of 50-49
#
# Sen. Dan Sullivan (R-AK) was absent due to a family emergency, so VP Kamala Harris did not need to break a tie
#
# Follow @Breaking911
#
#     [2021-06-25 00:33]
#     Rep. Marjorie Taylor Greene: "I’d like just to take a minute and remind everyone that words matter… Contraception stops a woman from becoming pregnant. The Plan B pill kills a baby in the womb."
#
#     [2021-09-03 01:22]
#     **BREAKING: Florida governor appeals ruling that schools can require student face masks, says it’s important to let parents opt out. - AP**
#
#     [2021-09-14 18:57]
#     R.I.P. - Norm MacDonald, comedian and former ‘SNL’ cast member, dies at 61 - https://breaking911.com/norm-macdonald-comedian-and-former-snl-cast-member-dies-at-61/
#
#     [2021-09-30 20:07]
#     FBI Pittsburgh offering $5,000 reward for information on gun stolen from government vehicle - https://breaking911.com/fbi-pittsburgh-offering-5000-reward-for-information-on-gun-stolen-from-government-vehicle/
#
#     [2021-10-03 20:10]
#     URGENT: Amber Alert Issued For 11-Year-Old North Carolina Girl Believed To Have Been Kidnapped - https://breaking911.com/urgent-amber-alert-issued-for-11-year-old-north-carolina-girl-believed-to-have-been-kidnapped/
#
# **PLEASE SHARE!**
#
#     [2021-11-29 00:26]
#     Dr. Fauci looks back on COVID-19 response, slams Republicans and says “I’m going to be saving lives.”
#
# Full Interview:  https://breaking911.com/full-interview-dr-fauci-looks-back-on-covid-19-response-slams-republicans-and-says-im-going-to-be-saving-lives/
#
#     [2021-12-07 21:23]
#     4th grader brought pistol to elementary school, police say  https://breaking911.com/4th-grader-brought-pistol-to-nashville-elementary-school-police-say/
#
# **Follow @Breaking911**
#
#     [2021-12-15 03:13]
#     DEVELOPING: Teen Shot Dead After Basketball Game At Virginia High School, Police Say - https://breaking911.com/teen-shot-dead-after-basketball-game-at-virginia-high-school-police-say/
#
#     [2021-12-15 21:09]
#     Her husband reported her missing, but police say he had already killed her and tried to hide the body.
#
# https://breaking911.com/her-husband-reported-her-missing-but-police-say-he-had-already-killed-her-and-tried-to-hide-her-body/
#
#     [2021-12-22 08:21]
#     **WATCH: Cop Pulls Gun During All-Out Brawl At Miami International Airport**! https://breaking911.com/watch-cop-pulls-gun-during-all-out-brawl-at-miami-international-airport/
#
#     [2022-04-06 17:28]
#     RAW: Bodycam Shows Police Drop Armed Woman Inside Florida Walmart - https://breaking911.com/raw-bodycam-shows-police-drop-armed-woman-inside-florida-walmart/
#
#     [2022-04-26 22:49]
#     “THIS MAN IS THE DEVIL”: 5-Year-Old Girl Lured from Birthday Party, Forced To Watch Child Porn While Being Sexually Battered, Sheriff Says  https://breaking911.com/this-is-the-devil-5-year-old-girl-lured-from-birthday-party-forced-to-watch-child-porn-while-being-sexually-battered-sheriff-says/
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1006503122 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #3, Score: 0.001844
#   In-degree: 1
#   Out-degree: 1,760
#   English messages: 129 ✓ VALID
#   Ground Truth Label: Software
#   Title: Durov's Channel
#   Username: @durov
#   Total messages in dataset: 136
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2016-04-14 21:34]
#     Here are 50+ great Telegram sticker sets for you. Made by winners of the sticker competition I held earlier this year. ENJOY! 👍
#
# https://telegram.me/addstickers/JeanBaptistePlagouille
# https://telegram.me/addstickers/JessAndJack
# https://telegram.me/addstickers/BornVillain
# https://telegram.me/addstick...
#
#     [2017-07-23 01:15]
#     There’s a weird rumor being spread in Iran about Telegram moving servers there. The idea of a privacy-oriented messaging app like Telegram moving its servers to a country with a history of Internet censorship is absurd and is hardly worth commenting on. However, it’s interesting to try to understand...
#
#     [2017-09-26 22:21]
#     **Why I Can't Visit Iran and Russia**
#
# Today, Iran joined the list of countries I can't travel to – Tehran's prosecutor just filed criminal charges against me there. More than 40 million people use Telegram in Iran and we've never blocked a single political channel and gave up exactly zero bytes of ...
#
#     [2017-12-21 20:37]
#     Happy Winter Solstice! May your wishes come true ✨🌟
#
#     [2018-04-30 17:51]
#     Thank you, each and every one of the 12,000+ people who stood up to support the freedom of internet and Telegram today in central Moscow.
# https://goo.gl/fEFtQb
#
#     [2018-06-30 09:59]
#     Cycling around Saimaa for 370km got us to Kummakivi, the balancing rock. This 7-meter long stone was left standing here by the Ice Age (or the Giants, whichever version you prefer).
#
#     [2018-07-15 17:32]
#     Although I normally don't watch football matches, I am very happy to hear France has won the World Cup ⚽
#
# I am a big admirer of French culture, art, design, architecture, cuisine, history and language.
#
# France is certain to play an even larger role in the world culture and economy in years to come ...
#
#     [2018-10-31 15:08]
#     My motto is “Never be afraid”. Even when an app's icons are trying to scare you. Happy Halloween! 🎃
#
# P.S. To see those icons, you'll need to have the latest version of Telegram for iOS installed.
#
#     [2019-03-14 08:35]
#     I see 3 million new users signed up for Telegram within the last 24 hours.
#
# Good. We have true privacy and unlimited space for everyone.
#
#     [2019-08-14 15:34]
#     Telegram turns 6 years today. Throughout these years, Telegram stood up for freedom and privacy. We defended what we believe in against tyrannies, kleptocracies and corporations.
#
# Today, 6 years after launch, Telegram is the third largest global messaging app in terms of the number of countries wher...
#
#     [2020-10-03 23:58]
#     Last night Telegram was down for about an hour in Europe due to hardware malfunctioning. Some iOS users who tried to access Telegram during this time may have been logged out and will unfortunately have to relogin.
#
# We have already fixed the iOS app and the update is on the way to the App Store. We...
#
#     [2020-11-20 10:47]
#     Just tried an iPhone 12 Pro – what an incredibly clunky piece of hardware. It looks and feels like an oversized version of an iPhone 5 from 2012, but with an ugly array of cameras sticking out at three different heights. The notorious notch and wide bezels are still there, creating a low screen-to-b...
#
#     [2021-01-08 18:33]
#     I hear Facebook has an entire department devoted to figuring out why Telegram is so popular. Imagine dozens of employees working on just that full-time.
#
# I am happy to save Facebook tens of millions of dollars and give away our secret for free: respect your users.
#
# Millions of people are outraged by...
#
#     [2021-01-10 17:21]
#     I’ve been taking part in the discussion in the comments and answering questions. Here are some of the responses:
#
# On Apple-Google censorship https://t.me/durovschat/518801
#
# On making server-side code open https://t.me/durovschat/515221
#
# On a privacy-conscious ad platform  https://t.me/durovschat/527...
#
#     [2021-03-19 14:19]
#     With [today’s update](https://telegram.org/blog/voice-chats-on-steroids), we're giving every Telegram user the power to run their own radio station (later this Spring: TV station) without adding any complexity to our apps.
#
# I’m proud we were able to roll out this new version of Telegram just 3 weeks...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1003099698 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #4, Score: 0.001731
#   In-degree: 14
#   Out-degree: 68
#   English messages: 866 ✓ VALID
#   Ground Truth Label: Software
#   Title: Telegram Geeks
#   Username: @geekschannel
#   Total messages in dataset: 1,067
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2016-02-22 13:36]
#     That's perfect for link sharing.
#
# How many times have you tried to copy just a link from a message but telegram copies the whole message instead?
#
#     [2016-03-02 12:03]
#     🔥 **TELEGRAM | DESKTOP** 🔥
#
# Telegram Desktop new update:
#
# **v0.9.29 dev**
#
# ➡️ **Ctrl+W or Ctrl+F4** for close window
# ➡️ **Ctrl+L** to lock Telegram if you use a local passcode
# ➡️ Bug fixes and other minor improvements.
#
# __Stable version will be released soon.__
#
# #telegram #desktop #update
#
#     [2016-03-14 22:40]
#     🏆We got some winners🏆
#
# For those asking if @PublicTestGroup is official, you can find the link here:
#
# https://telegram.org/blog/supergroups5k
#
#     [2016-03-21 21:00]
#     🔥 ** TELEGRAM | COMING SOON ** 🔥
#
# 🎥 Our @tlgramNET friends sent us a **video** showing the new features:
#
# ➡️ **Send stickers** without having the pack.
# ➡️ **Background connection**: Keep a low impact background connection to Telegram to receive notifications. Enable for reliable notifications.
# ➡️ **...
#
#     [2016-03-25 20:47]
#     ✅ Consecutive messages from a user in a group: Profile pic will only apper once (at the top message).
# ℹ️ @geeksChannel
#
#     [2016-03-27 19:51]
#     Top social apps in the most populated Asian countries.
#
# ℹ️ @geeksChannel
#
#     [2016-06-11 11:31]
#     🔥 New Beta feature
#
# If you leave a written message on a chat and you don't send it, you will see the draft at chats list.
#
# ℹ️ @geeksChannel
#
#     [2016-06-11 18:02]
#     🔥 Another new Beta feature
#
# Now at supergroups, messages will only receive the second mark after being read by someone in the group.
#
# ℹ️ @geeksChannel
#
#     [2016-11-22 20:14]
#     View Pack for Recent Stickers:
#
# try a long tap (or 3D-touch on iOS) on a recent sticker, then choose ‘View Pack’.
#
#     [2017-07-15 18:09]
#     Group preview with browser
#
# ℹ️ @geeksChannel
#
#     [2017-07-29 16:52]
#     🔥 New beta feature
#
# — Search: Filter by user messages
#
# #feature
#
# ℹ️ @geeksChannel
#
#     [2017-09-03 15:42]
#     🔥 New beta feature
#
# — Add sticker to favorite
# — Favorite stickers section
#
# #feature
#
# ℹ️ @geeksChannel
#
#     [2018-02-05 12:35]
#     🔥 New beta feature 🔥
#
# — Auto-night Theme.
#
# #telegram #beta #features
#
# ℹ️ @geeksChannel
#
#     [2019-02-04 17:20] [FWD from 1006503122]
#     We’ve just started Instant View 2.0 Competition – our crowdsourcing contest with a prize fund of $300,000, ending on the 4th of April.
#
# The goal is to create sets of rules (“templates”) that are used to generate beautiful “Instant View” previews for links shared on Telegram. Anyone with an understa...
#
#     [2019-07-06 16:11]
#     https://telegram.org/blog/animated-stickers
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1179270258 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #5, Score: 0.001405
#   In-degree: 0
#   Out-degree: 4,347
#   English messages: 201 ✓ VALID
#   Ground Truth Label: World news
#   Title: Disclose.tv
#   Username: @disclosetv
#   Total messages in dataset: 204
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2022-02-15 00:55]
#     JUST IN - The Canadian Civil Liberties Association states the government has not met the Emergencies Act threshold.
#
# https://twitter.com/cancivlib/status/1493383579983917057
#
# @disclosetv
#
#     [2022-02-16 11:00]
#     NEW - Klaus Schwab's World Economic Forum says "the COVID 19 pandemic has led to a heightened focus on the power of medical data, specifically so-called vaccine passports. These passports by nature serve as a form of digital identity."
#
# The new WEF report, published in February 2022, calls for a mul...
#
#     [2022-02-16 20:41]
#     NEW - Berkshire Hathaway Chair Charlie Munger admires the Chinese for banning cryptocurrencies such as #Bitcoin.
#
# "It's like some venereal disease or something."
#
# @disclosetv
#
#     [2022-02-21 17:24]
#     JUST IN - Russian President #Putin to address the nation tonight at 9 p.m. local time (1 p.m. ET).
#
# UPDATE - Moved to 10 p.m. local time.
#
# @disclosetv
#
#     [2022-02-24 15:50]
#     JUST IN - Switzerland imposes sanctions against three Russian banks and 361 deputies of the Russian Duma, President of the Swiss Confederation Ignazio Cassis announces.
#
# @disclosetv
#
#     [2022-02-25 12:18]
#     JUST IN - Chechen paramilitary (known as Kadyrovites) have reportedly been mobilized and are preparing to depart for #Ukraine, according to the Russian news outlet Baza.
#
# It is worth noting that the current footage from the live camera outside the mosque in Grozny does not show this gathering. So th...
#
#     [2022-02-25 17:39]
#     JUST IN - Russia is preparing for major medical events where doctors have to be drafted from across the country.
#
# The letter is signed by Deputy Health Minister Plutnitsky.
#
# https://twitter.com/EJ_Burrows/status/1497252061678813187
#
# @disclosetv
#
#     [2022-02-25 21:01]
#     NEW - Study by Lund University in Sweden shows "that [#Pfizer's mRNA vaccine][...] can be reverse transcribed to DNA [..], and this may give rise to the concern if [vaccine]-derived DNA may be integrated into the host genome and affect the integrity of genomic DNA, which may potentially mediate geno...
#
#     [2022-02-25 23:19]
#     JUST IN - US sanctions Putin, Lavrov, Russia's defense minister, deputy defense minister, and army chief.
#
# https://home.treasury.gov/news/press-releases/jy0610
#
# @disclosetv
#
#     [2022-02-27 12:21]
#     NOW - Russians search for cash at ATM machines as west imposes severe sanctions on banks.
#
# https://www.ft.com/content/0bd34bcd-52d9-4cff-9f81-33069a1851a3
#
# @disclosetv
#
#     [2022-02-27 16:54]
#     JUST IN - Ukraine informed the International Atomic Energy Agency (IAEA) today that missiles hit the site of a radioactive waste disposal facility in Kyiv.
#
# No damage, but IAEA calls an extraordinary meeting "to discuss the current situation in Ukraine."
#
# https://www.iaea.org/newscenter/pressrelease...
#
#     [2022-02-28 13:09]
#     JUST IN - Russia closes airspace for airlines from 36 countries.
#
# @disclosetv
#
#     [2022-02-28 19:08]
#     JUST IN - Monaco, wealth hub of the super-rich, adopts EU sanctions against Russia.
#
# @disclosetv
#
#     [2022-03-01 15:31]
#     NOW - Russia strikes near TV tower in Kyiv. Ukrainian TV channels reportedly stopped broadcasting several minutes ago, according to the local media outlet Kyiv Independent.
#
# @disclosetv
#
#     [2022-03-05 11:13]
#     NEW - PayPal shuts down its services in Russia.
#
# @disclosetv
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1126704851 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #6, Score: 0.001351
#   In-degree: 4
#   Out-degree: 856
#   English messages: 35 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: Huquqiy axborot
#   Username: @huquqiyaxborot
#   Total messages in dataset: 10,660
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2018-02-24 13:30]
#     💡МАЪЛУМОТ УЧУН
#
# 2018 йил 24 февраль ҳолатига:
#
# ✳️ Энг кам:
# ✔️иш ҳақи — ойига 172 240 сўм;
# ✔️ёшга доир пенсиялар — ойига 336 880 сўм;
# ✔️болаликдан ногиронларга бериладиган нафақа — ойига 336 880 сўм;
# ✔️зарур иш стажига эга бўлмаган кекса ёшдаги ва меҳнатга лаёқатсиз фуқароларга бериладиган нафақа —...
#
#     [2018-05-09 12:00]
#     [​​](http://telegra.ph/file/49b3646bd34168588245d.jpg)#Ғаройиб_қонунлар
# Таиланд пулни оёқ билан босиш, яъни топташ мумкин эмас. Бу барча пулларга нисбатан эмас, балки миллий пул бирлиги бўлмиш батга нисбатан амал қилади.
#
# Таиланд пул бирлигида қирол Рама IX нинг тасвири туширилган бўлиб, пулни оёқ о...
#
#     [2018-05-25 13:57]
#     https://goo.gl/FcjRmQ
#
#     [2019-10-22 10:03]
#     #Биласизми
# [Қонунчиликка мувофиқ](http://lex.uz/docs/1076015#1076272), бир қатор шахсларга автомобиль бензини сотиб олишга харажатларнинг бир қисми учун **ойлик пул компенсацияси** тўланади. 2019 йил 15 августдан компенсация миқдори **75 000 сўмни** [ташкил этади](http://lex.uz/docs/4453953).
#
# **✅ К...
#
#     [2019-12-29 09:54]
#     #Адлия_хабари
# “Ҳуқуқ билимдонлари” танловининг финал босқичи бугун, **29 декабрь соат 15:00 да MY5 телеканали** орқали намойиш этилади.
#
# Қарийб уч ой давом этган танловнинг ғолиблари ким? Ушбу саволга жавоб топишни истасангиз, муросасиз ўтган финал босқичини телевидение орқали томоша қилинг.
#
# Каналг...
#
#     [2020-03-02 12:00]
#     #Биласизми
# “Радар” йўл белгиси белгиланган ҳаракатланиш **тезлиги назоратга олинган барча жойларга ўрнатилиши** [шарт.
#
# ](http://lex.uz/docs/2850459)Кўчма махсус техника воситаларидан фойдаланиладиган жойларда кўчма устунга вақтинчалик йўл белгиларини ўрнатиш кўзда тутилади.
#
# Каналга уланиш👇👇👇
# http...
#
#     [2020-05-25 04:38]
#     #Биласизми
#
# 📋 Қонунчиликка мувофиқ ҳомиладорлик ва туғиш бўйича нафақани тайинлаш ва тўлаш учун** меҳнатга лаёқатсизлик варақаси** [асос бўлади.
#
# ](http://lex.uz/docs/357102#367601)💰 Ҳомиладорлик ва туғиш бўйича меҳнатга лаёқатсизлик варақаси **ҳомиладорликнинг ўттизинчи ҳафтасидан бошлаб **ҳудудий ...
#
#     [2020-06-21 05:00]
#     #Биласизми
# [Қонунчиликка кўра](http://lex.uz/docs/327039), кундузги таълим шаклида таҳсил олаётган талабаларга **ўқишдан бўш вақтларида** __(куннинг иккинчи ярмида)__ **меҳнат шартномаси бўйича** олий таълим муассасасида ёки бошқа ташкилотларда ишлашга **рухсат берилади.
#
# **Каналга уланиш👇👇👇
# https:/...
#
#     [2020-09-27 06:30]
#     #Ақл_чархи
#
# **“**[Ақл чархи](https://t.me/huquqiyaxborot/7858)**”** рукнидаги навбатдаги жумбоқ билан танишинг ҳамда ўз билимингиз ва иқтидорингизни синовдан ўтказинг.
#
# **ДАРАХТ ОСТИДАГИ ТИЛЛА
#
# **Қозихонага бир киши келиб, қозига ўз дардини айтди:
#
# – Бир пайтлар катта савдогар эдим. Бир йилча аввал...
#
#     [2020-11-02 13:51]
#     #Қонунчиликдаги_янгиликлар
#
# **Муҳаммад Ал-Хоразмий номидаги халқаро мукофот совриндорига 50 минг АҚШ доллари  берилади
#
# **🔰 Ҳукумат қарори билан __(676-сон, 30.10.2020 й.) __Президентнинг Муҳаммад Ал-Хоразмий номидаги халқаро мукофоти билан тақдирлаш тартиби тўғрисидаги низом тасдиқланди.
#
# Низомга...
#
#     [2020-11-26 07:50]
#     #Конституция_тест
#
# 🇺🇿 Ўзбекистон Республикасида илк бор Адлия вазирлиги ташаббуси билан  Бутун республика бўйлаб “**Конституцияни биласизми**” лойиҳаси амалга оширилади!
#
# 🌐 **Test.adliya.uz** сайти орқали ҳуқуқий тестларни ечинг ва Конституция бўйича билимларингизни синовдан ўтказинг.
#
# Синов Консти...
#
#     [2021-06-15 10:00]
#     #Биласизми
#
# **Психология таълим йўналишлари бўйича қабул параметрлари 30 фоизга оширилади
#
# **🔘** **2021/2022 ўқув йилида:
#
# 🔸 Олий таълим тизимида физика фанлари соҳаларга мослаштирилган ҳолда [ўқитилади](https://t.me/huquqiyaxborot/9375).
#
# 🔸 Республика ОТМ биология йўналишларининг 3 ва 4-курсларид...
#
#     [2021-09-05 07:36]
#     #Давлат_хизматлари_регламент
#
# **Объектни қайта ихтисослаштириш ва реконструкция қилиш учун рухсатнома бериш тартиби
#
# **⚠️ **Хизмат:** Объектларни қайта ихтисослаштириш ва реконструкция қилиш, шу жумладан, умумий овқатланиш корхоналарининг мавсумий кафеларини жойлаштириш учун рухсатномалар бериш
#
# 🙎...
#
#     [2021-10-08 04:28]
#     #Биласизми
#
# ✅ Газ бўлмайдиган ҳудудларда аҳолини кўмир билан узлуксиз таъминлаш учун қуйидагилар [амалга оширилади:](http://lex.uz/ru/docs/2693343)
#
# 👉 қиш мавсумида газ бўлмайдиган ҳудудларга етарли миқдорда кўмир етказиб бериш бўйича тегишли ҳужжатлар тасдиқланади __(Вазирлар Маҳкамаси – вилоят ҳо...
#
#     [2022-03-01 13:40]
#     #Биласизми
#
# ❌ Телекўрсатувларнинг бошловчилари, дикторлари ва бошқа қатнашчилари реклама учун ажратилган вақтдан ташқари пайтда маҳсулотни билатуриб намойиш қилиш ёки унинг истеъмол хусусиятларини бевосита ёки билвосита [тавсифлаш](https://lex.uz/docs/25458#26085)** ҳуқуқига эга эмас.
#
# **Каналга ул...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1009232144 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #7, Score: 0.001255
#   In-degree: 11
#   Out-degree: 1,704
#   English messages: 11 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: Двач
#   Username: @dvachannel
#   Total messages in dataset: 7,256
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-12-16 17:40]
#     Центробанк России задумал запретить инвестиции в криптовалюты
#
# Инвестируйте в стабильный российский рубль
#
#     [2021-12-26 07:06]
#     Искусство войны
#
#     [2022-01-09 11:28]
#     Украина может спать спокойно — тиктокера **Даню Милохина** не пустили в страну. Точная причина отказа во въезде неизвестна.
#
# В «Миротворец» уже внесли?
#
#     [2022-01-10 13:48]
#     Выбор очевиден
#
#     [2022-01-20 17:07]
#     Правительство Испании будет выплачивать молодым людям пособие, чтобы помочь им съехать от родителей
#
# Махровая русофобия какая-то
#
#     [2022-03-12 12:35]
#     Санкции на пользу
#
#     [2022-03-30 13:20]
#     Российского чиновника уволят за похвалу Зеленскому
#
# В этот раз без расстрела, но впредь будьте осторожны
#
#     [2022-04-06 08:59]
#     МВД попросит доступ к базам операторов и банков** в реальном времени
#
# **Да кто такая эта ваша тайна связи
#
#     [2022-05-13 12:55]
#     Потребители российского телевидения в Латвии
#
#     [2022-05-13 19:08]
#     **Gucci** представили ~~цак~~ **кольцо для носа** из латуни за **360 долларов** (23 тысячи рублей).
#
# Дайте два
#
#     [2022-05-15 08:28]
#     Зомбоящик продолжает готовить россиян к ядерной войне
#
#     [2022-05-16 14:05]
#     Ученые: видеоигры развивают интеллект у детей
#
# Сверхразумы с 10к+ часов в доте тут?
#
#     [2022-05-25 21:51]
#     Google отключит в России часть серверов
#
# Ждём лаги
#
#     [2022-06-01 20:47]
#     **«Если мы бахнем, то стратегическим, и не по Украине совсем. Поэтому, Джо, ты себя-то не успокаивай»
#
# Помёт** зачем-то спародировал Брежнева и прокомментировал слова **Байдена** о том, что США не видят у РФ планов запускать ядерку по Украине.
#
#     [2022-07-12 09:09]
#     В Пермском крае прошёл **чемпионат по метанию говна,** а именно — коровьих лепёшек. Рекордный бросок — 64 метра.
#
# Других соревнований у нас для вас нет
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1000170429 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #8, Score: 0.001210
#   In-degree: 4
#   Out-degree: 273
#   English messages: 18 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: None
#   Username: @khamenei_ir
#   Total messages in dataset: 6,953
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2015-09-24 07:06]
#     📹ويديو👆🏻؛ هم‌دلی جانبازها با آقای جانباز - بخش دوم
#
# ساير كيفيت ها:
# http://farsi.khamenei.ir/video-content?id=30822
#
#     [2015-11-24 12:55]
#     📷مجموعه پوستر تشكر رهبر انقلاب از ملت، عشاير و دولت عراق
# "مشكورين..."
#
# 🖨نسخه قابل چاپ مجموعه پوستر:
# http://khl.ink/5ol
#
# ☑️ @KHAMENEI_IR
#
#     [2016-02-03 10:21]
#     📩
# رهبر انقلاب: از همان ابتدای پیروزی انقلاب، برخی تفکر انقلابی را قبول نداشتند و برخی هم با اینکه داخل نظام بودند اما اعتقادی به مبارزه با استکبار نداشتند؛باید مقابل این جریان ایستاد/ در ٣٧سال گذشته، همواره مبارزه وجود داشته، البته امروز این مبارزه حساس‌تر شده است.
# ۹۴/۱۱/۱۴
#
#
# ☑️اخبار و مطالب درباره...
#
#     [2016-02-09 12:52]
#     🔎📝🔍
# مرور سریع بیانات رهبر انقلاب در دیدار نیروی هوایی ارتش ٩٤/١١/١٩
# 👇👇
# http://s15.khamenei.ir/ndata/news/32224/13941119-nirohavayi.pdf
#
#     [2016-05-02 15:02]
#     📸خانم «پارک گئون هی» رئیس جمهوری کره‌ی جنوبی و هیأت همراه، دقایقی پیش با حضرت آیت‌الله خامنه‌ای رهبر انقلاب اسلامی دیدار کردند. ۹۵/۲/۱۳
# 📽گزارش تصويری👇
# http://khl.ink/vnb
#
# ☑️ @Khamenei_ir
#
#     [2016-05-26 16:56]
#     🚨 #ويژه | دیدار خانواده شهید بدرالدین با رهبر انقلاب
#
# 📢خانواده شهید سید #مصطفی_بدرالدین فرمانده شاخه نظامی حزب‌الله لبنان عصر دیروز چهارشنبه (۵خرداد) با حضرت آیت‌الله خامنه‌ای دیدار کردند.
#
# 📝حضرت آیت‌الله خامنه‌ای در این دیدار با تجلیل از شجاعت‌ها و شهامت‌های #شهید_بدرالدین فرمودند:
# 🚩راجع به شخصیت م...
#
#     [2016-06-28 23:39]
#     ✨📩✨
# رهبر انقلاب: یکی از ابزارهای توسل و تقرب به پروردگار، توجه به ارواح مطهر شهیدان است. یعنی ما در این شبهای ماه رمضان اگر میخواهیم توسل بجوییم، تضرع کنیم، دعای مستجاب داشته باشیم، بایستی ارواح متعالی آنها را شفیع قرار بدهیم. خانواده‌های شهدا از ارواح شهیدان عزیزشان، استمداد کنند برای تقرب به خداون...
#
#     [2016-06-30 10:52]
#     📢شماره سی و نهم خط حزب‌الله منتشر شد؛
# 🌹منتظریم حاج احمد ان‌شاءالله بیاید...
# 🚩در آستانه فرا رسیدن #روز_قدس؛
# 🚨 انتشار بیانات منتشر نشده رهبرانقلاب درباره‌ حاج احمد متوسلیان
#
# ☑️چاپ👇
# http://khl.ink/kh39
#
#     [2016-07-09 19:29]
#     📸 تصوير كمتر ديده شده از رهبر انقلاب
#
# ☑️اخبار و مطالب درباره رهبرانقلاب👇
# http://telegram.me/joinchat/BVJQOTudY71xuff_eM03yg
#
#     [2016-08-25 14:54]
#     🎮 حكم بازی‌های اینترنتی 🎮
#
# ❓بعضى از سايت‌هاى خارجى بازی‌هاى اينترنتى دارند که بايد ابتدا مقدارى پول داد تا وارد بازى شد اگر ببريم اصل پولمان و جايزه به ما تعلق مى‌گيرد و اگر ببازيم پول خود را از دست مى‌دهيم. بازى کردن و پول دادن به اين سايت‌ها چگونه است؟
#
# ✅ جايز نيست.
#
#
# ☑️ #روزی_یک_حکم_شرعی مطابق با...
#
#     [2016-09-15 19:04]
#     📍خانمش گفت افتاده به سجده و دارد گریه میکند
#
# 📝 رهبر انقلاب: آن روزی که همین مسئله‌ی #سلولهای_بنیادی را جوانهای ما داشتند دنبال میکردند و کشف میکردند، خدا رحمت کند مرحوم مهندس کاظمی، رئیس این مؤسسه‌ی رویان آمده بود با همان جمع پیش من گزارش میداد.
#
# 🚩گفت من تلفن کردم که ببینم مهندس جوانی که مشغول تعقیب...
#
#     [2017-07-10 16:54]
#     💫 طرح| رهبرانقلاب: امروز جوانها باید خردمندی، معرفت و دانش، ایمان، همبستگی و یکپارچگی خودشان را هرچه ممکن است، تقویت کنند؛ درست همان‌هایی که دشمن می‌خواهد تقویت نشود.
#
# 🌹 #جوانان
# ☑️ @Khamenei_ir
#
#     [2017-07-13 17:20]
#     🌸 طرح | رهبر انقلاب: خداوند بر خانواده شهدا صلوات ميفرستد
#
# 🌹پنجشنبه‌ها؛ مجموعه #فرهنگ_شهادت
#
# 🖨 نسخه چاپ👇🏻
# ‏http://farsi.khamenei.ir/photo-album?id=34209
#
#     [2017-09-23 19:43]
#     🌏پوستر| تعامل گسترده با دنيا؛ توصيه هميشگی رهبرانقلاب
# ⚠️رهبرانقلاب: ما ميتوانيم با همه‌ی دنيا، منهای آمريكا و رژيم صهيونيستی رابطه داشته باشيم.
# 🗞 #پرونده_تعامل_با_دنیا
#
# 🏴 @Khamenei_ir
#
#     [2018-01-31 07:09]
#     📸 صبح امروز؛ حضور رهبرانقلاب اسلامی در گلزار شهدای بهشت زهرا(س) . ۹۶/۱۱/۱۱
#
# ☑️ @Khamenei_ir
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1117426017 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #9, Score: 0.001153
#   In-degree: 1
#   Out-degree: 462
#   English messages: 1914 ✓ VALID
#   Ground Truth Label: Entertainment
#   Title: None
#   Username: @Psychothreat
#   Total messages in dataset: 4,043
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-09-17 08:06]
#     🤣
# @psychothreat
#
#     [2021-09-20 23:31]
#     Travis Scott recent utopia post❤️‍🔥🌵🌟
# @psychothreat #news
#
#     [2021-09-28 21:31]
#     The bet saf now we don’t know how to stake again nana 😂
#
#     [2021-10-01 12:13]
#     What you see on the internet is rarely true.
#
#     [2021-10-02 23:13]
#     Wayne needs to retire.
#
#     [2021-10-04 11:25]
#     @psychothreat
#
#     [2021-10-16 09:49]
#     @psychothreat
#
#     [2021-10-24 18:17]
#     Cry some more
#
#     [2021-10-29 12:34]
#     Selling btc hola asap @cupid_x1
#
#     [2021-10-31 14:06]
#     i didn’t say ‘nft’ was a scam oo borga
# i said ‘nftsea.net’ is. know the difference
# why, you be blogger or something?😂
#
#     [2021-11-28 10:40]
#     CREDIT GIVEAWAY 🙏🙌💫😇 LOADING 🤍
#
#     [2021-11-29 20:32]
#     Winner.
#
#     [2021-12-11 07:21]
#     @unreshable2
#
#     [2021-12-21 09:41]
#     Mood for next sem😂💔
#
#     [2022-01-01 02:57]
#     I know yall bone ch 😹 ⭐️❤️‍🔥
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1387645188 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #10, Score: 0.001101
#   In-degree: 7
#   Out-degree: 2,813
#   English messages: 8500 ✓ VALID
#   Ground Truth Label: World news
#   Title: RT News
#   Username: @rtnews
#   Total messages in dataset: 8,574
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-08-31 19:09]
#     ⚡️Reporters have been told to leave and await updates with Joe Biden already more than 20 minutes late for his 'Afghanistan' speech at the White House.
#
# The WH Correspondent for Breitbart says it has now been delayed.
#
# Subscribe to RT t.me/rtintl
#
#     [2021-09-03 19:13]
#     ❗️**Central Moscow: Summer’s over, school's back — So is the infamous city traffic.
#
# **Happy Friday!
#
# Subscribe to RT t.me/rtintl
#
#     [2021-09-03 19:30]
#     **New ICE data-mining tool ALARMS unions & Sen Wyden - targets unauthorized workers**
#
# Senator Ron Wyden has raised the alarm over RAVEn, a powerful new data-mining tool being developed by ICE to clamp down on unauthorized workers.
#
# "I'm particularly concerned about the way ICE is buying its way a...
#
#     [2021-09-21 09:14]
#     **Winter Woes: Electricity prices to spike 10% in France (Report)
#
# **French consumer organization UFC-Que Choisir has warned of an unprecedented rise in electricity prices, expected to increase by 10% by the start of 2022.
#
# Le Parisien calculates the average costs for a household of four have skyroc...
#
#     [2021-09-27 19:20]
#     ⚡️ **US jury finds singer R. Kelly guilty of racketeering in sex trafficking case
#
# **Kelly now faces up to 20 years in prison.
#
# Subscribe to RT t.me/rtintl
#
#     [2021-10-06 14:14]
#     ⚡️**NATO leaders agree to remove accreditation for 8 Russian diplomats from Brussels over alleged "malign activities," while halving size of Russia's mission from 20 to 10 - **Sky News
#
# It comes after NATO rejected Russia's proposal to ensure missile control, for predictability and moderation - Russ...
#
#     [2021-10-10 17:00]
#     Thousands marched through Rome to protest workplace vaccine mandates. The authorities used water cannon to disperse some of those gathering in the Italian capital on Saturday.
#
# Subscribe to RT t.me/rtintl
#
#     [2021-10-15 17:39]
#     **DoJ reinstates “Russiagate” FBI agent McCabe's FULL pension**
#
# Frmr FBI agent Andrew McCabe will now receive his full pension and have records of his dismissal expunged from the Bureau's records – despite being fired by Donald Trump's administration for lying FOUR TIMES to the Department of Justi...
#
#     [2021-12-30 23:08]
#     ❗️**Kremlin ‘pleased’ with Biden-Putin talks, but warns against ‘colossal’ mistake**
#
# In a statement released after the phone talks between the Russian leader and his US counterpart, the Kremlin revealed that Biden made a pledge to Putin not to deploy offensive arms to Ukraine.
#
# Speaking to the Russ...
#
#     [2021-12-31 14:36]
#     ❗️**Fire engulfs pier in Kazakhstan
#
# **Firefighters are on the scene of a blaze in Ust-Kamenogorsk where two moored ships and a pier are up in flames.
#
# The cause of the inferno is yet to be established, authorities said.
#
# Subscribe to RT t.me/rtnews
#
#     [2022-01-04 17:23]
#     ⚡️**UK PM: Sticking with Plan B as hospitals declare ‘critical incidents’ ahead of Omicron ‘tsunami’
#
# **UK Prime Minister Boris Johnson will urge the cabinet to plough on with Plan B Covid measures - inc face masks in some indoor venues, testing before attending large venues, and working from home.
# ...
#
#     [2022-01-12 16:41]
#     **Around 50k Illegal Immigrants Released & Unaccounted for in US - Failed to Report to ICE
#
# **Over 47,000 immigrants released into the US on Notices To Report (NTR) between **March and August** last year have failed to report back to ICE officials and are now unaccounted for and roaming free.
#
# The f...
#
#     [2022-01-19 13:10]
#     ❗️**France Needs to LEAVE NATO** - presidential candidate
#
# Jean-Luc Melenchon believes an 'anti-Russia policy' is not in line with France’s interests. The presidential candidate called taking that option "dangerous and absurd."
#
# Subscribe to RT t.me/rtnews
#
#     [2022-01-26 18:15]
#     **Democrat congressman says Tucker Carlson viewers calling to whine at Biden for** **“not siding with Russia” in Ukraine crisis
#
# **New Jersey Congressman Tom Malinowski has claimed via Twitter his office is being bombarded with calls from Carlson viewers “upset we’re not siding with Russia.” (Guardi...
#
#     [2022-01-29 16:01]
#     **Secret UK govt unit used ‘unethical’ fear tactics to push Covid rules compliance – media
#
# **A parliamentary committee is reportedly set to investigate “scare ads” created by the UK government’s shadowy ‘behavioural insights’ team to “nudge” the public into obeying Covid-19 restrictions. The move c...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1353291112 [HUB]
# ────────────────────────────────────────────────────────────────────────────────
#   Hub: Rank #1, Score: 0.002203
#   In-degree: 249
#   Out-degree: 519
#   English messages: 15 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: ПростоПолитика
#   Username: @porno_politika
#   Total messages in dataset: 16,775
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-06-07 17:00]
#     Рубрика "Нам пишут"
#
# Сообщают о сборе азербайджанскими общественными деятелями подписей в обвинение новосибирского сотрудника ГИБДД Гусева и лиц, его поддержавших (в том числе и нас).
#
# Напомним, как в 2013 году они собирали подписи в защиту убийцы обычного парня Егора Щербакова - Орхана Зейналова. У...
#
#     [2021-06-08 08:23] [FWD from 1460033413]
#     Банк ВТБ вошел в проект строительства небоскреба iCity
# Группа ВТБ приобрела 25,1 долей в проекте строительства небоскреба iCity в Шмитовском проезде рядом с "Москва-Сити" у структуры ритейлера "Магнит" Алексея Богачева.
#  Ранее ВТБ открыл для MR Group кредитную линию на 30 миллиардов для строительст...
#
#     [2021-07-23 11:53]
#     И себе, и своим людям.
# http://v-times.site/component/k2/item/191576
#  Об этом сообщает @nexta_chita
#
#     [2021-07-31 09:52]
#     Место Александра Бердникова определили с помощью ГЛОНАСС
# http://ustav.group/component/k2/item/305977
#  Об этом сообщает @compromat_peterburgh
#
#     [2021-08-03 08:35]
#     Телеграм-канал Компромат 2.0.: сообщения от 01.08.2021
# http://politica2.info/component/k2/item/54723
#  Об этом сообщает @novost_free_lancer
#
#     [2021-08-23 08:51]
#     Источник https://t.me/porno_politika рассказал, что в настоящее время в городе Астрахани сложилась очень интересная ситуация в работе Астраханской межрегиональной природоохранной прокуратуры в лице её руководителя старшего советника юстиции Сегизекова Валерия Лазаревича. У него очень странные методы...
#
#     [2021-11-05 11:41] [FWD from 1183457811]
#     Попытка магазина часов Alltime отсудить 1 млрд руб. у Сбербанка за якобы имевшую место кражу логотипа предсказуемо закончилась ничем. Суд по интеллектуальным правам подтвердил законность решения Роспатента о приостановлении производства по иску Alltime. Осенью 2020 года Сбербанк представил новый лог...
#
#     [2022-03-25 14:16] [FWD from 1343638843]
#     Кумовство по-камчатски. Токсичный след появился в деле о рейдерском “распиле” Камчатской судоверфи (АО “Комкон”) на 1,5 млрд рублей.
#
# Выяснилось, что главный фигурант криминальной истории директор рыбзавода “Сокра” Андрей Обедин давно состоит в тесных приятельских отношениях и катается на лыжах вмес...
#
#     [2022-03-31 11:58] [FWD from 1272204784]
#     В очередной скандальный переплет вляпался зампред правительства Бурятии Баир Цыренов, а точнее история произошла с его супругой Ольгой Жигмитовой — ее застукали в нетрезвом состоянии за вождением. Этот эпизод может значительно усугубить и без того запятнанную политическую карьеру коммуниста Цыренова...
#
#     [2022-04-12 16:53] [FWD from 1194151689]
#     Письмо читателя. Здравствуй уважаемые! На канале постоянно выходят тексты о Богуне, но ты мало пишешь о командире ДОБ-1 Андрее Кардашяне и его заместителе Алексее Мачулине. Эти сотрудники ГИБДД постоянно заставляют подчиненных приносить конкретные суммы, которые собираются с водителей фур. Подобную ...
#
#     [2022-04-13 13:11]
#     Мегафон мутит с банком «Раунд»
#
# Рассказываем об очередном мошенничестве, столкнуться с котором может каждый. Дело в том, что организаторами выступают мобильные операторы Мегафон и YOTA. Схема у них простая, но удивительная в своей наглости.
#
# Для начала, вам стоит знать, что становясь клиентом этих о...
#
#     [2022-04-20 08:01] [FWD from 1489529243]
#     ВИС издевается над Левобережьем Новосибирска.
#
# Притчей во языцех согласно словарю называют явление, ставшее предметом широкого обсуждения и осуждения. В Новосибирске вот уже несколько лет этим самым явлением является компания ВИС. Она явилась в сибирский мегаполис, чтобы облагодетельствовать его, пр...
#
#     [2022-04-23 07:46] [FWD from 1424937539]
#     Счетная палата: воронежские власти провалили нацпроекты, прикрывшись красивыми цифрами
#
# Неразбериху, непрозрачные конкурсы, притянутые за уши отчеты и другие нарушения нашла Счетная палата РФ в Воронежской области. Отчет о результатах масштабной проверки пресс-служба СП направила редакции "Акцентов"...
#
#     [2022-06-29 09:07]
#     Игры в «Открытие»: Данкевич и Ко возьмут денег у Шмыгалева?
#
# Экс-глава «Открытия» Евгений Данкевич и другие бывшие топы банка, попавшие под взор силовиков год назад в связи с хищениями миллиардных сумм, решили поживиться от компании скандального экс-депутата Анатолия Шмыгалева. Через бывшего сотрудн...
#
#     [2022-07-28 10:48] [FWD from 1796040254]
#     В Татарстане на фоне скандала с запретом называть местного князька Рустама Минниханова президентом разворачивается скандал покруче. Татарские власти допустили свое окружение, атаку и полное поражение на мусорном фронте. При этом противник всем известен – «Ростех» Сергея Чемезова, списавший на провал...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1287556984 [HUB]
# ────────────────────────────────────────────────────────────────────────────────
#   Hub: Rank #2, Score: 0.002203
#   In-degree: 261
#   Out-degree: 509
#   English messages: 13 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: Тайны Кремля
#   Username: @cremlin_sekret
#   Total messages in dataset: 18,618
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-08-03 14:30]
#     Коломойский вляпался в «Татнефть»
# http://nezigar.com/component/k2/item/146721
#  Об этом сообщает @scryt_ugrozy
#
#     [2021-08-09 13:21]
#     Закон как драйвер спроса
# Уже более года ИПУ по 522-му ФЗ без платы для с потребителей ставят сетевые компании, в первую очередь "Россети", в частном секторе и предприятиях, гарантпоставщики ― в многоквартирных домах. С 1 января 2022 должны использоваться только интеллектуальные ИПУ.
#  "
# Известия" пи...
#
#     [2021-08-10 10:48]
#     Из школьной учебной программы в Белоруссии пропали произведения Набокова, Солженицына и Алексиевич
# http://politica2.info/component/k2/item/54860
#  Об этом сообщает @vesti_crasnodara
#
#     [2021-08-11 10:33]
#     До конца августа должна завершиться история с исполняющим обязанности министра ЖКХ Башкирии Аланом Марзаевым, которая может быть интересна
# Замгубернатора. Чиновник угрожающе пообещал "сделать сюрприз" школьнику, который сломал скульптуру пчелы в фонтане, ранее раскритикованную за уродство в социальн...
#
#     [2021-08-19 11:33] [FWD from 1296087183]
#     Источник рассказал, что в крайне  нервном состоянии пребывает в Лондоне решальщик Дмитрий Смычковский, который находится в международном розыске за дачу взяток сотрудникам СКР за освобождение авторитета Андрея Кочуйкова (Итльянец). Смычковский опасается, что «всплывет» крайне неприятная история, как...
#
#     [2021-08-20 08:05]
#     Мишки Сахалина ждут горбушу на нерест
# http://russian-post.info/component/k2/item/187533
#  Об этом сообщает @corono_novosti
#
#     [2021-08-21 15:35]
#     Все смешалось в рядах Единой России. Теперь уже сами ее кандидаты в попытке выкарабкаться из политического болота на тот островок, где дают мандаты, отпихивают партийных сотоварищей и клеймят партию почище самого Навального.
# Шума наделало видеообращение к избирателям кандидата от ЕР в калининградску...
#
#     [2021-10-23 08:18]
#     Двукратный олимпийский чемпион по лыжным гонкам Вячеслав Веденин скончался на 81 году жизни после болезни,
# сообщила РБК президент Федерации лыжных гонок России Елена Вяльбе.
#  Веденин был первым советским лыжником, выигравшим золото в индивидуальной мужской гонке на Олимпиаде. Он взял первое место ...
#
#     [2021-11-04 10:47] [FWD from 1256514066]
#     Кого губернаторы отправили в Совфед?
#
# В конце октября уполномоченным по правам ребенка стала Мария Львова-Белова. До этого она чуть больше года работала в Совфеде, как представитель Пензенской области.
#
# Сейчас главе региона Олегу Мельниченко предстоит назначить ей преемника. На этом фоне мы решили и...
#
#     [2022-03-22 14:09] [FWD from 1460670961]
#     На Ямале бывший депутат предстанет перед судом
#
# Бывшего депутата думы Салехарда, руководителя АО "ИСК ЯНАО" Михаила Бабийчука обвиняют в сокрытии от налоговой 17 млн рублей.
#
# Как полагает следствие, у АО "ИСК ЯНАО" возникла крупная задолженность перед налоговиками, однако Бабийчук с долгами решил не...
#
#     [2022-03-26 08:55] [FWD from 1296087183]
# ...
#
#     [2021-08-20 14:03]
#     Липецкий бизнес по Артамоновски
# http://russiangate.site/component/k2/item/87548
#  Об этом сообщает @zvjozd_vestnic
#
#     [2021-08-28 11:27]
#     Владимир Мошкович не удержал Максима Басова
# http://compromatbase.info/component/k2/item/107810
#  Об этом сообщает @politica_kitchen
#
#     [2021-10-11 11:23] [FWD from 1472588355]
#     Валерия Леонтьева госпитализировали с коронавирусом в Москве.
#  Секс-символ 80-х, 90-х, да и вообще всех времён пожаловался на слабость, кашель и высокую температуру. Несколько дней артист принимал таблетки самостоятельно, но ПЦР показал положительный результат.
#  Врачи оценивают состояние 72-летнег...
#
#     [2022-01-24 11:54] [FWD from 1776519647]
#     Здесь будет город-сад Таримское шоссе в Китае ― смелый и впечатляющий дорожный проект. Шоссе тянется около 500 км по одной из самых больших и опасных песчаных пустынь в мире, Такла-Макан, которая славится суровым климатом и зыбучими песками. Пустыня Такла-Макан необитаема, но 30 лет назад в ней были...
#
#     [2022-06-05 01:03]
#     ‟Дети всего внимательнее слушают тогда, когда говорят не с ними.„
#  © Анна Элеонора Рузвельт
#
#  Источник: @onlayn_peterburg
#
#     [2022-06-05 20:17]
#     ‟Вот почему ты так ненавидишь магов. Чтобы не винить в случившемся себя, ты винишь их.„
#  🎬 сериал «Мерлин» («Merlin», персонаж Артур Пендрагон)
#
#  Источник: @tsentr_novostey
#
#     [2022-06-09 05:22]
#     ‟Удивительное дело ― прошлое живёт в тебе, незримо и спокойно ожидая момента, чтобы всплыть на поверхность из мнимого небытия. Кажется, что его нет, что оно тебя покинуло. Но затем оно, как феникс, восставший из пепла, вспыхивает внутри со всей яркостью красок, звуков, движений присущей настоящему.„...
#
#     [2022-06-12 01:58]
#     ‟Она умела выкарабкиваться сама. Мои стремления помочь и поддержать редко принимались. Казалось, ей трудно поверить, что хоть что-то в этом мире может быть дано тебе даром. Она привыкла платить сразу и ненавидела брать в долг. Любой подарок, любая услуга, вплоть до подачи руки в транспорте или пропу...
#
#     [2022-07-21 19:30]
#     ‟— Логан, ты когда-нибудь испытывал сильное чувство? Такое сильное, что даже слово трудно вымолвить. — Один раз. Лучше мотоцикла я не видел... У меня не было слов, и его купил другой!„
#  🎬 мультфильм «Люди Икс: Эволюция» («X-men: Evolution», персонажи Скотт Саммерс/Циклоп, Джеймс «Логан» Хоулетт / Ро...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1185780966 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #8, Score: 0.002149
#   In-degree: 475
#   Out-degree: 450
#   English messages: 18 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: From Taganrog with love
#   Username: @from_tagranrog_with_love
#   Total messages in dataset: 14,541
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-07-01 11:28]
#     Снопок знает толк в Наливко
# http://russiangate.site/component/k2/item/83081
#  Об этом сообщает @infro_poshhjochiny
#
#     [2021-07-13 07:53] [FWD from 1296087183]
#     https://crimerussia.info/organizovannaya-prestupnost/item/262310-kak-tadzhikskaya-mafiya-delila-moskvu
#
#     [2021-07-26 13:54] [FWD from 1343638843]
#     https://rusrep.com/politika/item/130792-siloviki-pridut-za-livinskim-v-rosseti
#
#     [2021-08-14 10:18] [FWD from 1296087183]
#     В новом расследовании про схемы отмывания средств через недвижимость Дональда Трампа упоминаются россияне Андрей Богданов и Иван Казаников. Со слов Монте Фризнера,  консультанте по рискам в части отмывания средств, осужденном когда-то за отмывание денег и бывшем контракторе CIA, под прикрытием компа...
#
#     [2021-10-01 12:36]
#     Диагональ сработала, получили резкий выход вверх и это хорошо. Это была синяя стрелочка на одном из сценариев несколькими днями ранее. На этом коррекцию в В зигзага считаю законченной. Начинаем расти в финальную С в сценарии со старшим треугольником.
#  Сейчас ставим первую волну импульса вверх, посл...
#
#     [2021-11-16 11:26] [FWD from 1533411526]
#     Продвижение Tik Tok в школах продолжается?
# На всех последних мероприятиях
# министерство утверждало, что все проекты по продвижению среди школ и учителей, а особенно школьников, соцсети Tik Tok остановлены. Что же произошло?
#  «
# А вообще бывает, что вместе с учениками делаем ролик. Первая мысль у них...
#
#     [2021-12-07 10:00] [FWD from 1175598616]
#     🤑 ОТЧЕТ ИЗ АКАДЕМИИ
# КАЖДУЮ НЕДЕЛЮ МЫ ВЫВОДИМ С ФАРМИНГА И СТЕЙКИНГА
# СЕГОДНЯ ЭТО ― 1825$ ( за 8 дней )
# В академии добавили 5 новых видео , по разным темам и блокчейнам (Cosmos / Near / Solana / Kusama / Polkadot )
# Не теряй время ! Регистрируйся
# -
#  брать сразу пакет ― Годовая подписка Академии + Чат D...
#
#     [2022-01-13 16:30]
#     Бриф
#
# SharesPro
#
#
# ▪️
# Торги в среду завершились в умеренном позитиве: все ключевые индексы закончили торговые день в плюсе (см. картинку).
#
# ▪️
# Рынок позитивно воспринял данные по рекордной инфляции, так как они, несмотря на беспрецедентность, совпали с рыночными ожиданиями.
#
# ▪️
# В Штатах продолжа...
#
#     [2022-02-15 14:40]
#     В Петербурге мобильный пункт по профилактике ВИЧ среди трансгендерных людей прекратил свою работу после угроз «закатать “таких” в бетон» и визита агрессивно настроенных мужчин. Мы
# поговорили с директором фонда «Гуманитарное действие» (признан иноагентом) Сергеем Дугиным о специфике проекта и причина...
#
#     [2022-06-09 17:52]
#     ‟Женщине иной раз и впрямь полезно прикинуться дурочкой (иногда для этого даже не надо прикидываться!)„
#  © ВиКи, книга «Девушки со странностями» (персонаж Ирэн Ледуайен)
#
#  Источник: @loveth_leshcha
#
#     [2022-06-13 23:39]
#     ‟Настоящая правда всегда лежит по ту сторону слов, в непостижимой области, где-то посередине между сказанным и утаенным.„
#  © Макс Фрай, книга «Тёмная сторона» (персонаж Сэр Джуффин Халли)
#
#  Источник: @bashni_i_kupola
#
#     [2022-06-27 04:16]
#     ‟Может быть, мне суждено всегда влюбляться в тех, с кем невозможно быть вместе. Может быть, в будущем меня ждёт ещё много встреч с этими недостижимыми и несбыточными людьми. И мне предстоит вновь и вновь переживать эту несбыточность. Но, наверное, именно этого я и заслуживаю. Хотя нет. Это будет ещё...
#
#     [2022-07-03 15:35]
#     ‟Сопротивляйся прихотям твоим в молодости, ибо в старости никак не сможешь себя исправить, чтобы от них отвыкнуть.„
#  © Клавдий Птолемей
#
#  Источник: @biurocrady
#
#     [2022-07-06 13:29]
#     ‟Ты знаешь о чувстве, когда любишь кого-то так сильно, что ненавидишь?„
#  🎬 мультфильм «Дьявольские возлюбленные» («Diabolik Lovers», персонаж Райто)
#
#  Источник: @voyencor
#
#     [2022-07-30 12:50]
#     ‟— Должен предупредить, что такой уровень потребления крайне вредит здоровью. Ваше сердце... — Об этом не волнуйтесь, Ватсон. Там, где должен располагаться этот орган, вакуум. — Семейная черта.„
#  🎬 фильм «Шерлок: Безобразная невеста» («Sherlock: The Abominable Bride», персонажи Доктор Джон Ватсон, Ш...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1435525948 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #9, Score: 0.002149
#   In-degree: 473
#   Out-degree: 389
#   English messages: 21 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: Соловьиный полёт
#   Username: @solovjyinyy_pomjot
#   Total messages in dataset: 15,004
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-06-24 12:28] [FWD from 1343638843]
#     https://rospres.site/finance/item/370672-sergej-gordeev-v-dolgakh-kak-v-shelkakh
#
#     [2021-07-05 08:34]
#     В Житомирской области на строительстве очистных сооружений украли 900 тысяч гривен
# http://vchk-ogpu.com/component/k2/item/149979
#  Об этом сообщает @kremliovskiy_kuklovod
#
#     [2021-07-09 11:51]
#     Октавиан в Египте После победы над Антонием и Клеопатрой в 30 году до нашей эры Октавиан захватил Египет. Местное население переживало, что римляне устроят резню, грабеж и превратят все вокруг в кромешный ад, но будущий Август проявил милость ― он прекрасно понимал, что не следуют разрушать новую бо...
#
#     [2021-07-19 14:34] [FWD from 1336527836]
#     Видео с оскверненной вандалами могилой героя СССР Александра Медведева
# http://news-ru.site/component/k2/item/271567
#  Об этом сообщает @uho_prezidenta
#
#     [2021-07-23 14:03] [FWD from 1343638843]
#     Экс-главу регионального исполкома «Единой России» в Калининградской области Максима Суворова Ленинградский  райсуд заключил под стражу до 18 сентября.  Судебное заседание по избранию меры пресечения Суворову состоялось в четверг, 22 июля. В суде категорически не называют статью Уголовного кодекса РФ...
#
#     [2021-08-27 08:54]
#     Тимофей Кургин включил "непроливайку"
# http://slon.today/component/k2/item/222546
#  Об этом сообщает @wiesjci_inwiestora
#
#     [2021-08-28 09:48]
#     Экс-министра европейской интеграции Косово обвинили в коррупции
# http://compromat.pro/component/k2/item/274252
#  Об этом сообщает @vybrannyye_vory
#
#     [2021-09-16 09:51] [FWD from 1233287845]
#     🇺🇸
# 🇬🇧
# 🇦🇺
# США, Великобритания и Австралия
# создали новый военный альянс
# Интересы союза, получившего название AUKUS, будут сосредоточены в Индо-Тихоокеанском регионе. О появлении новой структуры объявили на совместной виртуальной конференции премьер-министр Австралии Скотт Моррисон, президент США Джо ...
#
#     [2021-09-21 08:20]
#     Долгожданное возвращение «Тинькофф» на рынок ипотеки начнётся с рефинансирования кредитов, которые его клиенты взяли в других банках. С декабря прошлого года проект работал в пилотном режиме для сотрудников. Рефинансирование ипотеки обычных клиентов начнётся в ближайшее время. Цель до конца года — и...
#
#     [2021-11-04 09:50] [FWD from 1353291112]
#     ͏͏Оргия иноагентов. Мужик слева похож на англичанина Сергея Брилёва с госканала Россия. Справа Юлиана Слащёва https://t.me/b_berezovskiy/26546  из госконторы Союзмультфильм - американская налогоплательщица, родная мать англичанки Марии Трапезниковой. Мусолит Слащёва либерала Андрея Трапезникова из г...
#
#     [2021-11-23 11:53]
#     «Не забудь, пожалуйста, купить майонез, ведра три. Ежекашечки. Будем твой любимый «Зимний» салат готовить. Пару тазиков всего».
#  Екатеринбурженка Елена Старикова написала небольшую книгу про Вторчермет. «Суровый Юг» — это 11 ироничных новелл про микрорайон, где автор живёт уже 15 лет.
#  26 ноября к...
#
#     [2022-04-05 21:34]
#     **Басманный суд Москвы назначил на 6 апреля рассмотрение ходатайства СКР о продлении срока ареста Денису Зубову**
#
#   Басманный суд Москвы назначил на 6 апреля рассмотрение ходатайства СКР о продлении срока ареста Денису Зубову – сыну заместителя министра внутренних дел Игоря Зубова. Также следствие ...
#
#     [2022-06-06 02:18]
#     ‟С мыслями толком никак собраться не могу. То я занят, то они.„
#  © Татьяна Устименко, книга «Лицо для Сумасшедшей принцессы» (персонаж дракон Эткин)
#
#  Источник: @stolichnyy_obzor
#
#     [2022-06-21 16:54]
#     **Задержания полицейских произошли не только в Магнитогорске, но и в Саратовской и Ростовской областях**  В Таганроге задержаны замначальника уголовного розыска Отдела полиции № 2 и его подчиненный оперативник по подозрению в получении взятки в 30 тыс. руб. https://t.me/depo_news/12 В Саратовской об...
#
#     [2022-07-03 22:11]
#     ‟Не думай, будто люди против тебя, по большей части они просто за самих себя.„
#  © Джин Фаулер
#
#  Источник: @mnogo_pesk_off
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1473948950 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #10, Score: 0.002149
#   In-degree: 473
#   Out-degree: 432
#   English messages: 15 ✓ VALID
#   Ground Truth Label: [NOT LABELED]
#   Title: News Center
#   Username: @tsentr_novostey
#   Total messages in dataset: 14,104
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-06-30 11:23]
#     Снопок знает толк в Наливко
# http://russiangate.site/component/k2/item/83081
#  Об этом сообщает @buster_and_knock_gun_up
#
#     [2021-07-19 11:10]
#     ⠀
# - Дедушка, а правда, что в СССР секса не было?
#  ― Правда, внученька, правда! Но зато всё остальное было. Причём, своё. А потом это всё мы успешно... променяли на секс...
#  ⠀   @tipichnaya_narva
#     Также по этой теме можете почитать https://t.me/lifehack_i_dlja_lifestyle_a/9622
#
#     [2021-07-30 12:46]
#     Навальный нашел у Мишустиных недвижимость почти на 3 миллиарда рублей
# http://the-people.info/component/k2/item/131208
#  Об этом сообщает @putenomika
#
#     [2021-07-31 13:06]
#     Сергеем Ролдугиным интересуется прокуратура Панамы
# http://dedal.club/component/k2/item/84132
#  Об этом сообщает @uralski_pellmeng
#
#     [2021-08-04 12:54]
#     Кто сильнее: гориллу сравнили с человеком, медведем гризли, львом и крокодилом
# http://ustav.group/component/k2/item/306141
#  Об этом сообщает @peterburzhskie_vedomosti
#
#     [2021-08-18 09:24]
#     Источник назвал предварительную причину крушения Ил-112В
# http://slon.today/component/k2/item/222217
#  Об этом сообщает @aljfa_i_omega
#
#     [2021-08-19 09:06]
#     Как друзья Владимира Путина «обувают» Россию
# http://the-people.info/component/k2/item/131744
#  Об этом сообщает @vladeyushhiy_mirom
#
#     [2021-09-14 07:42] [FWD from 1311346184]
#     ⛪️ Современный Курск глазами художников, какой он? Знаменский собор, Триумфальная арка, Тускарь и другие знакомые места появились на картинах по итогам Х Международного пленэра «Курск – соловьиного края столица». 🎨 В нём принимали участие живописцы из Беларуси, Донецка, Луганска, а также из разных у...
#
#     [2021-10-11 13:20] [FWD from 1475635308]
#     📈 ВТС отыгрывает рыночные позиции, приближаясь к показателю 55 тыс. долларов за монету, а российский «Сбербанк» стал самым дорогим банком Европы. За своих переполняет радость, не так ли? При этом многие страны в ЕС обеспокоены ростом цены на газ, как в сегменте бытового, так и промышленного использо...
#
#     [2021-10-13 11:41]
#     Четырёхлетний ребёнок чуть не сгорел заживо в машине в Алуште. Мужчина похитил сына у бывшей жены, посадил его в автомобиль и поджег. Сейчас мальчик в больнице с ожогами.
#  В отношении отца возбудили уголовное дело   @shaljnyye_bashni
#     Также по этой теме можете почитать https://t.me/glav_fin/4476
#
#     [2022-02-14 12:42] [FWD from 1296087183]
#     Махинации с переработкой мусора в Самарской области обрастают подробностями.
#
# Тольяттинский телеграмм-канал «Русский Детройт» опубликовал подробное описание схем по уходу от налогов, отмыванию денег и завышению тарифов на утилизацию отходов, которые использует группа компаний «Эковоз» принадлежащая ...
#
#     [2022-04-08 12:04]
#     **В Орле возбуждено уголовное дело ****https://t.me/doclad_docladchic/35394**  **о хищении в ходе реализации нацпроекта "Жилье и городская среда".**
#
#   По данным следствия, подрядчик сэкономил 1 млн руб. на материалах при благоустройстве двух дворов в Советском районе. Источник https://t.me/doclad_d...
#
#     [2022-06-23 22:42]
#     ‟Во вселенной полно сказочных вещей, которые терпеливо ждут, когда мы обратим на них внимание.„
#  © Иден Филпотс
#
#  Источник: @infobimba
#
#     [2022-06-24 13:11]
#     ‟Работай с умом, а не до ночи.„
#  © Луций Анней Сенека
#
#  Источник: @podslush_cubanj
#
#     [2022-06-27 07:50]
#     ‟Чтобы любовь жила вечно, достаточно забыть о времени. Это современный мир убивает любовь.„
#  © Фредерик Бегбедер, книга «Любовь живёт три года»
#
#  Источник: @peterb_dnevnik
#
#
# ================================================================================
# INVESTIGATION SUMMARY
# ================================================================================
#
# Channels investigated: 30
#   Found in TGDataset: 30
#   Not found: 0
#   With GT label: 7
#   Valid (>= 10 English msgs): 30
#   Invalid (< 10 English msgs): 0
#
# By metric:
#   Pagerank: 10 channels
#   Hub: 10 channels
#   Authority: 10 channels
