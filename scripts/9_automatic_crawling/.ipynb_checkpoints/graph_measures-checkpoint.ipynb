# %% [markdown]
# # Misure rilevanti su un grafo diretto con NetworkX
#
# Questo notebook mostra **solo le misure più utili** per analizzare un **grafo diretto** costruito da una *edge list* e indica **quando una misura è dispendiosa** per grafi grandi.
#
# > **Nota:** per grafi molto grandi, alcune misure basate su cammini minimi o enumerazione di cicli possono diventare impraticabili.

# %% [markdown]
# ## 0) Setup e costruzione del grafo
#
# Assumiamo di avere una lista di archi orientati:
#
# - `edges = [(u1, v1), (u2, v2), ...]`
#
# Sostituisci/leggi i dati nel modo che preferisci (CSV, JSON, ecc.).

# %%
# =============================================
# FAST LOAD: FILTERED GRAPH + PREPROCESSING INFO
# =============================================
# Use this cell to quickly load the pre-filtered graph
# AND the preprocessing info (channel English message counts)
#
# Requirements: run the full filtering cell ONCE first to create the cache files

import pandas as pd
import networkx as nx
import json

FILTERED_EDGES_FILE = '../../material/tgdataset_edges_filtered.csv.gz'
VALID_CHANNELS_CACHE = '../../material/valid_channels_cache.json'

# Load filtered edges
print("Loading filtered edges...")
edges_df = pd.read_csv(FILTERED_EDGES_FILE, compression='gzip')
G = nx.DiGraph()
G.add_edges_from(zip(edges_df['source'], edges_df['target']))

# Load preprocessing info
print("Loading preprocessing info...")
with open(VALID_CHANNELS_CACHE, 'r') as f:
    cache_data = json.load(f)

valid_channels = set(cache_data['valid_channel_ids'])
channel_english_count = {int(k): v for k, v in cache_data['channel_english_count'].items()}
MIN_CHANNEL_MESSAGES = cache_data['min_channel_messages']

print(f"\n{'='*60}")
print(f"FILTERED GRAPH LOADED")
print(f"{'='*60}")
print(f"  Edges: {len(edges_df):,}")
print(f"  Nodes: {G.number_of_nodes():,}")
print(f"  Valid channels: {len(valid_channels):,}")
print(f"  Min English messages: {MIN_CHANNEL_MESSAGES}")
# Out:
# Caricati 6,955,167 archi, 1,117,812 nodi

# %% [markdown]
# ## 1) Dimensione e densità (sempre fattibili)
#
# - **Numero di nodi**: `G.number_of_nodes()`
# - **Numero di archi**: `G.number_of_edges()`
# - **Densità**: `nx.density(G)`
#
# **Costo:** ~O(1)

# %%
n = G.number_of_nodes()
m = G.number_of_edges()
dens = nx.density(G)

n, m, dens
# Out:
# (1117812, 6955167, 5.566348786247016e-06)

# %% [markdown]
# ## 2) In-degree e out-degree (fondamentali)
#
# - **In-degree**: numero di archi entranti
# - **Out-degree**: numero di archi uscenti
#
# **Costo:** ~O(|E|) (scala bene anche su grafi grandi)

# %%
in_deg  = dict(G.in_degree())
out_deg = dict(G.out_degree())

# Top-10 per in-degree / out-degree
top_in  = sorted(in_deg.items(),  key=lambda x: x[1], reverse=True)[:10]
top_out = sorted(out_deg.items(), key=lambda x: x[1], reverse=True)[:10]

top_in, top_out
# Out:
# ([(1303782697, 2970),
#   (1145761925, 2455),
#   (1102334403, 2287),
#   (1225656516, 2020),
#   (1004035975, 1957),
#   (1133019113, 1846),
#   (1241034426, 1761),
#   (1334602589, 1755),
#   (1335904171, 1730),
#   (1440393212, 1604)],
#  [(1394050290, 6172),
#   (1117628569, 5740),
#   (1101170442, 5601),
#   (200389711, 4808),
#   (1179270258, 4379),
#   (1069772626, 4269),
#   (1096463945, 4194),
#   (1479163323, 3761),
#   (1378813139, 3759),
#   (1036362176, 3688)])

# %%
import matplotlib.pyplot as plt
import numpy as np

# =============================================
# PLOT IN-DEGREE DISTRIBUTION (log-log)
# =============================================
in_values = list(in_deg.values())
out_values = list(out_deg.values())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# In-degree histogram con bin logaritmici
in_values_nonzero = [v for v in in_values if v > 0]
bins_in = np.logspace(0, np.log10(max(in_values_nonzero)), 50)
axes[0].hist(in_values_nonzero, bins=bins_in, edgecolor='black', alpha=0.7)
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel('In-degree')
axes[0].set_ylabel('Number of nodes')
axes[0].set_title('In-degree distribution(log-log)')
axes[0].grid(True, alpha=0.3)

# Out-degree histogram con bin logaritmici
out_values_nonzero = [v for v in out_values if v > 0]
bins_out = np.logspace(0, np.log10(max(out_values_nonzero)), 50)
axes[1].hist(out_values_nonzero, bins=bins_out, edgecolor='black', alpha=0.7, color='orange')
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlabel('Out-degree')
axes[1].set_ylabel('Number of nodes')
axes[1].set_title('Out-degree distribution(log-log)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('degree_distribution_loglog.png', dpi=150)
plt.show()

# =============================================
# STATISTICHE: Frazioni di nodi per soglie
# =============================================
n_nodes = len(in_deg)

print("=" * 60)
print("STATISTICHE IN-DEGREE")
print("=" * 60)
print(f"Nodi con in-degree = 0:   {sum(1 for v in in_values if v == 0):,} ({100*sum(1 for v in in_values if v == 0)/n_nodes:.1f}%)")
print(f"Nodi con in-degree < 10:  {sum(1 for v in in_values if v < 10):,} ({100*sum(1 for v in in_values if v < 10)/n_nodes:.1f}%)")
print(f"Nodi con in-degree < 100: {sum(1 for v in in_values if v < 100):,} ({100*sum(1 for v in in_values if v < 100)/n_nodes:.1f}%)")
print(f"Nodi con in-degree >= 100: {sum(1 for v in in_values if v >= 100):,} ({100*sum(1 for v in in_values if v >= 100)/n_nodes:.1f}%)")

print("\n" + "=" * 60)
print("STATISTICHE OUT-DEGREE")
print("=" * 60)
print(f"Nodi con out-degree = 0:   {sum(1 for v in out_values if v == 0):,} ({100*sum(1 for v in out_values if v == 0)/n_nodes:.1f}%)")
print(f"Nodi con out-degree < 10:  {sum(1 for v in out_values if v < 10):,} ({100*sum(1 for v in out_values if v < 10)/n_nodes:.1f}%)")
print(f"Nodi con out-degree < 100: {sum(1 for v in out_values if v < 100):,} ({100*sum(1 for v in out_values if v < 100)/n_nodes:.1f}%)")
print(f"Nodi con out-degree >= 100: {sum(1 for v in out_values if v >= 100):,} ({100*sum(1 for v in out_values if v >= 100)/n_nodes:.1f}%)")
# Out:
# ============================================================
# STATISTICHE IN-DEGREE
# ============================================================
# Nodi con in-degree = 0:   1,013,414 (90.7%)
# Nodi con in-degree < 10:  1,053,033 (94.2%)
# Nodi con in-degree < 100: 1,099,642 (98.4%)
# Nodi con in-degree >= 100: 18,170 (1.6%)
#
# ============================================================
# STATISTICHE OUT-DEGREE
# ============================================================
# Nodi con out-degree = 0:   3,000 (0.3%)
# Nodi con out-degree < 10:  1,031,461 (92.3%)
# Nodi con out-degree < 100: 1,108,130 (99.1%)
# Nodi con out-degree >= 100: 9,682 (0.9%)

# %% [markdown]
# ### Centralità di grado (normalizzata)
#
# - `nx.in_degree_centrality(G)`
# - `nx.out_degree_centrality(G)`
#
# **Costo:** ~O(|E|)

# %%
in_deg_cent  = nx.in_degree_centrality(G)
out_deg_cent = nx.out_degree_centrality(G)

# Top-10
sorted(in_deg_cent.items(), key=lambda x: x[1], reverse=True)[:10], sorted(out_deg_cent.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# ([(1303782697, 0.0026569786842319497),
#   (1145761925, 0.0021962567911748944),
#   (1102334403, 0.0020459630474203598),
#   (1225656516, 0.0018071033475247605),
#   (1004035975, 0.00175074319361681),
#   (1133019113, 0.0016514419700647068),
#   (1241034426, 0.001575400492569853),
#   (1334602589, 0.0015700328588643339),
#   (1335904171, 0.001547667718424671),
#   (1440393212, 0.00143494741060877)],
#  [(1394050290, 0.005521505871743971),
#   (1117628569, 0.005135036244946597),
#   (1101170442, 0.005010686064102071),
#   (200389711, 0.004301263809355965),
#   (1179270258, 0.00391747799941135),
#   (1069772626, 0.003819071381476833),
#   (1096463945, 0.003751975960157844),
#   (1479163323, 0.0033646117277428833),
#   (1378813139, 0.00336282251650771),
#   (1036362176, 0.0032993055176590677)])

# %% [markdown]
# ## 3) Componenti connesse (molto importanti)
#
# Nei grafi diretti si usa spesso:
#
# - **SCC** (*Strongly Connected Components*): nodi mutuamente raggiungibili seguendo le direzioni.
# - **WCC** (*Weakly Connected Components*): connettività ignorando l'orientamento.
#
# **Costo:** ~O(|V| + |E|) (fattibile anche su grafi grandi)

# %%
scc = list(nx.strongly_connected_components(G))
wcc = list(nx.weakly_connected_components(G))

num_scc = len(scc)
num_wcc = len(wcc)

largest_scc = max(scc, key=len)
largest_wcc = max(wcc, key=len)

num_scc, len(largest_scc), num_wcc, len(largest_wcc)
# Out:
# (1031451, 85361, 530, 1116361)

# %%
# =============================================
# DETAILED CONNECTED COMPONENTS ANALYSIS
# =============================================
# This block analyzes WCC (Weakly Connected Components) and SCC (Strongly Connected Components)
# to understand the graph structure and implications for the crawler.
# - WCC: groups of nodes reachable ignoring edge direction
# - SCC: groups where EVERY node can reach EVERY other following edge directions
# If seeds are outside the Giant SCC, the crawler may not reach many groups.

print("=" * 60)
print("CONNECTED COMPONENTS ANALYSIS")
print("=" * 60)

# Get number of nodes for percentage calculations
total_nodes = G.number_of_nodes()

# ---- WCC Analysis ----
# wcc_sizes: list of component sizes, sorted descending
# Example: [1116361, 50, 30, 20, 10, ...] → giant component + small ones
wcc_sizes_sorted = sorted([len(component) for component in wcc], reverse=True)

print(f"\nWEAKLY CONNECTED COMPONENTS (WCC):")
print(f"  Total components: {num_wcc}")
print(f"  Giant WCC: {wcc_sizes_sorted[0]:,} nodes ({100*wcc_sizes_sorted[0]/total_nodes:.1f}%)")

if len(wcc_sizes_sorted) > 1:
    print(f"  2nd component: {wcc_sizes_sorted[1]:,} nodes ({100*wcc_sizes_sorted[1]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 2:
    print(f"  3rd component: {wcc_sizes_sorted[2]:,} nodes ({100*wcc_sizes_sorted[2]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 3:
    print(f"  4th component: {wcc_sizes_sorted[3]:,} nodes ({100*wcc_sizes_sorted[3]/total_nodes:.1f}%)")
if len(wcc_sizes_sorted) > 4:
    print(f"  5th component: {wcc_sizes_sorted[4]:,} nodes ({100*wcc_sizes_sorted[4]/total_nodes:.1f}%)")

print(f"  Top 10 component sizes: {wcc_sizes_sorted[:10]}")

# ---- SCC Analysis ----
# scc_sizes: list of component sizes, sorted descending
# Example: [85361, 2, 2, 2, 1, 1, ...] → one medium component + many singletons
scc_sizes_sorted = sorted([len(component) for component in scc], reverse=True)

print(f"\nSTRONGLY CONNECTED COMPONENTS (SCC):")
print(f"  Total components: {num_scc}")
print(f"  Giant SCC: {scc_sizes_sorted[0]:,} nodes ({100*scc_sizes_sorted[0]/total_nodes:.1f}%)")

if len(scc_sizes_sorted) > 1:
    print(f"  2nd component: {scc_sizes_sorted[1]:,} nodes ({100*scc_sizes_sorted[1]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 2:
    print(f"  3rd component: {scc_sizes_sorted[2]:,} nodes ({100*scc_sizes_sorted[2]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 3:
    print(f"  4th component: {scc_sizes_sorted[3]:,} nodes ({100*scc_sizes_sorted[3]/total_nodes:.1f}%)")
if len(scc_sizes_sorted) > 4:
    print(f"  5th component: {scc_sizes_sorted[4]:,} nodes ({100*scc_sizes_sorted[4]/total_nodes:.1f}%)")

print(f"  Top 10 component sizes: {scc_sizes_sorted[:10]}")

# ---- Implications for the crawler ----
print("\n" + "=" * 60)
print("IMPLICATIONS FOR THE CRAWLER")
print("=" * 60)
print(f"• {100*wcc_sizes_sorted[0]/total_nodes:.1f}% of nodes are in Giant WCC → network is connected (ignoring directions)")
print(f"• Only {100*scc_sizes_sorted[0]/total_nodes:.1f}% are in Giant SCC → few nodes are mutually reachable")
print(f"• If seeds are OUTSIDE the SCC, the crawler may not reach many groups")
print(f"• There are {num_wcc} separate WCC components: if all seeds are in one, others are unreachable")
# Out:
# ============================================================
# CONNECTED COMPONENTS ANALYSIS
# ============================================================
#
# WEAKLY CONNECTED COMPONENTS (WCC):
#   Total components: 530
#   Giant WCC: 1,116,361 nodes (99.9%)
#   2nd component: 45 nodes (0.0%)
#   3rd component: 32 nodes (0.0%)
#   4th component: 25 nodes (0.0%)
#   5th component: 18 nodes (0.0%)
#   Top 10 component sizes: [1116361, 45, 32, 25, 18, 15, 15, 15, 15, 12]
#
# STRONGLY CONNECTED COMPONENTS (SCC):
#   Total components: 1031451
#   Giant SCC: 85,361 nodes (7.6%)
#   2nd component: 22 nodes (0.0%)
#   3rd component: 17 nodes (0.0%)
#   4th component: 16 nodes (0.0%)
#   5th component: 13 nodes (0.0%)
#   Top 10 component sizes: [85361, 22, 17, 16, 13, 12, 12, 11, 11, 10]
#
# ============================================================
# IMPLICATIONS FOR THE CRAWLER
# ============================================================
# • 99.9% of nodes are in Giant WCC → network is connected (ignoring directions)
# • Only 7.6% are in Giant SCC → few nodes are mutually reachable
# • If seeds are OUTSIDE the SCC, the crawler may not reach many groups
# • There are 530 separate WCC components: if all seeds are in one, others are unreachable

# %% [markdown]
# ## 4) PageRank (chiave nei grafi diretti)
#
# - `nx.pagerank(G)` calcola un punteggio di importanza dei nodi.
# - È un metodo **iterativo**.
#
# **Costo:** ~O(k·|E|) dove *k* è il numero di iterazioni.
# Su grafi grandi può essere costoso: controlla `max_iter` e `tol`.

# %%
# =============================================
# PAGERANK CON ARCHI INVERTITI
# =============================================
# Normalmente PageRank premia chi ha archi ENTRANTI (aggregatori)
# Con archi invertiti, premia chi ha archi USCENTI (fonti originali)

# Crea una copia del grafo con archi invertiti
# Originale: A → B (B ha forwardato da A)
# Invertito: B → A
G_reversed = G.reverse()

# Calcola PageRank sul grafo invertito
pr = nx.pagerank(G_reversed, max_iter=100, tol=1e-6)

top_pr = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:10]
top_pr
# Out:
# [(200389711, 0.000229593206010286),
#  (191243967, 0.00015877541141803706),
#  (1117628569, 0.0001232515641186753),
#  (1394050290, 9.789617962771433e-05),
#  (1101170442, 9.125484806414493e-05),
#  (1096463945, 7.200466421996355e-05),
#  (1139528163, 7.045122045976693e-05),
#  (1001766948, 6.814564228504139e-05),
#  (1009232144, 6.626300872159349e-05),
#  (1378813139, 5.7446752029160745e-05)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# =============================================
# PLOT PAGERANK DISTRIBUTION (log-log)
# =============================================
pr_values = list(pr.values())

fig, ax = plt.subplots(figsize=(8, 5))

# Bin logaritmici
pr_values_nonzero = [v for v in pr_values if v > 0]
bins_pr = np.logspace(np.log10(min(pr_values_nonzero)), np.log10(max(pr_values_nonzero)), 50)
ax.hist(pr_values_nonzero, bins=bins_pr, edgecolor='black', alpha=0.7, color='green')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('PageRank')
ax.set_ylabel('Number of nodes')
ax.set_title('PageRank distribution(log-log) ')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('pagerank_distribution_loglog.png', dpi=150)
plt.show()

# %% [markdown]
# ## 5) HITS (hub e authority)
#
# - `nx.hits(G)` restituisce due dizionari: **hubs** e **authorities**.
# - Anche questo è **iterativo**.
#
# **Costo:** ~O(k·|E|)
# Su grafi grandi può essere costoso e talvolta più instabile di PageRank.

# %%
hubs, auth = nx.hits(G, max_iter=1000, tol=1e-8)

top_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:10]
top_auth = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:10]

top_hubs, top_auth
# Out:
# ([(1296087183, 0.0016441063217274444),
#   (1353291112, 0.0016438643012409548),
#   (1489529243, 0.0016432882456483445),
#   (1343638843, 0.0016423058512385555),
#   (1265080114, 0.0016423003485455815),
#   (1450000704, 0.0016421384204552301),
#   (1254793878, 0.001640756892384719),
#   (1303844417, 0.001640331599725397),
#   (1371199592, 0.0016400089827523735),
#   (1424937539, 0.0016396911735837823)],
#  [(1319837199, 0.001466093863644194),
#   (1212645245, 0.001464074926052309),
#   (1318275860, 0.0014618533192408052),
#   (1461240728, 0.0014597384018712552),
#   (1347229123, 0.0014581495257246738),
#   (1215834055, 0.0014572565826898257),
#   (1361322669, 0.001453538380371366),
#   (1263113710, 0.0014521381295638327),
#   (1444621361, 0.0014520848716576122),
#   (1277748571, 0.0014515238471664966)])

# %% [markdown]
# ## 6) Betweenness centrality (da usare con cautela)
#
# - `nx.betweenness_centrality(G)` misura quanto un nodo fa da “ponte” tra percorsi.
#
# **Costo:** ~O(|V|·|E|)
# 👉 **Molto dispendioso**: sconsigliato su grafi grandi.
#
# Suggerimento pratico: su grafi grandi considera un'**approssimazione** scegliendo un campione di sorgenti con `k=`.

# %%
# ESEMPIO: su grafi grandi usare una versione approssimata:
approx_bc = nx.betweenness_centrality(G, k=100, seed=42)

#bc = nx.betweenness_centrality(G)  # ok solo su grafi piccoli/medi
sorted(approx_bc.items(), key=lambda x: x[1], reverse=True)[:10]

# %% [markdown]
# ## 7) Closeness centrality (attenzione)
#
# - `nx.closeness_centrality(G)` usa molte distanze minime.
#
# **Costo:** ~O(|V|·(|V|+|E|))
# 👉 **Dispendioso** su grafi grandi e poco robusto se il grafo non è ben connesso.

# %%
cc = nx.closeness_centrality(G)
sorted(cc.items(), key=lambda x: x[1], reverse=True)[:10]

# %% [markdown]
# ## 8) Distanze globali / all-pairs shortest paths (solo su sottografi)
#
# - `nx.all_pairs_shortest_path_length(G)` calcola le distanze minime **da ogni nodo verso tutti i raggiungibili**.
#
# **Costo:** ~O(|V|·(|V|+|E|))
# 👉 **Impraticabile** su grafi grandi.
#
# Consiglio: applicare la misura **solo alla SCC più grande**.

# %%
# Costruiamo il sottografo della SCC più grande (tipica scelta)
H = G.subgraph(largest_scc).copy()

# ATTENZIONE: anche su H può essere costoso se H è grande
all_pairs = dict(nx.all_pairs_shortest_path_length(H))

# Esempio: media delle distanze (incluse le 0 su se stessi)
dists = []
for u, dist_dict in all_pairs.items():
    dists.extend(dist_dict.values())

avg_dist = sum(dists) / len(dists) if dists else None
len(H), avg_dist

# %% [markdown]
# ## 9) Cicli e DAG
#
# - `nx.is_directed_acyclic_graph(G)` verifica se il grafo è un **DAG** (nessun ciclo diretto).
#   **Costo:** ~O(|V|+|E|)
#
# - `nx.simple_cycles(G)` elenca i cicli semplici.
#   **Costo:** potenzialmente **esponenziale** 👉 evitare su grafi grandi.

# %%
is_dag = nx.is_directed_acyclic_graph(G)
is_dag
# Out:
# False

# %%
# ATTENZIONE: può esplodere su grafi grandi
cycles = list(nx.simple_cycles(G))
cycles

# %% [markdown]
# ## 10) Reciprocità (utile e leggera)
#
# Misura quanto gli archi sono spesso **bidirezionali**.
#
# - `nx.reciprocity(G)` -> valore globale (0..1 circa)
#
# **Costo:** ~O(|E|) (molto fattibile)

# %%
nx.reciprocity(G)
# Out:
# 0.11127209454496204

# %%
# =============================================
# TELEGRAM LINKS FOR MANUAL INVESTIGATION
# =============================================
# This block provides channel IDs for manual investigation.
# 
# Note: Telegram channel_ids cannot be directly converted to links.
# To investigate, you need to either:
# 1. Use Telegram API (telethon/pyrogram) to get username/title from ID
# 2. Search the ID on sites like tgstat.com or similar

# ---- Define top 20 for each metric ----
# top20_pagerank: list of tuples [(node_id, score), ...]
# Example: [(1004035975, 0.00132), (1064404455, 0.00118), ...]
top20_pagerank = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:20]
top20_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:20]
top20_authorities = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:20]

# ---- Extract just the node IDs as sets (for comparison later) ----
# Example: {1004035975, 1064404455, 1433940064, ...}
top20_pagerank_ids = set([node_id for node_id, score in top20_pagerank])
top20_hub_ids = set([node_id for node_id, score in top20_hubs])
top20_authority_ids = set([node_id for node_id, score in top20_authorities])

print("=" * 70)
print("CHANNEL IDs FOR MANUAL INVESTIGATION")
print("=" * 70)

print("\nNote: Telegram channel_ids are numeric and cannot be directly")
print("converted to links without using the Telegram API.")
print("\nTo investigate these channels, you can:")
print("  1. Use Telegram API (telethon) to get username/title from ID")
print("  2. Search the ID on tgstat.com or similar services")
print("  3. Use a bot like @username_to_id_bot (reverse lookup)")

# ---- Top 10 PageRank IDs ----
print("\n--- TOP 10 PAGERANK (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_pagerank[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Top 10 Hub IDs ----
print("\n--- TOP 10 HUBS (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_hubs[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Top 10 Authority IDs ----
print("\n--- TOP 10 AUTHORITIES (to investigate) ---")
for rank, (node_id, score) in enumerate(top20_authorities[:10], 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"  {rank}. Channel ID: {node_id} (in:{node_in_degree}, out:{node_out_degree})")

# ---- Summary of unique channels to investigate ----
all_top_ids = top20_pagerank_ids | top20_hub_ids | top20_authority_ids
print(f"\n--- SUMMARY ---")
print(f"Total unique channels in top 20 of any metric: {len(all_top_ids)}")
# Out:
# ======================================================================
# CHANNEL IDs FOR MANUAL INVESTIGATION
# ======================================================================
#
# Note: Telegram channel_ids are numeric and cannot be directly
# converted to links without using the Telegram API.
#
# To investigate these channels, you can:
#   1. Use Telegram API (telethon) to get username/title from ID
#   2. Search the ID on tgstat.com or similar services
#   3. Use a bot like @username_to_id_bot (reverse lookup)
#
# --- TOP 10 PAGERANK (to investigate) ---
#   1. Channel ID: 200389711 (in:0, out:4808)
#   2. Channel ID: 191243967 (in:0, out:3631)
#   3. Channel ID: 1117628569 (in:15, out:5740)
#   4. Channel ID: 1394050290 (in:2, out:6172)
#   5. Channel ID: 1101170442 (in:0, out:5601)
#   6. Channel ID: 1096463945 (in:838, out:4194)
#   7. Channel ID: 1139528163 (in:0, out:2658)
#   8. Channel ID: 1001766948 (in:45, out:2692)
#   9. Channel ID: 1009232144 (in:40, out:2941)
#   10. Channel ID: 1378813139 (in:0, out:3759)
#
# --- TOP 10 HUBS (to investigate) ---
#   1. Channel ID: 1296087183 (in:126, out:1032)
#   2. Channel ID: 1353291112 (in:437, out:1015)
#   3. Channel ID: 1489529243 (in:563, out:987)
#   4. Channel ID: 1343638843 (in:233, out:1006)
#   5. Channel ID: 1265080114 (in:457, out:970)
#   6. Channel ID: 1450000704 (in:439, out:968)
#   7. Channel ID: 1254793878 (in:572, out:971)
#   8. Channel ID: 1303844417 (in:228, out:977)
#   9. Channel ID: 1371199592 (in:516, out:965)
#   10. Channel ID: 1424937539 (in:435, out:991)
#
# --- TOP 10 AUTHORITIES (to investigate) ---
#   1. Channel ID: 1319837199 (in:749, out:642)
#   2. Channel ID: 1212645245 (in:745, out:551)
#   3. Channel ID: 1318275860 (in:730, out:629)
#   4. Channel ID: 1461240728 (in:741, out:590)
#   5. Channel ID: 1347229123 (in:748, out:781)
#   6. Channel ID: 1215834055 (in:743, out:567)
#   7. Channel ID: 1361322669 (in:741, out:515)
#   8. Channel ID: 1263113710 (in:740, out:547)
#   9. Channel ID: 1444621361 (in:728, out:602)
#   10. Channel ID: 1277748571 (in:731, out:689)
#
# --- SUMMARY ---
# Total unique channels in top 20 of any metric: 60

# %%
# =============================================
# MANUAL INVESTIGATION: TOP NODES BY PAGERANK, HUB, AUTHORITY
# =============================================
# This block prints detailed tables and compares overlap between metrics.
# Goal: understand if top Hubs are also top Authorities, or if they differ.
# 
# Reminder (in this graph, edge A→B means B forwarded from A):
# - Hub: node whose content is forwarded a lot (high out-degree)
# - Authority: node that forwards from many good sources (high in-degree)

# =============================================
# CONFIGURATION: Set how many top nodes to analyze
# =============================================
TOP_N = 700  # ← CHANGE THIS VALUE TO ANALYZE MORE OR FEWER NODES

# ---- Define top N for each metric ----
# top_n_pagerank: list of tuples [(node_id, score), ...]
# Example: [(1004035975, 0.00132), (1064404455, 0.00118), ...]
top_n_pagerank = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:TOP_N]
top_n_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:TOP_N]
top_n_authorities = sorted(auth.items(), key=lambda x: x[1], reverse=True)[:TOP_N]

# ---- Extract just the node IDs as sets (for comparison) ----
# Example: {1004035975, 1064404455, 1433940064, ...}
top_n_pagerank_ids = set([node_id for node_id, score in top_n_pagerank])
top_n_hub_ids = set([node_id for node_id, score in top_n_hubs])
top_n_authority_ids = set([node_id for node_id, score in top_n_authorities])

print("=" * 70)
print(f"TOP {TOP_N} NODES BY PAGERANK, HUB, AUTHORITY")
print("=" * 70)

# ---- Print top N PageRank with in/out degree ----
print(f"\n--- TOP {TOP_N} PAGERANK ---")
print(f"{'Rank':<5} {'Node ID':<15} {'PageRank':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_pagerank, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# ---- Print top N Hubs with in/out degree ----
print(f"\n--- TOP {TOP_N} HUBS ---")
print(f"{'Rank':<5} {'Node ID':<15} {'Hub Score':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_hubs, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# ---- Print top N Authorities with in/out degree ----
print(f"\n--- TOP {TOP_N} AUTHORITIES ---")
print(f"{'Rank':<5} {'Node ID':<15} {'Auth Score':<12} {'In-degree':<12} {'Out-degree':<12}")
print("-" * 56)
for rank, (node_id, score) in enumerate(top_n_authorities, 1):
    node_in_degree = in_deg.get(node_id, 0)
    node_out_degree = out_deg.get(node_id, 0)
    print(f"{rank:<5} {node_id:<15} {score:<12.6f} {node_in_degree:<12} {node_out_degree:<12}")

# =============================================
# COMPARISON: Are top Hubs also top Authorities?
# =============================================
print("\n" + "=" * 70)
print(f"COMPARISON: TOP {TOP_N} HUBS vs TOP {TOP_N} AUTHORITIES")
print("=" * 70)

# Set operations to find overlap and differences
nodes_in_both_hub_and_auth = top_n_hub_ids & top_n_authority_ids  # intersection
nodes_only_in_hub = top_n_hub_ids - top_n_authority_ids           # hub but not authority
nodes_only_in_auth = top_n_authority_ids - top_n_hub_ids          # authority but not hub

print(f"\nNodes in BOTH top {TOP_N} (Hub AND Authority): {len(nodes_in_both_hub_and_auth)}")
print(f"Nodes ONLY in top {TOP_N} Hubs: {len(nodes_only_in_hub)}")
print(f"Nodes ONLY in top {TOP_N} Authorities: {len(nodes_only_in_auth)}")

if len(nodes_in_both_hub_and_auth) > 0:
    print(f"\nNode IDs in common: {nodes_in_both_hub_and_auth}")
else:
    print(f"\n→ Top {TOP_N} Hubs and top {TOP_N} Authorities are DISTINCT groups!")

# ---- Comparison across all three metrics ----
print("\n" + "=" * 70)
print(f"COMPARISON: PAGERANK vs HUB vs AUTHORITY (TOP {TOP_N})")
print("=" * 70)

overlap_pr_hub = top_n_pagerank_ids & top_n_hub_ids
overlap_pr_auth = top_n_pagerank_ids & top_n_authority_ids
overlap_hub_auth = top_n_hub_ids & top_n_authority_ids
overlap_all_three = top_n_pagerank_ids & top_n_hub_ids & top_n_authority_ids

print(f"PageRank ∩ Hub: {len(overlap_pr_hub)} nodes in common")
print(f"PageRank ∩ Authority: {len(overlap_pr_auth)} nodes in common")
print(f"Hub ∩ Authority: {len(overlap_hub_auth)} nodes in common")
print(f"All three metrics: {len(overlap_all_three)} nodes in common")

if len(overlap_all_three) > 0:
    print(f"\nNodes in ALL three top {TOP_N}: {overlap_all_three}")

# ---- Summary ----
all_top_ids = top_n_pagerank_ids | top_n_hub_ids | top_n_authority_ids
print(f"\n--- SUMMARY ---")
print(f"Total unique channels in top {TOP_N} of any metric: {len(all_top_ids)}")
# Out:
# ======================================================================
#     },
# }

import json
import os
import random
from collections import defaultdict
from datetime import datetime

# =============================================
# CONFIGURATION
# =============================================
TGDATASET_DIR = "../../material"
EXTRACTED_DIR = f"{TGDATASET_DIR}/TGDataset_extracted"
MAPPING_FILE = f"{TGDATASET_DIR}/channel_file_mapping.json"
LABELED_FILE = f"{TGDATASET_DIR}/TGDataset/labeled_data/ch_to_topic_mapping.csv"

# How many top nodes to investigate for each metric
TOP_N_TO_INVESTIGATE = 10

# How many messages to extract per channel
N_MESSAGES = 15

# Selection mode: 'first', 'last', 'random'
SELECTION_MODE = 'random'

# =============================================
# BUILD CHANNELS CONFIG DICTIONARY
# =============================================
# Structure: {channel_id: {'n_messages': int, 'selection': str, 'metrics': list, ...}}
channels_config = {}

# Add top PageRank nodes
for rank, (node_id, score) in enumerate(top_n_pagerank[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),  # From preprocessing
        }
    channels_config[node_id]['metrics'].append('pagerank')
    channels_config[node_id]['pagerank_rank'] = rank
    channels_config[node_id]['pagerank_score'] = score

# Add top Hub nodes
for rank, (node_id, score) in enumerate(top_n_hubs[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),
        }
    channels_config[node_id]['metrics'].append('hub')
    channels_config[node_id]['hub_rank'] = rank
    channels_config[node_id]['hub_score'] = score

# Add top Authority nodes
for rank, (node_id, score) in enumerate(top_n_authorities[:TOP_N_TO_INVESTIGATE], 1):
    if node_id not in channels_config:
        channels_config[node_id] = {
            'n_messages': N_MESSAGES,
            'selection': SELECTION_MODE,
            'metrics': [],
            'in_degree': in_deg.get(node_id, 0),
            'out_degree': out_deg.get(node_id, 0),
            'english_msg_count': channel_english_count.get(node_id, 0),
        }
    channels_config[node_id]['metrics'].append('authority')
    channels_config[node_id]['authority_rank'] = rank
    channels_config[node_id]['authority_score'] = score

print(f"Channels to investigate: {len(channels_config)}")
print(f"  - From PageRank top {TOP_N_TO_INVESTIGATE}")
print(f"  - From Hub top {TOP_N_TO_INVESTIGATE}")
print(f"  - From Authority top {TOP_N_TO_INVESTIGATE}")

# =============================================
# LOAD CHANNEL MAPPING AND LABELS
# =============================================
print("\nLoading channel mapping...")
with open(MAPPING_FILE, 'r') as f:
    channel_mapping = json.load(f)

print("Loading ground truth labels...")
labels_df = pd.read_csv(LABELED_FILE)
channel_labels = dict(zip(labels_df['ch_ID'], labels_df['topic']))

print(f"  Channels in mapping: {len(channel_mapping):,}")
print(f"  Channels with labels: {len(channel_labels):,}")

# =============================================
# FUNCTION: LOAD CHANNEL DATA FROM TGDATASET
# =============================================
def load_channel_data(channel_id, channel_mapping, extracted_dir):
    """
    Load channel data from TGDataset extracted files.
    
    Returns dict with keys: 'title', 'username', 'text_messages', 'total_messages'
    """
    ch_id_str = str(channel_id)
    
    if ch_id_str not in channel_mapping:
        return None
    
    file_path = channel_mapping[ch_id_str]['file']
    full_path = f"{extracted_dir}/{file_path}"
    
    if not os.path.exists(full_path):
        return None
    
    try:
        with open(full_path, 'r') as f:
            data = json.load(f)
        
        if ch_id_str in data:
            channel_data = data[ch_id_str]
            return {
                'title': channel_data.get('title', '[no title]'),
                'username': channel_data.get('username', '[no username]'),
                'text_messages': channel_data.get('text_messages', {}),
                'total_messages': len(channel_data.get('text_messages', {})),
            }
    except Exception as e:
        print(f"  [ERROR] Failed to load channel {channel_id}: {e}")
    
    return None

# =============================================
# FUNCTION: SELECT MESSAGES
# =============================================
def select_messages(text_messages, n_messages, selection_mode):
    """
    Select messages from a channel based on configuration.
    Returns list of (msg_id, msg_data) tuples, sorted by date.
    """
    if not text_messages:
        return []
    
    msg_items = list(text_messages.items())
    msg_items_sorted = sorted(msg_items, key=lambda x: x[1].get('date', 0))
    
    n_available = len(msg_items_sorted)
    n_to_select = min(n_messages, n_available)
    
    if selection_mode == 'first':
        selected = msg_items_sorted[:n_to_select]
    elif selection_mode == 'last':
        selected = msg_items_sorted[-n_to_select:]
    elif selection_mode == 'random':
        selected = random.sample(msg_items_sorted, n_to_select)
        selected = sorted(selected, key=lambda x: x[1].get('date', 0))
    else:
        selected = msg_items_sorted[:n_to_select]
    
    return selected

# =============================================
# INVESTIGATE EACH CHANNEL
# =============================================
print("\n" + "=" * 80)
print("CHANNEL INVESTIGATION")
print("=" * 80)

investigation_results = {}

for channel_id, config in channels_config.items():
    print(f"\n{'─' * 80}")
    
    # Header with metrics
    metrics_str = ', '.join(config['metrics']).upper()
    print(f"CHANNEL {channel_id} [{metrics_str}]")
    print(f"{'─' * 80}")
    
    # Print metric rankings
    for metric in config['metrics']:
        rank = config.get(f'{metric}_rank', '?')
        score = config.get(f'{metric}_score', 0)
        print(f"  {metric.capitalize()}: Rank #{rank}, Score: {score:.6f}")
    
    # Print degree info
    print(f"  In-degree: {config['in_degree']:,}")
    print(f"  Out-degree: {config['out_degree']:,}")
    
    # Print preprocessing info
    english_count = config['english_msg_count']
    preprocess_status = "✓ VALID" if english_count >= MIN_CHANNEL_MESSAGES else f"✗ INVALID (< {MIN_CHANNEL_MESSAGES})"
    print(f"  English messages: {english_count} {preprocess_status}")
    
    # Check if labeled
    gt_label = channel_labels.get(channel_id, '[NOT LABELED]')
    print(f"  Ground Truth Label: {gt_label}")
    
    # Load channel data
    channel_data = load_channel_data(channel_id, channel_mapping, EXTRACTED_DIR)
    
    if channel_data is None:
        print(f"  [WARNING] Channel not found in TGDataset")
        investigation_results[channel_id] = {
            'config': config,
            'label': gt_label,
            'found': False,
        }
        continue
    
    print(f"  Title: {channel_data['title']}")
    print(f"  Username: @{channel_data['username']}")
    print(f"  Total messages in dataset: {channel_data['total_messages']:,}")
    
    # Select messages
    selected_messages = select_messages(
        channel_data['text_messages'],
        config['n_messages'],
        config['selection']
    )
    
    print(f"\n  MESSAGES ({len(selected_messages)} {config['selection']}, max {config['n_messages']}):")
    print(f"  {'─' * 70}")
    
    for msg_id, msg_data in selected_messages:
        msg_text = msg_data.get('message', '[no text]')
        msg_date = msg_data.get('date', 0)
        fwd_from = msg_data.get('forwarded_from_id', None)
        
        # Format date
        if msg_date:
            date_str = datetime.fromtimestamp(msg_date).strftime('%Y-%m-%d %H:%M')
        else:
            date_str = '[no date]'
        
        # Truncate message
        msg_display = msg_text[:300] if msg_text else '[empty]'
        if len(msg_text) > 300:
            msg_display += "..."
        
        # Forward indicator
        fwd_str = f" [FWD from {fwd_from}]" if fwd_from else ""
        
        print(f"    [{date_str}]{fwd_str}")
        print(f"    {msg_display}")
        print()
    
    # Store results
    investigation_results[channel_id] = {
        'config': config,
        'label': gt_label,
        'found': True,
        'title': channel_data['title'],
        'username': channel_data['username'],
        'total_messages': channel_data['total_messages'],
        'english_msg_count': english_count,
    }

# =============================================
# SUMMARY
# =============================================
print("\n" + "=" * 80)
print("INVESTIGATION SUMMARY")
print("=" * 80)

found_count = sum(1 for r in investigation_results.values() if r['found'])
labeled_count = sum(1 for r in investigation_results.values() if r['label'] != '[NOT LABELED]')

print(f"\nChannels investigated: {len(investigation_results)}")
print(f"  Found in TGDataset: {found_count}")
print(f"  Not found: {len(investigation_results) - found_count}")
print(f"  With GT label: {labeled_count}")

# Preprocessing status
valid_count = sum(1 for ch_id, r in investigation_results.items() 
                  if channels_config[ch_id]['english_msg_count'] >= MIN_CHANNEL_MESSAGES)
print(f"  Valid (>= {MIN_CHANNEL_MESSAGES} English msgs): {valid_count}")
print(f"  Invalid (< {MIN_CHANNEL_MESSAGES} English msgs): {len(investigation_results) - valid_count}")

# By metric
print("\nBy metric:")
for metric in ['pagerank', 'hub', 'authority']:
    count = sum(1 for ch_id, r in investigation_results.items() 
                if metric in channels_config[ch_id]['metrics'])
    print(f"  {metric.capitalize()}: {count} channels")
```

---

## Cambiamenti Cella 33

| Prima | Dopo |
|-------|------|
| Nessuna info preprocessing | Mostra `english_msg_count` per ogni canale |
| Nessuno status validità | Mostra `✓ VALID` o `✗ INVALID (< 10)` |
| Nessun summary preprocessing | Summary con conteggio valid/invalid |

---

## Output esempio (nuovo)
```
────────────────────────────────────────────────────────────────────────────────
CHANNEL 1117628569 [PAGERANK]
────────────────────────────────────────────────────────────────────────────────
  Pagerank: Rank #3, Score: 0.000123
  In-degree: 15
  Out-degree: 5,740
  English messages: 156 ✓ VALID
  Ground Truth Label: [NOT LABELED]
  Title: Mash
  Username: @breakingmash
  ...
# Out:
# Channels to investigate: 30
#   - From PageRank top 10
#   - From Hub top 10
#   - From Authority top 10
#
# Loading channel mapping...
# Loading ground truth labels...
#   Channels in mapping: 120,979
#   Channels with labels: 19,768
#
# ================================================================================
# CHANNEL INVESTIGATION
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 200389711 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #1, Score: 0.000230
#   In-degree: 0
#   Out-degree: 4,808
#   Ground Truth Label: [NOT LABELED]
#   [WARNING] Channel not found in TGDataset
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 191243967 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #2, Score: 0.000159
#   In-degree: 0
#   Out-degree: 3,631
#   Ground Truth Label: [NOT LABELED]
#   [WARNING] Channel not found in TGDataset
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1117628569 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #3, Score: 0.000123
#   In-degree: 15
#   Out-degree: 5,740
#   Ground Truth Label: [NOT LABELED]
#   Title: Mash
#   Username: @breakingmash
#   Total messages in dataset: 13,373
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2020-12-14 10:06]
#     **“Мне очень стыдно за свое поведение”
#
# **Михаил Ефремов продолжает извиняться. Еще одну весточку из мест заключения актер послал адвокату Александру Добровинскому. Артист извинился за свое поведение во время судебных заседаний, попросил прощения и попросил не держать на него зла.
#
# “Я считаю, что ег...
#
#     [2020-12-16 14:00]
#     Пока наше любимое приложение спало, биткоин пробил исторический максимум — 20 042 доллара.
#
#     [2021-02-01 19:03]
#     Россия продлила приостановку авиасообщения с Великобританий до 16 февраля.
#
#     [2021-03-22 10:55]
#     Главу Пензенской области Ивана Белозерцева арестовали до 20 мая.
#
# Также появились вопросы к губернаторским выборам, на которых он был избран. Следствие считает, что бывшая руководительница местной УИК сфальсифицировала итоги голосования прошлого года.
#
# Белозерцева подозревают во взятках на 31 млн ...
#
#     [2021-04-24 12:58]
#     Начальника УФСИН по Забайкалью, генерала внутренней службы Евгения Шихова застрелили на охоте.
#
# Также тяжело ранили его напарника, который скончался по дороге в больницу.
#
# **UPD:** Шихова и его напарника застрелил работник охотничьего угодья в Карымском районе Забайкалья. Причина — бытовой конфликт...
#
#     [2021-07-26 06:01]
#     Троллинг коммунальщиков вышел на новый уровень.
#
# Вчера граффити [появлялись в Питере](https://t.me/mashmoyka/7287), сегодня на Зацепском Валу нарисовали новую пикчу: дзюдоиста на фоне Фудзи, и опять хештег #wewillROCyou.
#
# Цоя закрасили, Флинта закрасили... ну-ка, кто сегодня смелый?
#
#     [2021-09-05 19:33]
#     Такого поворота в игре Аргентины и Бразилии точно не ждал никто. Матч остановлен — за четырьмя игроками аргентинской сборной пришла полиция.
#
# Мартинес, Ромеро, Ло Челсо и Буэндиа не отсидели 14-дневный карантин, обязательный для тех, кто приезжает в Бразилию из Великобритании (а они вчетвером играют...
#
#     [2021-09-08 13:01]
#     Алана Мамаева обратилась в полицию из-за угроз убийством в Инстаграме.
#
# Развод футболиста Павла Мамаева со своей женой-моделью обрастает новыми подробностями. Если раньше Павел [прикинулся](https://t.me/breakingmash/27249) мебелью и прописался в кафе, то теперь Алане угрожает Тони Монтана из инсты....
#
#     [2021-10-24 18:15]
#     Арт-фестивали в галереях и промзонах? А может, лучше в открытом поле? Такой уже третий год проводит семья художников из Ростова-на-Дону.
#
# Виктория Белокобыльская и Михаил Абрамов творили и этим же зарабатывали в городе. Пара оформляла интерьеры, делала мозаики в храмах, украшала рестораны. Но пришёл...
#
#     [2021-11-30 05:57]
#     Исследования проб воздуха из "Листвяжной" подтвердили, что в шахте произошел взрыв — МЧС
#
#     [2022-01-19 20:51] [FWD from 1529002404]
#     В Краснодаре задержан Алексей Щетинин — с осени его подозревают в убийстве, нападении на полицейских и кражах.
#
# Когда-то 44-летний мужчина был знаменит тиктоками на несколько миллионов лайков и ролью того самого зятя, к которому тёща бежала пить пиво. В октябре всё изменилось — Щетинин стал подозре...
#
#     [2022-04-21 13:46]
#     **"Слышу ZOV — еб*ть АЗОВ"**
#
# Русские хакеры снова взламывают бегущую строку на украинском телеканале "1+1" и развлекаются как могут.
#
#     [2022-04-25 18:38]
#     Жители Вельска встали на защиту 66-летнего кедра, который администрация города хотела спилить ради дорожной развязки.
#
# Ветеран Александр Иванович Беляев посадил дерево рядом с домом после войны.
# Это дерево — всё, что осталось у правнучки Ксении в память о родственнике. Кедр пережил три поколения се...
#
#     [2022-05-29 14:31]
#     Недовольные покупатели машины похитили продавца в Подмосковье и потребовали с него 180 тысяч рублей в качестве компенсации за неудобства.
#
# 26-летний Александр из Долгопрудного решил продать своё авто. Появился вариант — получить за него не какие-то бумажки, а трушную олдовую BMW 7-й серии. Долго пок...
#
#     [2022-06-20 19:08]
#     Такси вылетело на пешеходный переход и сбило пять человек в Нью-Йорке.
#
# ДТП произошло в центре Манхэттена около часа дня по местному времени. Всех пострадавших госпитализировали, водителя задержали.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1394050290 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #4, Score: 0.000098
#   In-degree: 2
#   Out-degree: 6,172
#   Ground Truth Label: [NOT LABELED]
#   Title: Раньше всех. Ну почти.
#   Username: @bbbreaking
#   Total messages in dataset: 24,187
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-12-20 13:15]
#     **Стамбульская биржа в понедельник вновь в автоматическом режиме приостановила торги ценными бумаги на фоне очередного рекордного падения турецкой лиры. **
#
# На данный момент турецкая лира потеряла около 7,67% к доллару с начала торгов утром. Курс вырос до 17,78 лиры за доллар, что является очередным...
#
#     [2022-01-13 09:40]
#     ❗️Власти Калужской области** отложили на неопределенный срок** введение обязанности предъявлять QR-код при посещении общественных мест, намеченное ранее на 15 января.
#
#     [2022-01-22 16:25]
#     ⚡️МИД Германии готовит планы по эвакуации семей персонала посольства на Украине на случай эскалации – СМИ
#
#     [2022-01-23 11:45]
#     Владимир Путин на предстоящей неделе встретится со студентами, пообщается с Олимпийской сборной РФ по телемосту, проведет совещание с кабмином и заседание Совбеза РФ — "Россия 1"
#
#     [2022-01-25 07:30]
#     В центре Антальи впервые за 29 лет выпал снег
#
#     [2022-01-26 18:05]
#     Остановки "Северного потока 2" в случае военной эскалации на Украине **было бы слишком мало**, санкции ЕС будут чувствительными для РФ — канцлер Австрии
#
#     [2022-02-02 18:21]
#     ⚡️Путин назначил Наталью Поклонскую замглавы Россотрудничества
#
#     [2022-02-10 08:10]
#     **«Металлоинвест» обвинил в шантаже нескольких бывших акционеров Лебединского ГОКа, у которых компания выкупила акции еще в августе 2007 года. **
#
# Через полгода после сделки из-за роста цен на железную руду также выросла и стоимость комбината. С тех пор миноритарии требуют компенсировать им упущенну...
#
#     [2022-02-22 15:25]
#     ⚡️США введут в ближайшие часы "существенные дополнительные санкции" в отношении РФ —  замгоссекретаря
#
#     [2022-02-22 18:33]
#     Министр национальной обороны Румынии Василе Дынку заявил во вторник в парламенте, что страна может принять более 500 тысяч беженцев в случае конфликта на Украине, сообщило агентство Аджерпрес.
#
#     [2022-04-15 08:20]
#     **В России содержатся более тысячи украинских военных, сдавшихся в плен, заявили в СК РФ. **
#
# Следователи допросили подавляющее большинство украинских военных, сдавшихся в плен и содержащихся в РФ, среди них 5 командиров бригад, заявили в ведомстве.
#
#     [2022-04-17 06:32]
#     ❗️Землетрясение магнитудой 5,3 произошло у берегов Индонезии
#
#     [2022-05-07 18:32]
#     **В субботу благодаря беспрецедентным мерам РФ и при участии ООН и МККК завершена гуманитарная операция по эвакуации мирных граждан с «Азовстали», сообщает Минобороны РФ. **
#
# За период проведения гумоперации на «Азовстали» с 5 мая удалось спасти 51 человека, включая 11 детей, каждому обеспечена безо...
#
#     [2022-07-13 16:20]
#     ❗️Союзные силы зашли в городскую черту Северска — МВД ЛНР
#
#     [2022-07-25 05:45]
#     Цифровую маркировку икры лососевых и осетровых рыб могут ввести в России до конца 2022 года, сообщает пресс-служба правительства Камчатского края.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1101170442 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #5, Score: 0.000091
#   In-degree: 0
#   Out-degree: 5,601
#   Ground Truth Label: [NOT LABELED]
#   Title: РИА Новости
#   Username: @rian_ru
#   Total messages in dataset: 9,216
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-12-06 09:52]
#     Сбербанк с нового года будет допускать к работе с клиентами только привитых сотрудников в регионах, где введена обязательная вакцинация для клиентских подразделений
#
#     [2021-12-07 08:05]
#     **Как будет организовано паломничество в Мекку для россиян, **рассказал РИА Новости муфтий Московской области Аббясов:
#
# ▪️ пока регулярных рейсов из России в Саудовскую Аравию нет, но будут чартеры и рейсы через третьи страны
#
# ▪️ по прибытии - трехдневный карантин в гостинице, поэтому нужно снять но...
#
#     [2021-12-08 00:10]
#     Депутат Владимир Бурматов призвал разрешить новогодние салюты **только в удаленных от зоопарков и приютов для животных** местах.
#
# Громкие звуки от взрывов пиротехники становятся причиной для психологических и физических травм у животных, заявил он РИА Новости.
#
#     [2021-12-08 15:07]
#     "Роскосмос" намерен отправить единственную женщину-космонавта России Анну Кикину на американском корабле Crew Dragon в 2022
#
#     [2021-12-12 00:05]
#     Эффективность "Спутника V" против "омикрона" проверят в центре Гамалеи в течение 10 дней, заявил Гинцбург РИА Новости
#
#     [2021-12-14 08:41]
#     Выявленные за сутки заражения по регионам
#
#     [2021-12-23 16:01]
#     Жилой дом горит в центре Нижнего Новгорода, один человек погиб
#
#     [2022-01-06 14:34]
#     Казахстанское телевидение выпустило репортаж об атаке на полицейский участок в Алма-Ате
#
#     [2022-01-09 05:16]
#     В генконсульстве РФ в Алма-Ате прокомментировали РИА Новости информацию о пропаже российского актера Ильи Глинникова: ничего такого к ним не поступало
#
#     [2022-01-13 16:00]
#     Канцлер ФРГ заявил, что представители "нормандской четверки" в скором времени проведут встречу, не уточнив уровень переговорщиков
#
#     [2022-01-14 07:23]
#     Окунуться в прорубь на Крещение в Магнитогорске возможно только при предъявлении QR-кода
#
#     [2022-01-19 07:30]
#     В Петербурге взрывной рост заболеваемости коронавирусом - при этом госпитализация растет не такими быстрыми темпами, сказал вице-губернатор
#
#     [2022-01-24 11:35]
#     Песков о ситуации на финансовых рынках: за периодами падения приходит рост, чем раньше оппоненты прекратят истерику - тем скорее это произойдет
#
#     [2022-01-31 16:12]
#     Генсек НАТО заявил, что видит риск в совместных учениях России и Белоруссии в связи с ситуацией вокруг Украины
#
#     [2022-02-02 12:27]
#     В НАТО отказались комментировать РИА Новости публикацию в Pais ответа США и альянса на российские предложения по безопасности. В госдепе тоже отказались комментировать.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1096463945 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #6, Score: 0.000072
#   In-degree: 838
#   Out-degree: 4,194
#   Ground Truth Label: [NOT LABELED]
#   Title: НЕЗЫГАРЬ
#   Username: @russica2
#   Total messages in dataset: 10,206
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2020-12-22 12:17]
#     По данным Минздрава, ситуация с коронавирусом стабилизировалось в Новосибирской и Курганской области. На достаточно высоком уровне заболеваемость в регионах ЦФО и ПФО (прежде всего в мегаполисах).
#
# Глава управления Роспотребнадзора по Санкт-Петербургу просит по возможности не приезжать в город, несм...
#
#     [2021-01-12 16:12] [FWD from 1474293282]
#     🔗** Растянутая на неделю [интрига Незыгаря](https://t.me/russica2/35427) завершилась словами песни из "Иронии Судьбы": думайте сами, решайте сами...**
#    Но сколько очевидностей осталось за рамками достаточно интересного сбора "пазлов" текущего перехода из точки А в точку ХЗ?
#    Одной из неозвученн...
#
#     [2021-04-23 12:12]
#     Россия больше года продолжает соблюдать «золотой мораторий», введенный с 1 апреля 2020 года в пользу Всемирного Золотого Совета в Лондоне. За год в ЗВР России не было приобретено ни одной унции драгоценного металла, вся добыча уходит на экспорт, поддерживая глобальный паритет золота и нефти на миним...
#
#     [2021-05-20 16:46] [FWD from 1075708167]
#     Главный итог встречи Лаврова и Блинкена — возврат к уважению. Уважению и пониманию, что страны друг без друга существовать не могут.
#
# Причем возврат именно американский, Россия в незбежности сосуществования не сомневалась, в отличие от новой администрации в Вашингтоне. Никаких нотаций и нравоучений,...
#
#     [2021-06-08 10:40]
#     ИРТТЭК @[irttek_ru](https://web.telegram.org/#/im?p=%40irttek_ru) специально для Незыгаря @[russica2](https://web.telegram.org/#/im?p=%40russica2)
#
# Российский дизель ждет кризис перепроизводства**
# **Тенденция
# Если не свернуть программу модернизации нефтепереработки 2011 года, то через 10 лет четверт...
#
#     [2021-07-20 15:00] [FWD from 1277368627]
#     [Индекс пандемии](https://t.me/regpol/1127) в регионах за 12-18 июля продемонстрировал отсутствие существенного роста числа новых случаев заболевания коронавирусом – оно выросло только на 0,7%, что позволяет надеяться на стабилизацию динамики. Однако серьезной проблемой остается смертность – число у...
#
#     [2021-08-04 06:22]
#     Рост цен и возможный товарный дефицит становится главным фактором социального напряжения в преддверии выборов в ГосДуму.
# Несмотря на все попытки "мягко регулировать цены" растет число жалоб населения на пропажу продуктов из магазинов. Как отмечают граждане, ситуация доходит до того, что в отдельных...
#
#     [2021-09-05 11:51]
#     [Александр Дугин](https://t.me/Agdchan)**, лидер Международного евразийского движения, - для Незыгаря**.
#
# [1].
# Идеологическая ситуация в России накануне выборов становится все более напряженной. Результат не имеет никакого значения. Но сама система начинает вибрировать не от надвигающихся рисков, ...
#
#     [2021-10-15 05:35]
#     Смыслы и оценки.
#
# Персона дня: Алексей Навальный
# Арестант был введён в повестку через вопрос президенту России и номинацию на очередную премию.
#
# @rakova_pozvonit Из интервью Путина для CNBC: Условия жизни Навального не самые лучшие, но он нарушил закон.
# @PoLSat203 В Кремле подготовились. За нескольк...
#
#     [2021-10-30 11:00] [FWD from 1277368627]
#     В Мурманской области никак не удается урегулировать отношения между местными элитами. Спустя больше месяца после выборов фактически остается обезглавленным областной центр. На прошедшем больше месяца назад заседании горсовет отказался утверждать ставленницу губернатора-варяга Чибиса, бывшего министр...
#
#     [2021-11-12 05:27]
#     **Смыслы и оценки.**
#
# Персона дня: Виталий Савельев
# Глава Минтранса вызвал неудовольствие президента неспособностью разобраться с транспортным коллапсом на Дальнем Востоке.
#
# @russica2 Минтранс в ситуации с задержкой грузов в отдалённые районы Дальнего Востока показывает свою профнепригодность. Как г...
#
#     [2021-11-15 11:34]
#     Об итогах конференции ООН в Глазго.
# 1. Конференция ООН по изменению климата выявила стратегические разногласия групп стран (200 государств и 120 их глав) в отношении проблем энергоперехода и декарбонизации в отсутствии выступлений лидеров Китая и России, без которых мирового консенсуса достичь нево...
#
#     [2021-12-09 12:56] [FWD from 1136605823]
#     КОМУ ВЫГОДНО ЗАКРЫТИЕ ПЕНЗЕНСКОГО «МАЯКА»?
#
# Шумиха вокруг загрязнения реки Суры в Пензе набирает обороты. Руководство бумажного холдинга «Маяк», которого в ряде недобросовестных СМИ едва ли не лично называют виновником случившегося, скатываясь вплоть до оскорблений, уже заплатило штраф и дало офици...
#
#     [2022-01-04 11:37]
#     __Основатель Центра социального проектирования «Платформа» Алексей Фирсов – специально для «Незыгаря». __
#
# **Пандемия как социальный тест.**
#
# Сложившуюся в 2021 году ситуацию можно описать как «новую нормальность»: общество свыклось с эпидемией и перешло в двойной регистр существования. В одном рег...
#
#     [2022-02-03 06:07] [FWD from 1006112008]
#     Россия может войти в пятерку крупнейших производителей меди в мире, [пишет](https://www.ft.com/content/d2c1cdad-f075-42a9-9372-2b54269f6316) Financial Times.
#
# К 2030 году объем производства меди в стране может вырасти вдвое, до уровня свыше 2 млн тонн. Благодаря этому Россия станет четвертым по вели...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1139528163 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #7, Score: 0.000070
#   In-degree: 0
#   Out-degree: 2,658
#   Ground Truth Label: [NOT LABELED]
#   Title: Shavkat Mirziyoyev_press-service
#   Username: @shmirziyoyev
#   Total messages in dataset: 4,187
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2018-01-10 17:44]
#     Сегодня скорость приведения Вооруженных Сил Узбекистана в боевую готовность составляет 3 часа против прежних 5 дней.
#
#     [2018-01-24 12:14]
#     Шавкат Мирзиёев Корея Республикаси Президенти Мун Чжэ Ин билан телефон орқали мулоқот қилди. Икки мамлакат ўртасидаги ҳамкорликни ривожлантириш масалалари муҳокама этилди
# www.president.uz/uz/1443
#
#     [2018-03-31 09:55]
#     Шавкат Мирзиёев: военные полигоны должны быть предметом гордости, источником силы и знаний
# www.president.uz/ru/1615
#
#     [2018-05-04 11:32]
#     Шавкат Мирзиёев Ҳиндистон халқига ҳамдардлик билдирди
# www.president.uz/uz/1699
# —
# Шавкат Мирзиёев выразил соболезнования народу Индии
# www.president.uz/ru/1699
#
#     [2018-08-06 13:17]
#     Президент Индонезия халқига ҳамдардлик билдирди
# www.president.uz/uz/1925
# --
# Президент выразил соболезнования народу Индонезии
# www.president.uz/ru/1925
#
#     [2018-10-09 02:36]
#     #UZBFRA2018
#
# Президент Шавкат Мирзиёевнинг Франция Республикасига расмий ташрифининг биринчи куни
#
#     [2018-10-19 11:26]
#     Владимир Путин Мустақиллик ва эзгулик монументига гул қўйди
# www.president.uz/uz/2098
# --
# Владимир Путин возложил цветы к монументу Независимости и гуманизма
# www.president.uz/ru/2098
#
#     [2018-11-22 07:32]
#     Инсон ҳуқуқлари бўйича Осиё форуми иштирокчиларига
# www.president.uz/uz/2152
# --
# Участникам Азиатского форума по правам человека
# www.president.uz/ru/2152
#
#     [2019-01-24 17:01]
#     Шавкат Мирзиёев: Германия Ўзбекистоннинг ишончли ва истиқболли шеригидир.
# —
# Шавкат Мирзиёев: Германия - долгосрочный и надежный партнер Узбекистана.
#
#     [2019-03-01 11:31]
#     Наманган вилоятини комплекс ривожлантириш учун 2,8 миллиард долларлик Дастур ишлаб чиқилди
# www.president.uz/uz/2410
# --
# Для комплексного развития Наманганской области разработана Программа на 2,8 миллиарда долларов
# www.president.uz/ru/2410
#
#     [2019-12-18 07:51]
#     Давлатимиз раҳбари Япония пойтахтига келди.
# "Ханэда" халқаро аэропортида Ўзбекистон Республикаси Президентини Япония таълим, маданият, спорт, фан ва технологиялар, таълим тизимини тиклаш масалалари вазири Хагиуда Коичи, Япония Ташқи ишлар вазирлигининг Марказий Осиё бўйича махсус вакили Хидеки Уяма ...
#
#     [2021-04-01 16:56]
#     Аҳоли саломатлигини сақлаш ва коронавирусга қарши курашиш масалалари бўйича [видеоселектор йиғилиши ўтказилди.
# ](https://president.uz/uz/lists/view/4274)Сирдарё вилоятида синовдан ўтказилган соғлиқни сақлаш тизимининг янги модели барча ҳудудларда жорий этилиши таъкидланди.
# Коронавирусга қарши кураши...
#
#     [2021-04-22 16:09]
#     Ҳудудларда хизмат кўрсатиш соҳасини ривожлантириш бўйича [видеоселектор йиғилиши ўтказилди](https://president.uz/uz/lists/view/4300).
# Вилоят, туман ва шаҳар ҳокимликлари томонидан 42 мингта янги лойиҳа режалаштирилгани қайд этилди.
# Бюджетдан ва Миллий банк томонидан хизмат кўрсатиш соҳасига жами 500...
#
#     [2021-05-24 05:01]
#     "**Халқ билан**" лойиҳасининг навбатдаги сони. Унинг қаҳрамонлари Президент билан учрашуви ҳақида сўзлаб беришади
# —
# Очередной выпуск нового проекта "**С народом**". Его герои расскажут о своей встрече с Президентом
#
# [Prezident.uz](https://www.prezident.uz/uz)[|](https://www.prezident.uz/oz)[Facebook...
#
#     [2021-12-27 13:50]
#     Президент Шавкат Мирзиёев 28 декабрь куни Мустақил Давлатлар Ҳамдўстлигига аъзо давлатлар раҳбарларининг норасмий саммитида иштирок этиш учун амалий ташриф билан Санкт-Петербург шаҳрига [боради.
# ](https://president.uz/uz/lists/view/4850)Тадбир кун тартибидан МДҲ доирасидаги кўп томонлама ҳамкорликка...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1001766948 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #8, Score: 0.000068
#   In-degree: 45
#   Out-degree: 2,692
#   Ground Truth Label: [NOT LABELED]
#   Title: Kun.uz | Расмий канал
#   Username: @kunuzofficial
#   Total messages in dataset: 13,913
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-06-14 09:20]
#     **Назорат қилувчи идоралар мустақил бўлиши керак. Давлат бошқарувидаги муаммолардан бири ҳақида
#
# **Нега мамлакатда назорат органларининг сиёсий мустақиллиги таъминланмаган?
#
# 👉 https://kun.uz/11247917
#
# **Kun.uz** **Telegram каналлари👇
#
# **[Ўзбекча](https://t.me/kunuzofficial) | [O‘zbekcha](https://t.m...
#
#     [2021-07-03 10:18]
#     **Чилонзорда 1 гектар ерни 1,4 млн долларга сотмоқчи бўлган мансабдорлар 8 йилга “кесилгани” маълум бўлди
#
# **Тошкент шаҳар ҳокимлиги ҳузуридаги Капитал қурилиш бош бошқармаси бошлиғи ўринбосари ҳамда Чилонзор туман инвестициялар ва ташқи савдо бўлими бошлиғи 2020 йил 25 июн куни Чилонзор туманидаги ...
#
#     [2021-08-05 14:19]
#     **«Олимнинг сиёсатга кириши янги фикр, янги штрихларни олиб келади» — президентликка номзод Баҳром Абдуҳалимов билан суҳбат
#
# **Ўзбекистон президентлик сайловида «Адолат» социал-демократик партияси томонидан партия сиёсий кенгаши раиси, тарих фанлари доктори Баҳром Абдуҳалимов номзод сифатида иштирок...
#
#     [2021-09-17 10:09]
#     **Данияда яшаш: ижтимоий ҳаёт, маданият ва харажатлар
#
# **[UzbekLife](https://t.me/uzbeklifeofficial) колумнисти навбатдаги мақола орқали Дания Қироллигида ҳаёт кечириш бўйича фойдали маълумотларни тақдим этади.
#
# 👉 [Батафсил ўқиш
#
# ](https://t.me/uzbeklifeofficial/721)**Kun.uz** **Telegram каналлари👇
# ...
#
#     [2021-10-09 09:00]
#     **Нархларнинг умумий тушиши!**
#
# Пандемия даврида, шунингдек шамоллаш ва грипп мавсумида аҳолини қўллаб-қувватлаш учун биз "Grand Pharm" дорихоналар тармоғидаги барча дори-дармонлар нархларининг **ПАСАЙИШИНИ** эълон қиламиз.
#
# Иммунитетни сақлаш учун зарур бўлган барча вирусга қарши препаратлар ва тўп...
#
#     [2021-11-17 15:05]
#     **Қоидабузарларни видеога олиб юбориш чақимчилик эмас — Ҳасанхон Яҳё Абдулмажид
#
# **Омманинг ҳақига зид иш қилинганда жамоатчиликнинг вакили сифатида буни етказиш жоиз ҳисобланади, деди йўл ҳаракати фиқҳи бўйича мутахассис Ҳасанхон Яҳё Абдулмажид Kun.uz'га берган интервьюсида. Унинг сўзларига кўра, қ...
#
#     [2022-01-26 16:55]
#     **Қатор ҳудудларда ҳали электр таъминоти тикланмади
#
# **Вазирликнинг янгиланган маълумотларига кўра, фақат тўрт ҳудудда - Тошкент шаҳри, Қорақалпоғистон, Хоразм ва Жиззахда таъминот 100 фоиз тикланган.
#
# Андижоннинг аксар туманларида кўрсаткич 10 фоиз, Сирдарёнинг Ширин шаҳридан бошқа ҳудудларида таъм...
#
#     [2022-02-11 11:10]
#     **«Машинани устига ҳайдаяпти...» — Президент ЙҲХ инспекторлари фаолиятига қаршилик кўрсатиш учун жавобгарликни кучайтириш ҳақида гапирди
#
# **Видеоселекторда йўл ҳаракати хавфсизлиги инспекторлари фаолиятига қаршилик кўрсатиш муаммосига алоҳида эътибор қаратилди.
#
# 👉 📹 https://kun.uz/33748669
#
# [Kun.uz ...
#
#     [2022-03-22 15:00]
#     **Кооперация: нима у? | ****Kun.uz**** мултфилм
#
# **Фаровон яшаш учун одамлар доим тадбир кўришган – тадбиркорлик қилишган. Бироқ бир кун келиб алоҳида-алоҳида эмас, балки бирлашиб ҳаракат қилиш яхшироқ эканини, айнан бирлашиб ҳаракат қилганда кўпроқ фойда олиш, воситалардан биргаликда фойдаланиш мум...
#
#     [2022-03-24 13:55]
#     **“Ёпиқлик томон ташланган қадам” — ИИВ киритмоқчи бўлаётган тақиқ танқидга учради
#
# **Қатор фаолларнинг фикрича, ЙПХ ходимининг видеосини интернетга берухсат қўйишни тақиқлаш – нафақат очиқлик сиёсатига, балки қонунларга ҳам зид.
#
# 👉 https://kun.uz/65502783
#
# [Kun.uz расмий канали](https://t.me/kunuzo...
#
#     [2022-03-26 10:29]
#     **Самарқанд давлат тиббиёт институтининг қарийб 1000 нафар ўқитувчи ва шифокорлари донорлик қилди
#
# **👉 https://kun.uz/71526481
#
# [Kun.uz расмий канали](https://t.me/kunuzofficial)
#
#     [2022-05-05 04:59]
#     🌎 Бутун дунёга экспорт қилиш ҳақида билмоқчимисиз?
#
# 🎯 Ундай бўлса, Анвар Абдуқаюмнинг овозли чатида иштирок этинг. Овозли чатда экспорт қилиш сирларини билиб олинг ва саволларингизни бериш имкониятига эга бўлинг!
#
# Анвар Абдуқаюм — 10 дан ортиқ бизнеслар асосчиси ва 10+ йиллик экспорт соҳасида тажриб...
#
#     [2022-06-23 12:01]
#     **Mobiuz корпоратив тариф режаларидаги интернет ҳажмини оширди
#
# **👉 https://kun.uz/44848852
#
# Реклама
#
#     [2022-07-20 07:11]
#     **Ўзбекистоннинг олтин-валюта захиралари кўпайди
#
# **Июнь ойида Ўзбекистон халқаро захираларининг валюта қисми 157,5 млн долларга, олтин қисми эса 39,8 млн долларга ошди.
#
# 👉 https://kun.uz/01032474
#
# [Kun.uz расмий канали](https://t.me/kunuzofficial)
#
#     [2022-07-24 03:52]
#     **ССВ хорижий ва нодавлат ОТМлардан ўқишни кўчиришда неча балл талаб этилишини маълум қилди
#
# **Ўтиш баллидан паст натижа тўплаган талабалар бакалавриатга қабул қилишдаги тартибга мувофиқ, табақалаштирилган тўлов-контракт асосида талабалар сафига қўшилади.
#
# 👉 https://kun.uz/43985816
#
# [Kun.uz расмий к...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1009232144 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #9, Score: 0.000066
#   In-degree: 40
#   Out-degree: 2,941
#   Ground Truth Label: [NOT LABELED]
#   Title: Двач
#   Username: @dvachannel
#   Total messages in dataset: 7,256
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-09-05 15:18]
#     **Инстасамка** приехала в Киев с концертом и во время выступления под улюлюканье своих «фанатов» **обматерила и выгнала пацана**.
#
# За что — неизвестно, но билет на концерт стоил около 1500 рублей.
#
# Кумиры, которых пориджи заслужили
#
#     [2021-09-07 05:20]
#     Когда на заводе забыл надеть каску и какая-то огромная железная хуёвина упала в сантиметре от тебя
#
#     [2021-09-14 14:38]
#     В России предложили ограничить использование средств связи во время ЧП
#
# Чтобы если вдруг чего — никто об этом не узнал
#
#     [2021-11-08 09:20]
#     Россиянку забили до смерти из-за съеденных продуктов
#
# Новости из цивилизации
#
#     [2021-12-02 06:38]
#     В России задумали строить дома из вторсырья
#
# Питаться из помоек, жить в домах из отходов
#
#     [2021-12-15 11:11]
#     Кому сейчас тоже грустно?
#
# Нам **очень**, потому что ещё не все подписались на канал [МТС Офишиал](http://t.me/vishka_mts).
#
# Мы работаем по бартеру: с тебя подписка, а с нас самые интересные новости МТС. Иногда из будущего. Иногда шуточки. Иногда не шуточки. Иногда KION. Иногда 5G.
#
# Всё как в жи...
#
#     [2021-12-22 05:38]
#     Россиянин задохнулся во время мастурбации в маске
#
# Коронавирус сосатб
#
#     [2022-02-15 10:56]
#     Тем, у кого нет 13-й зарплаты, придётся отказаться от 12-й
#
#     [2022-02-21 00:00]
#     Смекал_очка
#
#     [2022-05-06 23:20]
#     Флуоресцентная краска — опасная игрушка
#
#     [2022-05-14 17:51]
#     Бразильским копам пришлось **протаранить крыло самолёта,** чтобы не дать наркобарыгам улететь.
#
# Бразилия — это обычное лобби GTA Online
#
#     [2022-06-02 13:25]
#     Геймер попросил Bethesda сосредоточиться на создании игр вместо поддержки ЛГБТ. Компания отказала
#
# Directed by Robert B. Weide
#
#     [2022-07-03 22:44]
#     Всё ещё живёшь в своей хрущёвке? А вот обычный Петрович купил себе **дом на колёсах** за **300 тысяч рублей** и обустроил его за **4,5 миллиона.
#
# У него есть всё для жизни: **кондиционер, душ, стиральная машинка, «умный дом», кухня, отопление и даже тёплые полы. Всё это питают солнечные панели, заря...
#
#     [2022-07-18 19:20]
#     В Москве мужик засунул себе **в жопу огурец,** врачи благополучно его достали.
#
# Фулл у нас в [**Запрещёнке](https://t.me/ru2ch_ban/13629)** [[❓](https://telegra.ph/2ch-11-01)].
#
#     [2022-07-21 16:53]
#     В Москве на **шахматном турнире** ~~робот с искусственным интеллектом~~ мешок с гайками **Chessrobot** во время партии из-за сбоя **сломал 7-летнему зумеру палец.** Пацана зовут **Кристофер** и он входит в топ-30 сильнейших шахматистов столицы до 9 лет.
#
# Скайнет, прекрати калечить детей
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1378813139 [PAGERANK]
# ────────────────────────────────────────────────────────────────────────────────
#   Pagerank: Rank #10, Score: 0.000057
#   In-degree: 0
#   Out-degree: 3,759
#   Ground Truth Label: [NOT LABELED]
#   Title: Baza
#   Username: @bazabazon
#   Total messages in dataset: 11,172
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [
#     В Кузбассе на шахте имени Рубана произошел пожар. Внутри находятся 128 шахтеров.
#
# Возгорание началось в 20:50 по местному времени. По предварительным данным, пока на поверхность успели вывести 7 человек. На месте работают 24 спасателей.
#
# UPD: Эвакуация завершилась. Обошлось без пострадавших.
#
#     [2022-01-03 17:25]
#     Второй из братьев-близнецов Богданофф – Игорь – скончался в возрасте 72 лет. Чуть ранее ушёл из жизни Григорий. Об этом сообщают французские СМИ.
#
#     [2022-03-14 11:42]
#     В Москве отменен масочный режим - указ мэра.
#
# С завтрашнего дня маски в столице можно не носить.
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1296087183 [HUB]
# ────────────────────────────────────────────────────────────────────────────────
#   Hub: Rank #1, Score: 0.001644
#   In-degree: 126
#   Out-degree: 1,032
#   Ground Truth Label: [NOT LABELED]
#   Title: Караульный компромата
#   Username: @mafia_7ru
#   Total messages in dataset: 9,773
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-02-15 14:31]
#     Как рассказал источник, сейчас в Генпрокуратуре идут бои за вакантные места заместителей генпрокурора. Предварительно на эти места претендуют начальники управлений генпрокуратуры Золотарев, Некрасов, Войнов (которому по всей видимости уже наскучила должность начальника управления кадров, который нич...
#
#     [2021-02-17 05:58]
#     Герман Греф PZDC как любит ролевые игры. То Безосом себя представит, то Маском. Сегодня очередь Илона и Греф покупает разработчика приснопамятного «Ё-мобиля», компанию «Ё-инжиниринг». Проект помер, не родившись, в 2014-м, а ведь были планы выпускать уже в 2018-м по 40 тыс. автомобилей в год. Основна...
#
#     [2021-03-13 06:53] [FWD from 1353291112]
#     Набиуллина действительно такая или придуривается?
#
# Набиуллина продолжает отжигать про инфляцию: «Есть много причин, почему сейчас показатель высокий: продолжавшийся перенос ослабления валютного курса, глобальная ситуация на товарных рынках, рост цен на товары повседневного спроса, которые чувствител...
#
#     [2021-03-18 13:52] [FWD from 1272204784]
#     Помните, пару месяцев назад мы писали про ульяновского зампреда правительства Семенкина, который обжаловал свое увольнение, по суду восстановился в должности, и припеваючи работает теперь назло губернатору Морозову?
#
# Его примеру вчера, похоже, решил последовать бывший глава городка Нелидово, что нах...
#
#     [2021-04-02 04:53] [FWD from 1296087183]
#     Павел Ливинский в народе Паша Лифчик бьет новые рекорды по количеству заблокированных ссылок с его упоминанием.
# 👁 Обнаружили в реестре запрещённых сайтов еще 11,3 тыс записей, где фигурирует Ливинский.
# ➡️ https://reestr.rublacklist.net/search/?q=2-3199%2F2019
# Уважаемый Павел Анатольевич, интернет вс...
#
#     [2021-04-04 16:01]
#     Про майбах 18-летнего сына директора Ростеха Сергея Чемезова. Модель Maybach S 560 4Matic, номер в ссылке. Сестра «разбивающего стереотипы» ребенка имеет две бентли и пятисотый мерин. Например, Bentley Mulsanne Extended Wheelbase Е390ОТ799. Чемезов-отец принуждает людей платить за выкидыши своего Ав...
#
#     [2021-06-07 07:47]
#     https://fib.name/rezonans/item/188395-na-chjom-pogorel-byvshij-glava-rosalkogolregulirovaniya-igor-chuyan
#
#     [2021-07-22 08:35]
#     Агафья Лыкова возглавит список «Единой России» в Хакасии! https://t.me/porno_politika/25714
#
# Сибирская отшельница Агафья Лыкова возглавит список «Единой России» в Хакасии на выборах в Госдуму, сообщается в пресс-релизе партии. Общественную деятельницу выдвинут по одномандатному округу в Абакане. В п...
#
#     [2021-07-22 16:55]
#     Почему АП боится Грудинина?
#
# По нашей информации, сегодня на заседании ЦИК будет решена дальнейшая судьба Грудинина. Центризбирком даст ответ: останется ли предприниматель в федеральном списке КПРФ. Как сообщает наш источник, на заседании ожидается «цирк с конями».
#
# О том, почему АП категорически не...
#
#     [2021-07-27 12:02]
#     Гей оргии Эдиной России за бюджетные деньги. 10 января 2015 года друзья спикера ГД Вячеслава Володина летели в самолёте из Москвы в Саратов. Фитнес-тренер Артём Кшнясев (он на фотке), депутат Госдумы Николай Панков и актёр Евгений Миронов. Билеты куплены за полмесяца, всем троим - одним заказом. Пан...
#
#     [2021-07-28 05:03]
#     СРОЧНО. Разрешилась интрига с тем, кто будет защищать экс-главу отдела экономической безопасности  ЮКОСа Алексея Пичугина, который был этапирован  в СИЗО Лефортово и отказался от всех прежних адвокатов. Источник рассказал, что интересы осужденного на пожизненный срок будет представлять адвокат Дмитр...
#
#     [2021-08-10 14:41]
#     ❗️Пока горит Якутия, дочь главы развлекается в люксовых авто!😱
#
# 💬Айсен Николаев https://t.me/sol_cremly/11328  купи жильё пострадавшим из своего кармана! Ты украл сотни миллионов из бюджета, выведи деньги из оффшоров и заначку иначе арестуют счета за границей. Твоя судьба очень плохо кончится. Карма...
#
#     [2021-09-27 13:21]
#     Капитан спецназа ГРУ задержан за сексуальное насилие над военнослужащими
#
# Уголовные дела против командира роты спецназа ГРУ и его заместителя за сексуальное насилие над военнослужащими возбудили на Дальнем востоке. Об этом в понедельник, 27 сентября, «Ленте.ру» сообщил правозащитник Владимир Осечкин...
#
#     [2021-09-30 14:38]
#     #Москва #ЖизньНалаживается #МосковскиеВласти #Чиновники #Мэрия #Ликсутов #ДепТранс #Бокарев #Махмудов #ОбщественныйТранспорт #Бизнес #Коррупция #Бюджет
#
# Центральная пригородная пассажирская компания (ЦППК), принадлежащая олигарху Искандеру Махмудову объявила тендер на фантастическую сумму – 395 млр...
#
#     [2021-11-01 10:33] [FWD from 1241288255]
#     О конфликте в Транснефти (из аналитической справки)
# 1. АО Транснефть опубликовало официальное заявление по поводу внутреннего конфликта в Каспийском трубопроводном консорциуме, обостренного экологической катастрофой на новороссийском терминале КТК. “Безответственные каналы интернет-мессенджера «Теле...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1353291112 [HUB]
# ────────────────────────────────────────────────────────────────────────────────
#   Hub: Rank #2, Score: 0.001644
#   In-degree: 437
#   Out-degree: 1,015
#   Ground Truth Label: [NOT LABELED]
#   Title: ПростоПолитика
#   Username: @porno_politika
#   Total messages in dataset: 16,775
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-05-25 10:17]
#     Греческий миллиардер (он же Ростовский теневой босс) Иван Саввиди (он же Иван Савиди и Иван Саввидис), известный широкой аудитории по «случаю на футбольном поле», активам рекордной стоимости в ЮФО, а также «аннексии» греческого порта Салоники, не дает спокойно спать как конкурентам (в первую очередь...
#
#     [2021-06-01 09:57] [FWD from 1343638843]
#     https://rospres.site/corruption/item/369182-biznesmen-shmatko-vskryl-skhemy-obnala-s-uchastiem-fns-i-fsb
#
#     [2022-07-15 14:08] [FWD from 1296087183]
#     Редакция  начинает серию публикаций об известном в уголовном мире «предпринимателе» и «филантропе» Тимофее Кургине, который в некоторых базах фигурирует как Тимофей Кургин и Теймураз Кургин.
#
# Несколько лет назад господин Кургин начал создавать видимость кипучей «социальной» деятельности, которая бы ...
#
#     [2022-07-15 14:18] [FWD from 1296087183]
#     🤷‍♀️ “Меняем шило на мыло” или как в России назначают чиновников
#
# Дениса Мантурова утвердили на должность вице-премьера.
#
# Мы его знаем как министра промышленности и торговли. А еще мы знаем, что на эту должность Мантурова протащил генерал-полковник Сергей Чемезов (его считают входящим в окружение Пу...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1489529243 [HUB]
# ────────────────────────────────────────────────────────────────────────────────
#   Hub: Rank #3, Score: 0.001643
#   In-degree: 563
#   Out-degree: 987
#   Ground Truth Label: [NOT LABELED]
#   Title: Уполномочен заявить
#   Username: @tass_kgb
#   Total messages in dataset: 25,239
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-07-26 13:25]
#     Сомнительная энергетика Рюмина?
# http://russiangate.site/component/k2/item/86344
#  Об этом сообщает @asy_piiara
#
#     [2021-08-10 16:49] [FWD from 1296087183]
#     Якутия: пожары - ничто, чиновники - все
#
# Республика горит, для тушения пожаров стянуты немалые федеральные силы. Ситуация беспрецендентная, требующая максимального внимания всех жителей Якутии.
# Однако местное законодательное собрание Ил Тумэн вместо того, чтобы оказать самое пристальное внимание пож...
#
#     [2021-08-16 11:43] [FWD from 1296087183]
#     Госбанк «ВТБ» выводит деньги при продаже активов на аффилированных лиц, плюс кормит их госконтрактами.    Преступная Россия   пишет, что некто ИП Юлия Иванова выступает организатором продажи складского комплекса «Тиера», который продает «ВТБ» со стартовой ценой 2.99 млрд. рублей. Иванова получает за...
#
#     [2021-08-27 12:42]
#     В Харькове силовики штурмовали дом криминального авторитета, – СМИ
# http://minpravda.com/component/k2/item/200464
#  Об этом сообщает @voyen_oborzevateli
#
#     [2021-09-01 07:36]
#     Гигантский робот создан на потеху публике. По сути, он ничего не делает полезного, а просто впечатляет...   @pochtaljyon_pechcin
#     Также по этой теме можете почитать https://t.me/sodruzh_nezavis_gosudar/13750
#
#     [2021-10-19 11:10] [FWD from 1353291112]
#     Московская реновация имени Собянина не только дает застройщикам возможность заработать на новом строительстве и расчищает место для новых человейников. Самые ушлые из них, например, Пик, пока граждане оформляют ордера и готовятся к переезду, быстренько проводят общие собрания и утверждают управленче...
#
#     [2021-11-04 06:22] [FWD from 1353291112]
#     ͏͏Оргия иноагентов. Мужик слева похож на англичанина Сергея Брилёва с госканала Россия. Справа Юлиана Слащёва https://t.me/b_berezovskiy/26546  из госконторы Союзмультфильм - американская налогоплательщица, родная мать англичанки Марии Трапезниковой. Мусолит Слащёва либерала Андрея Трапезникова из г...
#
#     [2022-01-08 17:09] [FWD from 1296087183]
#     Скандальный казахский «БТА банк» внезапно снова оказался в заголовках криминальных новостей по всему миру.
#
# В США бывшего делового партнера Дональда Трампа, бизнесмена и девелопера Феликса Сатера, обвинили в выводе миллионов $ (сумма пока не озвучена) из «БТА» с последующим отмывом через собственнос...
#
#     [2022-02-16 16:49] [FWD from 1460670961]
# ...
#
#     [2021-08-18 12:52]
#     В Якутии рассказали о ситуации с пожарами в лесах
# http://rasstriga.info/component/k2/item/121502
#  Об этом сообщает @otcat_za_otcatom
#
#     [2021-09-06 15:32] [FWD from 1342185951]
#     ​Российский бизнес заподозрили в отмывании 616 млрд рублей.
#  Заявители обращаются в суд, чтобы получить исполнительные документы и легализовать незаконные доходы. За год сумма требований по таким спорам выросла в три раза   @voyencor_online
#     Также по этой теме можете почитать https://t.me/piesni...
#
#     [2021-09-08 12:50] [FWD from 1244801504]
#     **У покойной https://t.me/evdoc_avriolovna/17892**  **депутатки Ларисы Шойгу не только муж Фламенбаум.**
#
#   Сама сестра Сергея Шойгу была Ларисой Кужугетовной Фламенбаум. Получила на эту фамилию паспорт 4501153355, ИНН, прописку. У зама Шойгу по минобороны жена-гражданка Израиля, тесно связана со сп...
#
#     [2021-11-09 11:05] [FWD from 1219033456]
#     Делягин Михаил Геннадьевич
# Экономист, депутат Госдумы РФ от партии «Справедливая Россия — За правду»
#
#  «При этом все говорят о вакцинации. Это неправда! У нас идёт эксперимент, тестирование вакцины! Люди, которые хотят вакцинироваться, на самом деле предоставляют себя для научного эксперимента».
#  ...
#
#     [2021-12-04 10:48]
#     🤷‍♂️ По окончании этого года Manifesto Market изменит расположение своей первой гастрономической зоны. Из района Florenc рынок переместится в новое место, откуда "посетителям откроется захватывающий вид на Прагу". Команда, собранная основателем проекта, архитектором Мартином Барри, создаст новое про...
#
#     [2021-12-22 09:35]
#     Немецкий медиарегулятор приказал европейскому спутниковому оператору Eutelsat 9В снять со своей платформы немецкоязычный телеканал RT DE, вещающий из студий в Москве —
#  считаем действия немецкого регулятора незаконными и убеждены, что данное решение будет пересмотрено в судебном порядке» , — сообщил...
#
#     [2022-02-09 17:02] [FWD from 1269495740]
#     Губернатор Самарской области Азаров оставил без охраны детские сады. Криворукие подчиненные губернатора увлеклись проектами 700-метровых фонтанов и просто забыли заложить в бюджет деньги на безопасность дошкольных образовательных учреждений.
#
# Проблема вскрылась после обращения самарских родителей к ...
#
#     [2022-03-22 15:32]
#     **Ирина Волк: Следователи МВД России расследуют первое в стране уголовное дело о растрате денежных средств и имущества криптовалютной биржи**
#
#   Ирина Волк: Следователи МВД России расследуют первое в стране уголовное дело о растрате денежных средств и имущества криптовалютной биржи https://t.me/beri...
#
#     [2022-07-27 12:33]
#     ‟Все жанры искусства хороши, кроме скучного, но скука — не жанр.„
#  © Вольтер (Франсуа-Мари Аруэ)
#
#  Источник: @gosdura_rf
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1263113710 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #8, Score: 0.001452
#   In-degree: 740
#   Out-degree: 547
#   Ground Truth Label: [NOT LABELED]
#   Title: Media base
#   Username: @mediynaya_baza
#   Total messages in dataset: 13,784
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-07-15 08:32]
#     В крупнейших городах Франции тысячи людей вышли на акции против запрета на посещение общественных мест без сертификата о вакцинации
# http://dedal.club/component/k2/item/80777
#  Об этом сообщает @wiesti_3_0
#
#     [2021-07-26 10:57]
#     Ихтияр Уразалин ответит за пропавшие вещдоки.
# http://compromatbase.info/component/k2/item/105683
#  Об этом сообщает @corruptionny_digest
#
#     [2021-07-31 10:31]
#     Кобура в центральном круге
# http://dedal.club/component/k2/item/84151
#  Об этом сообщает @crypto_west_nick
#
#     [2021-08-02 07:52]
#     Дольщики ЖК "Звезда" стали жертвой ГК "Элис"
# http://politica2.info/component/k2/item/54646
#  Об этом сообщает @now_go_road_ski
#
#     [2021-08-05 11:32]
#     Фейк Марии Захаровой: Гитлер пришел к власти демократическим путем
# http://politica2.info/component/k2/item/54762
#  Об этом сообщает @novosti_topora
#
#     [2021-09-02 07:20]
#     Павел Латушко провел встречу с послом Канады в Польше и Беларуси Руководитель НАУ Павел Латушко встретился с Лесли Скэнлон – главой дипмиссии Канады в Польше и Беларуси по совместительству. Главной темой встречи было обсуждения вопроса возможностей блокирования использования специальных прав заимств...
#
#     [2021-09-08 13:45] [FWD from 1518283341]
#     **Коррупция и бесконтрольное разбазаривание бюджетных денег в Минобороны — новая тема размышлений находящегося под арестом экс-главы Серпуховского района Александра Шестуна.**
#
#   Чья команда эффективнее — министра обороны Шойгу или его предшественника Сердюкова? Когда в военном ведомстве было больше...
#
#     [2021-09-21 10:27] [FWD from 1269638412]
#     **Ольга Хромченко, которую журналисты связывают с главой Минфина Антоном Силуановым, получила доли в проектах, получающих масштабное финансирование из казны.**
#
#   Ее родственники числились в компании, причастной к многомиллионной махинации с государственными средствами. 33-летняя Хромченко родилась ...
#
#     [2021-09-23 11:04]
#     Новые функции «Инстаграм» : инструкция по фильтрации контента, борьбе со спамом и хейтерами
# Летом «Инстаграм» активно взялся за безопасность и ввел несколько новых функций. Прилетает много спама в директ? – вот, держите специальный фильтр. Одолели боты с глупыми комментариями? – включите ещё один фи...
#
#     [2021-10-18 13:12] [FWD from 1592770527]
#     Комиинформ
# В Печоре понадобилась помощь росгвардейцев, чтобы решить вопрос с заснувшей в магазине женщиной   @wiesjci_inwiestora
#     Также по этой теме можете почитать https://t.me/v_lastj_v_slastj/8196
#
#     [2021-11-19 09:31]
#     Магадан получит 63 миллиона рублей на ремонт 9 дворов. Какие именно дворы благоустроят ― выберут сами магаданцы   @analitichesciy_vestnic
#     Также по этой теме можете почитать https://t.me/poyezdca_po_ocraine/21073
#
#     [2022-04-29 18:22]
#     **Прошли обыски ****https://t.me/putin_ryzan/39078** **у замминистра здравоохранения Башкирии Ирины Кононовой**
#
#   Прошли обыски https://t.me/putin_ryzan/39078 у замминистра здравоохранения Башкирии Ирины Кононовой по делу о нарушения при закупках препарата для онкобольных "Трипторелин" на 51 млн ру...
#
#     [2022-06-12 00:20]
#     ‟Все теории построения идеального общества обречены на провал, потому что исходят из неправильной посылки. Они рассчитаны на то, что человек — существо порядочное и с готовностью воспримет идеи добра, стоит только их ему предоставить.„
#  🎬 фильм «Будь что будет» («Whatever Works», персонаж Борис (Bor...
#
#     [2022-06-21 15:12]
#     ‟Сейчас даже fuck значит не то, что значило когда-то. И по правде сказать, что жаль...„
#  © Януш Леон Вишневский, книга «Одиночество в Сети»
#
#  Источник: @neftjanyye_reki
#
#     [2022-07-21 16:55]
#     ‟Мудрости не учишься у других, к ней приходишь сам, вставая на ноги после каждого нового удара судьбы.„
#  © Эльчин Сафарли, книга «Мне тебя обещали»
#
#  Источник: @denjgi_i_groshy
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1444621361 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #9, Score: 0.001452
#   In-degree: 728
#   Out-degree: 602
#   Ground Truth Label: [NOT LABELED]
#   Title: Mash Moscow
#   Username: @mash_moscow
#   Total messages in dataset: 14,524
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-07-19 08:51] [FWD from 1417590558]
#     Скандальный «Вентпром». Кто получает госзаказ от директора «МОСИНЖПРОЕКТА» Марса Газизуллина
# http://compromatbase.info/component/k2/item/103456
#  Об этом сообщает @putin_a_k_a_pynja
#
#     [2021-07-20 09:32]
#     У Кубива заказали фуршет в Женеве за 6 миллионов
# http://fib.name/component/k2/item/190206
#  Об этом сообщает @contrsancthiyi
#
#     [2021-07-21 10:09]
#     Пресс-конференция депутата Демина по кличке "Кокос"
# http://dedal.club/component/k2/item/82165
#  Об этом сообщает @lavrov_life
#
#     [2021-08-05 10:10]
#     Самое время совершить арт-поездку в Питер, где сейчас можно посмотреть новые выставки в порте Севкабель и Петербургском Манеже
# Освещая с разных ракурсов тему
#  «Новая кожа: миф технологического тела» , авторы выставки в порте Севкабель фокусируются на концепции зарождающейся сегодня новой экологическ...
#
#     [2021-08-06 08:44]
#     Учёные разработали ультрафиолетовую лампу, которая почти на 100  защищает от коронавируса
# http://slon.today/component/k2/item/221946
#  Об этом сообщает @tipichn_roscosmos
#
#     [2021-08-12 13:19]
#     Билл Гейтс низко пал после развода
# http://russiangate.site/component/k2/item/87317
#  Об этом сообщает @mir_vsem_mestnyim
#
#     [2021-08-27 08:00]
#     Бывший глава пыточной колонии в Карелии, где сидел активист Дадин, вышел на свободу досрочно
# http://minpravda.com/component/k2/item/200420
#  Об этом сообщает @khronik_sechin
#
#     [2021-10-05 09:20]
#     Актриса Юлия Пересильд и режиссёр Клим Шипенко летят на МКС снимать фильм. Смотрите трансляцию запуска корабля
# ДАННОЕ СООБЩЕНИЕ (МАТЕРИАЛ) СОЗДАНО И (ИЛИ) РАСПРОСТРАНЕНО ИНОСТРАННЫМ СРЕДСТВОМ МАССОВОЙ ИНФОРМАЦИИ, ВЫПОЛНЯЮЩИМ ФУНКЦИИ ИНОСТРАННОГО АГЕНТА, И (ИЛИ) РОССИЙСКИМ ЮРИДИЧЕСКИМ ЛИЦОМ, ВЫПОЛНЯЮ...
#
#     [2021-11-08 09:21] [FWD from 1411515332]
#     В повестке:
# -доклад ЦБ согласно которому рост цен и инфляция неминуемо продолжатся в 2022 году. Де-факто регулятор расписывается в собственной неспособности хоть как-то повлиять на обесценивающиеся уже восемь месяцев подряд доходы и пенсии россиян. Рост реальных доходов населения в 2021 году оказалс...
#
#     [2021-12-18 10:04] [FWD from 1544834983]
#     Ищу способных учеников на обучение трейдингу — удалённой профессии, набирающей популярность в интернете.
#  Мне нужны трудоспособные мужчины и девушки, у которых есть ноутбук (или смартфон), один свободный час в день и желание уделить его обучению и применению знаний на практике, чтобы зарабатывать в...
#
#     [2022-02-09 10:06] [FWD from 1343638843]
#     Чистая работа: ответственность производителей за отходы товаров и упаковки пересмотрят
#
# Вице-премьер Виктория Абрамченко назначила 25 февраля контрольным сроком, когда профильные ведомства должны представить ей свои предложения о перезапуске механизма расширенной ответственности производителей и имп...
#
#     [2022-06-21 16:51]
#     ‟Против глупости сами боги бороться бессильны.„
#  © Фридрих Шиллер
#
#  Источник: @corruption_week
#
#     [2022-07-01 22:53]
#     ‟Настоящая любовь безгранична. Это как жизнь или смерть. Когда ты готова умереть, когда вы расстаетесь, потому что чувства так чисты, так сильны.„
#  🎬 фильм «Нация прозака» («Prozac Nation», персонаж Элизабет Вурцел (Elizabeth Wurtzel))
#
#  Источник: @stolich_zhyznj
#
#     [2022-07-05 05:46]
#     ‟Свиться струйкой водопроводной – Двинуть к морю до холодов. Я хочу быть такой свободной, Чтобы не оставлять следов.„
#  © Вера Полозкова
#
#  Источник: @sibirsciye_thyrjuljnici
#
#     [2022-07-11 10:22]
#     **​​Генеалогическое древо Путиных, включающее его тайную племянницу**  Властям много лет удавалось скрывать, что двоюродная племянница президента Анна Путина и «хозяйка» Кемеровской области, угольный магнат Анна Цивилева — один и тот же человек. Рассказываем, как мы это установили и заодно публикуем...
#
#
# ────────────────────────────────────────────────────────────────────────────────
# CHANNEL 1277748571 [AUTHORITY]
# ────────────────────────────────────────────────────────────────────────────────
#   Authority: Rank #10, Score: 0.001452
#   In-degree: 731
#   Out-degree: 689
#   Ground Truth Label: [NOT LABELED]
#   Title: Шальные башни
#   Username: @shaljnyye_bashni
#   Total messages in dataset: 14,951
#
#   MESSAGES (15 random, max 15):
#   ──────────────────────────────────────────────────────────────────────
#     [2021-06-18 15:05]
#     Краснов, Бортников и Бастрыкин проконтролируют уголовное дело ОПГ депутатов Вихаревых?
# http://minpravda.com/component/k2/item/192948
#  Об этом сообщает @nal_i_kriminal
#
#     [2021-06-19 10:23]
#     Бывших полицейских подвела прослушка
# http://politica2.info/component/k2/item/47763
#  Об этом сообщает @don_d_gordon
#
#     [2021-07-08 14:25]
#     👉Сегодня, 8 июля, в России отмечается День семьи, любви и верности. Праздник стал государственным в 2008 году, когда инициатива об его учреждении была одобрена в Совете Федерации. 🔶В этот день Русская православная церковь отмечает день памяти святых Петра и Февронии, которые издревле считались на Ру...
#
#     [2021-07-31 07:44]
#     Генерал-майор ФСБ Владимир Подольский может стать дважды мошенником
# http://skelety.club/component/k2/item/163603
#  Об этом сообщает @gossovet_online
#
#     [2021-08-14 09:40] [FWD from 1175598616]
#     Турчаку аукнулось гиперзвуком
# http://minpravda.com/component/k2/item/200049
#  Об этом сообщает @borjba_za_uspekh
#
#     [2021-08-19 12:40]
#     Российский посол заявил о стабилизации ситуации в Кабуле
# http://news-ru.site/component/k2/item/274475
#  Об этом сообщает @analitic_fin
#
#     [2021-09-17 11:03]
#     📌 «Климент Римский являлся 4 епископом Рима, был крещён апостолом Петром. Он принял мученическую смерть в инкерманских каменоломнях, куда был сослан императором Трояном. Его глава ― первая святыня, которую принёс князь Владимир на Русь после своего крещения» ― рассказывает настоятель храмов Климента...
#
#     [2021-12-17 15:34]
#     Во вчерашней аварии с "Поло" на Невском погибла 23-летняя девушка-фотограф и очень серьёзно пострадал её 26-летний спутник, снимавшийся для рекламы.
#  Спиридона Анисимова, известного по съёмкам в том числе для Tinder, отвезли в Мариинскую больницу с переломом позвоночника, сотрясением и черепно-мозг...
#
#     [2022-03-21 13:44]
#     **В МОСКВЕ ПОД ДОМАШНИЙ АРЕСТ ОТПРАВИЛИ РОМАНА КОРОЛЁВА**
#
#   В МОСКВЕ ПОД ДОМАШНИЙ АРЕСТ ОТПРАВИЛИ РОМАНА КОРОЛЁВА — экс зампрокурора Курской области, сына экс-губернатора и сенатора от Липецкой обл. Олега Королёва https://t.me/themoscow_post/40388 Роман Королев, являясь ныне адвокатом, пытался похи...
#
#     [2022-04-16 20:19]
#     **Экс-главе администрации Ульяновской области Анатолию Озернову предъявили взятку на 2 млн руб. и растрату на 300 тыс. рублей.**
#
#   Экс-главе администрации Ульяновской области Анатолию Озернову предъявили взятку на 2 млн руб. и растрату на 300 тыс. рублей. возбуждено еще одно уголовное дело, которое...
#
#     [2022-06-05 22:53]
#     ‟Умей сгруппироваться, достичь успеха и не терять сон.„
#  🎬 фильм «Адвокат Дьявола» («The Devil's Advocate»)
#
#  Источник: @typical_petersburgh
#
#     [2022-06-15 00:20]
#     ‟Даже если раны детства заживают, ранимость никогда не проходит. Возраст не служит защитой от душевной травмы.„
#  © Марио Пьюзо, книга «Дураки умирают» (персонаж Джон Мерлин)
#
#  Источник: @cao_inform
#
#     [2022-07-09 04:13]
#     ‟Проживание — это разница между дохлой фразой в учебнике истории: «По дороге на Теночтитлан Кортес после нескольких вооруженных стычек заручился поддержкой тласкальцев» и тем ужасом, когда горстка (сотни две) раненных, голодных, дезентерийных испанцев, отбив атаки, днями сидели в окружении нескольки...
#
#     [2022-07-11 11:04]
#     **Кузбасс — место, где власти и нечистый на руку бизнес издеваются над людьми и экологией.**  Кузбасс — место, где власти и нечистый на руку бизнес издеваются над людьми и экологией. Вот чёрный снег выпал в городе Киселевске. Причина тому — работа Центральной обогатительной фабрики «Краснокаменская»...
#
#     [2022-07-21 09:53]
#     ‟Может быть, нам только кажется, что мы существуем, а на самом деле нас нет. Ничего я не знаю, никто ничего не знает.„
#  © Антон Павлович Чехов, книга «Три сестры» (персонаж Чебутыкин)
#
#  Источник: @guber_srok
#
#
# ================================================================================
# INVESTIGATION SUMMARY
# ================================================================================
#
# Channels investigated: 30
#   Found in TGDataset: 28
#   Not found: 2
#   With GT label: 0
#
# By metric:
#   Pagerank: 10 channels
#   Hub: 10 channels
#   Authority: 10 channels

# %% [markdown]
# ## Riepilogo pratico (cosa usare su grafi grandi)
#
# ✅ **Sempre ok**: nodi/archi/densità, in/out-degree, SCC/WCC, reciprocità
# ⚠️ **Ok con attenzione**: PageRank, HITS (iterativi)
# ❌ **Spesso da evitare**: betweenness, closeness, all-pairs shortest paths, enumerazione cicli
